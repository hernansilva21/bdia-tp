# %% [markdown]
# # TP FINAL

# %%
# !pip install pymongo python-dotenv

# %%
# Conexión a MongoDB
from dotenv import load_dotenv
import os
from pymongo import MongoClient

load_dotenv()
user = os.environ["MONGO_USER"]
password = os.environ["MONGO_PASS"]
client = MongoClient(f"mongodb+srv://{user}:{password}@cluster0.xet1xsa.mongodb.net/")
db = client["sample_mflix"]

# %% [markdown]
# ## 1. Encuentra el número de películas lanzadas cada año

# %%
result = db.movies.aggregate([
    { '$group': { '_id': '$year', 'total': { '$sum': 1 } } },
    { '$sort': { '_id': 1 } }
])
for doc in result:
    print(doc)
# Out:
# {'_id': 1896, 'total': 2}
# {'_id': 1903, 'total': 1}
# {'_id': 1909, 'total': 1}
# {'_id': 1911, 'total': 2}
# {'_id': 1913, 'total': 1}
# {'_id': 1914, 'total': 3}
# {'_id': 1915, 'total': 2}
# {'_id': 1916, 'total': 2}
# {'_id': 1917, 'total': 2}
# {'_id': 1918, 'total': 1}
# {'_id': 1919, 'total': 1}
# {'_id': 1920, 'total': 4}
# {'_id': 1921, 'total': 5}
# {'_id': 1922, 'total': 3}
# {'_id': 1923, 'total': 2}
# {'_id': 1924, 'total': 6}
# {'_id': 1925, 'total': 3}
# {'_id': 1926, 'total': 6}
# {'_id': 1927, 'total': 4}
# {'_id': 1928, 'total': 8}
# {'_id': 1929, 'total': 7}
# {'_id': 1930, 'total': 10}
# {'_id': 1931, 'total': 20}
# {'_id': 1932, 'total': 18}
# {'_id': 1933, 'total': 20}
# {'_id': 1934, 'total': 23}
# {'_id': 1935, 'total': 31}
# {'_id': 1936, 'total': 30}
# {'_id': 1937, 'total': 31}
# {'_id': 1938, 'total': 38}
# {'_id': 1939, 'total': 20}
# {'_id': 1940, 'total': 24}
# {'_id': 1941, 'total': 24}
# {'_id': 1942, 'total': 30}
# {'_id': 1943, 'total': 32}
# {'_id': 1944, 'total': 23}
# {'_id': 1945, 'total': 29}
# {'_id': 1946, 'total': 34}
# {'_id': 1947, 'total': 29}
# {'_id': 1948, 'total': 56}
# {'_id': 1949, 'total': 52}
# {'_id': 1950, 'total': 55}
# {'_id': 1951, 'total': 54}
# {'_id': 1952, 'total': 45}
# {'_id': 1953, 'total': 65}
# {'_id': 1954, 'total': 47}
# {'_id': 1955, 'total': 67}
# {'_id': 1956, 'total': 67}
# {'_id': 1957, 'total': 71}
# {'_id': 1958, 'total': 75}
# {'_id': 1959, 'total': 71}
# {'_id': 1960, 'total': 73}
# {'_id': 1961, 'total': 68}
# {'_id': 1962, 'total': 70}
# {'_id': 1963, 'total': 69}
# {'_id': 1964, 'total': 86}
# {'_id': 1965, 'total': 77}
# {'_id': 1966, 'total': 87}
# {'_id': 1967, 'total': 81}
# {'_id': 1968, 'total': 89}
# {'_id': 1969, 'total': 107}
# {'_id': 1970, 'total': 120}
# {'_id': 1971, 'total': 106}
# {'_id': 1972, 'total': 121}
# {'_id': 1973, 'total': 112}
# {'_id': 1974, 'total': 103}
# {'_id': 1975, 'total': 107}
# {'_id': 1976, 'total': 116}
# {'_id': 1977, 'total': 123}
# {'_id': 1978, 'total': 128}
# {'_id': 1979, 'total': 131}
# {'_id': 1980, 'total': 167}
# {'_id': 1981, 'total': 168}
# {'_id': 1982, 'total': 177}
# {'_id': 1983, 'total': 161}
# {'_id': 1984, 'total': 199}
# {'_id': 1985, 'total': 189}
# {'_id': 1986, 'total': 190}
# {'_id': 1987, 'total': 222}
# {'_id': 1988, 'total': 251}
# {'_id': 1989, 'total': 232}
# {'_id': 1990, 'total': 225}
# {'_id': 1991, 'total': 238}
# {'_id': 1992, 'total': 270}
# {'_id': 1993, 'total': 274}
# {'_id': 1994, 'total': 305}
# {'_id': 1995, 'total': 372}
# {'_id': 1996, 'total': 407}
# {'_id': 1997, 'total': 439}
# {'_id': 1998, 'total': 513}
# {'_id': 1999, 'total': 515}
# {'_id': 2000, 'total': 581}
# {'_id': 2001, 'total': 612}
# {'_id': 2002, 'total': 622}
# {'_id': 2003, 'total': 603}
# {'_id': 2004, 'total': 678}
# {'_id': 2005, 'total': 713}
# {'_id': 2006, 'total': 774}
# {'_id': 2007, 'total': 810}
# {'_id': 2008, 'total': 886}
# {'_id': 2009, 'total': 917}
# {'_id': 2010, 'total': 866}
# {'_id': 2011, 'total': 893}
# {'_id': 2012, 'total': 955}
# {'_id': 2013, 'total': 1105}
# {'_id': 2014, 'total': 1073}
# {'_id': 2015, 'total': 480}
# {'_id': 2016, 'total': 1}
# {'_id': '1981è', 'total': 1}
# {'_id': '1986è', 'total': 1}
# {'_id': '1987è', 'total': 1}
# {'_id': '1988è', 'total': 1}
# {'_id': '1994è1998', 'total': 1}
# {'_id': '1995è', 'total': 1}
# {'_id': '1996è', 'total': 1}
# {'_id': '1997è', 'total': 2}
# {'_id': '1999è', 'total': 1}
# {'_id': '2000è', 'total': 1}
# {'_id': '2002è', 'total': 1}
# {'_id': '2003è', 'total': 1}
# {'_id': '2005è', 'total': 2}
# {'_id': '2006è', 'total': 1}
# {'_id': '2006è2007', 'total': 1}
# {'_id': '2006è2012', 'total': 2}
# {'_id': '2007è', 'total': 3}
# {'_id': '2009è', 'total': 2}
# {'_id': '2010è', 'total': 4}
# {'_id': '2011è', 'total': 2}
# {'_id': '2012è', 'total': 3}
# {'_id': '2014è', 'total': 2}

# %% [markdown]
# ## 2. Encuentra la calificación promedio de IMDb para películas en cada género

# %%
result = db.movies.aggregate([
    { '$unwind': '$genres' },
    { '$group': { '_id': '$genres', 'avg_imdb': { '$avg': '$imdb.rating' } } },
    { '$sort': { 'avg_imdb': -1 } }
])
for doc in result:
    print(doc)
# Out:
# {'_id': 'Film-Noir', 'avg_imdb': 7.397402597402598}
# {'_id': 'Short', 'avg_imdb': 7.377574370709382}
# {'_id': 'Documentary', 'avg_imdb': 7.365679824561403}
# {'_id': 'News', 'avg_imdb': 7.252272727272728}
# {'_id': 'History', 'avg_imdb': 7.1696100917431185}
# {'_id': 'War', 'avg_imdb': 7.128591954022989}
# {'_id': 'Biography', 'avg_imdb': 7.087984189723319}
# {'_id': 'Talk-Show', 'avg_imdb': 7.0}
# {'_id': 'Animation', 'avg_imdb': 6.89669603524229}
# {'_id': 'Music', 'avg_imdb': 6.883333333333334}
# {'_id': 'Western', 'avg_imdb': 6.823553719008264}
# {'_id': 'Drama', 'avg_imdb': 6.803377338624768}
# {'_id': 'Sport', 'avg_imdb': 6.749041095890411}
# {'_id': 'Crime', 'avg_imdb': 6.688585405625764}
# {'_id': 'Musical', 'avg_imdb': 6.665831435079727}
# {'_id': 'Romance', 'avg_imdb': 6.6564272782136396}
# {'_id': 'Mystery', 'avg_imdb': 6.527425044091711}
# {'_id': 'Adventure', 'avg_imdb': 6.493680884676145}
# {'_id': 'Comedy', 'avg_imdb': 6.450214658080344}
# {'_id': 'Fantasy', 'avg_imdb': 6.3829847908745245}
# {'_id': 'Action', 'avg_imdb': 6.347098402018503}
# {'_id': 'Family', 'avg_imdb': 6.3296712109061755}
# {'_id': 'Thriller', 'avg_imdb': 6.304498977505112}
# {'_id': 'Sci-Fi', 'avg_imdb': 6.123609653725079}
# {'_id': 'Horror', 'avg_imdb': 5.784709897610922}

# %% [markdown]
# ## 3. Lista las 5 películas con la calificación IMDb más alta

# %%
result = db.movies.find({ 'imdb.rating': { '$type': 'number' } }, { 'title': 1, 'imdb.rating': 1 }).sort('imdb.rating', -1).limit(5)
for doc in result:
    print(doc)
# Out:
# {'_id': ObjectId('573a139ff29313caabd003c4'), 'title': 'Band of Brothers', 'imdb': {'rating': 9.6}}
# {'_id': ObjectId('573a13b8f29313caabd4c241'), 'title': 'Planet Earth', 'imdb': {'rating': 9.5}}
# {'_id': ObjectId('573a13f0f29313caabdda542'), 'title': 'A Brave Heart: The Lizzie Velasquez Story', 'imdb': {'rating': 9.4}}
# {'_id': ObjectId('573a13a3f29313caabd0e77b'), 'title': 'The Civil War', 'imdb': {'rating': 9.4}}
# {'_id': ObjectId('573a1398f29313caabcebc0b'), 'title': 'The Civil War', 'imdb': {'rating': 9.4}}

# %% [markdown]
# ## 4. Determina el número total de películas y la duración promedio para cada director

# %%
result = db.movies.aggregate([
    { '$group': {
        '_id': '$directors',
        'total_peliculas': { '$sum': 1 },
        'duracion_promedio': { '$avg': '$runtime' }
    } },
    { '$sort': { 'total_peliculas': -1 } }
])
for doc in result:
    print(doc)
# Out:
# {'_id': None, 'total_peliculas': 242, 'duracion_promedio': 228.4834123222749}
# {'_id': ['Woody Allen'], 'total_peliculas': 39, 'duracion_promedio': 95.35897435897436}
# {'_id': ['Takashi Miike'], 'total_peliculas': 30, 'duracion_promedio': 116.7}
# {'_id': ['Martin Scorsese'], 'total_peliculas': 29, 'duracion_promedio': 138.17241379310346}
# {'_id': ['Sidney Lumet'], 'total_peliculas': 28, 'duracion_promedio': 122.03571428571429}
# {'_id': ['Steven Spielberg'], 'total_peliculas': 28, 'duracion_promedio': 134.82142857142858}
# {'_id': ['Clint Eastwood'], 'total_peliculas': 27, 'duracion_promedio': 130.77777777777777}
# {'_id': ['Michael Apted'], 'total_peliculas': 27, 'duracion_promedio': 109.88461538461539}
# {'_id': ['Robert Altman'], 'total_peliculas': 26, 'duracion_promedio': 120.73076923076923}
# {'_id': ['Spike Lee'], 'total_peliculas': 25, 'duracion_promedio': 126.96}
# {'_id': ['John Ford'], 'total_peliculas': 24, 'duracion_promedio': 107.0}
# {'_id': ['Ridley Scott'], 'total_peliculas': 24, 'duracion_promedio': 128.625}
# {'_id': ['Alfred Hitchcock'], 'total_peliculas': 24, 'duracion_promedio': 111.04166666666667}
# {'_id': ['Joseph Sargent'], 'total_peliculas': 23, 'duracion_promedio': 113.56521739130434}
# {'_id': ['Steven Soderbergh'], 'total_peliculas': 23, 'duracion_promedio': 105.04347826086956}
# {'_id': ['Wim Wenders'], 'total_peliculas': 23, 'duracion_promedio': 119.69565217391305}
# {'_id': ['Michael Winterbottom'], 'total_peliculas': 22, 'duracion_promedio': 101.9090909090909}
# {'_id': ['Norman Jewison'], 'total_peliculas': 22, 'duracion_promedio': 117.4090909090909}
# {'_id': ['Stephen Frears'], 'total_peliculas': 22, 'duracion_promedio': 98.63636363636364}
# {'_id': ['Brian De Palma'], 'total_peliculas': 21, 'duracion_promedio': 110.57142857142857}
# {'_id': ['Ron Howard'], 'total_peliculas': 21, 'duracion_promedio': 125.9}
# {'_id': ['Francis Ford Coppola'], 'total_peliculas': 21, 'duracion_promedio': 124.71428571428571}
# {'_id': ['Mario Monicelli'], 'total_peliculas': 21, 'duracion_promedio': 113.80952380952381}
# {'_id': ['George Cukor'], 'total_peliculas': 20, 'duracion_promedio': 112.15}
# {'_id': ['Joel Schumacher'], 'total_peliculas': 20, 'duracion_promedio': 108.85}
# {'_id': ['Blake Edwards'], 'total_peliculas': 19, 'duracion_promedio': 112.89473684210526}
# {'_id': ['Tim Burton'], 'total_peliculas': 19, 'duracion_promedio': 101.10526315789474}
# {'_id': ['Carlo Verdone'], 'total_peliculas': 19, 'duracion_promedio': 111.6842105263158}
# {'_id': ['Oliver Stone'], 'total_peliculas': 19, 'duracion_promedio': 137.26315789473685}
# {'_id': ['Claude Chabrol'], 'total_peliculas': 19, 'duracion_promedio': 108.3157894736842}
# {'_id': ['Eric Rohmer'], 'total_peliculas': 19, 'duracion_promedio': 106.73684210526316}
# {'_id': ['John Huston'], 'total_peliculas': 19, 'duracion_promedio': 103.63157894736842}
# {'_id': ['Barry Levinson'], 'total_peliculas': 19, 'duracion_promedio': 120.21052631578948}
# {'_id': ['Bruce Beresford'], 'total_peliculas': 18, 'duracion_promedio': 104.0}
# {'_id': ['John Carpenter'], 'total_peliculas': 18, 'duracion_promedio': 102.05555555555556}
# {'_id': ['Ingmar Bergman'], 'total_peliculas': 18, 'duracion_promedio': 106.61111111111111}
# {'_id': ['Carlos Saura'], 'total_peliculas': 18, 'duracion_promedio': 101.0}
# {'_id': ['John Frankenheimer'], 'total_peliculas': 18, 'duracion_promedio': 126.27777777777777}
# {'_id': ['William Wyler'], 'total_peliculas': 18, 'duracion_promedio': 120.55555555555556}
# {'_id': ['Mike Nichols'], 'total_peliculas': 18, 'duracion_promedio': 111.94444444444444}
# {'_id': ['Robert Wise'], 'total_peliculas': 18, 'duracion_promedio': 116.83333333333333}
# {'_id': ['Wes Craven'], 'total_peliculas': 18, 'duracion_promedio': 105.33333333333333}
# {'_id': ['David Cronenberg'], 'total_peliculas': 17, 'duracion_promedio': 100.05882352941177}
# {'_id': ['Mark Robson'], 'total_peliculas': 17, 'duracion_promedio': 106.52941176470588}
# {'_id': ['Renny Harlin'], 'total_peliculas': 17, 'duracion_promedio': 107.58823529411765}
# {'_id': ['Werner Herzog'], 'total_peliculas': 17, 'duracion_promedio': 100.82352941176471}
# {'_id': ['Vincente Minnelli'], 'total_peliculas': 17, 'duracion_promedio': 114.3529411764706}
# {'_id': ['Hark Tsui'], 'total_peliculas': 17, 'duracion_promedio': 116.94117647058823}
# {'_id': ['Hayao Miyazaki'], 'total_peliculas': 17, 'duracion_promedio': 114.0}
# {'_id': ['Ken Loach'], 'total_peliculas': 17, 'duracion_promedio': 105.52941176470588}
# {'_id': ['Herbert Ross'], 'total_peliculas': 17, 'duracion_promedio': 111.94117647058823}
# {'_id': ['Jan Troell'], 'total_peliculas': 17, 'duracion_promedio': 129.23529411764707}
# {'_id': ['Robert Zemeckis'], 'total_peliculas': 16, 'duracion_promedio': 120.375}
# {'_id': ['Paul Schrader'], 'total_peliculas': 16, 'duracion_promedio': 109.1875}
# {'_id': ['William Friedkin'], 'total_peliculas': 16, 'duracion_promedio': 108.8125}
# {'_id': ['Kiyoshi Kurosawa'], 'total_peliculas': 16, 'duracion_promedio': 109.4375}
# {'_id': ['Yimou Zhang'], 'total_peliculas': 16, 'duracion_promedio': 110.625}
# {'_id': ['Jonathan Demme'], 'total_peliculas': 16, 'duracion_promedio': 109.5}
# {'_id': ['Tony Scott'], 'total_peliculas': 16, 'duracion_promedio': 108.8125}
# {'_id': ['Rainer Werner Fassbinder'], 'total_peliculas': 15, 'duracion_promedio': 108.73333333333333}
# {'_id': ['Luis Buèuel'], 'total_peliculas': 15, 'duracion_promedio': 92.8}
# {'_id': ['Ki-duk Kim'], 'total_peliculas': 15, 'duracion_promedio': 95.13333333333334}
# {'_id': ['James Ivory'], 'total_peliculas': 15, 'duracion_promedio': 123.66666666666667}
# {'_id': ['Andrey Konchalovskiy'], 'total_peliculas': 15, 'duracion_promedio': 116.46666666666667}
# {'_id': ['Gus Van Sant'], 'total_peliculas': 15, 'duracion_promedio': 105.0}
# {'_id': ['Pupi Avati'], 'total_peliculas': 15, 'duracion_promedio': 105.46666666666667}
# {'_id': ['Bertrand Tavernier'], 'total_peliculas': 15, 'duracion_promedio': 124.86666666666666}
# {'_id': ['Chris Columbus'], 'total_peliculas': 15, 'duracion_promedio': 119.86666666666666}
# {'_id': ['Takeshi Kitano'], 'total_peliculas': 15, 'duracion_promedio': 109.2}
# {'_id': ['Mike Newell'], 'total_peliculas': 15, 'duracion_promedio': 115.73333333333333}
# {'_id': ['Richard Fleischer'], 'total_peliculas': 15, 'duracion_promedio': 108.53333333333333}
# {'_id': ['Richard Linklater'], 'total_peliculas': 15, 'duracion_promedio': 107.93333333333334}
# {'_id': ['Arthur Hiller'], 'total_peliculas': 15, 'duracion_promedio': 106.6}
# {'_id': ['Tyler Perry'], 'total_peliculas': 15, 'duracion_promedio': 110.2}
# {'_id': ['Martin Ritt'], 'total_peliculas': 15, 'duracion_promedio': 106.06666666666666}
# {'_id': ['Alain Resnais'], 'total_peliculas': 15, 'duracion_promedio': 124.13333333333334}
# {'_id': ['Lasse Hallstrèm'], 'total_peliculas': 15, 'duracion_promedio': 115.2}
# {'_id': ['John Schlesinger'], 'total_peliculas': 15, 'duracion_promedio': 116.93333333333334}
# {'_id': ['Dino Risi'], 'total_peliculas': 14, 'duracion_promedio': 104.57142857142857}
# {'_id': ['Richard Brooks'], 'total_peliculas': 14, 'duracion_promedio': 121.35714285714286}
# {'_id': ['Sang-soo Hong'], 'total_peliculas': 14, 'duracion_promedio': 104.14285714285714}
# {'_id': ['Neil Jordan'], 'total_peliculas': 14, 'duracion_promedio': 111.85714285714286}
# {'_id': ['Kenneth Branagh'], 'total_peliculas': 14, 'duracion_promedio': 120.42857142857143}
# {'_id': ['Satyajit Ray'], 'total_peliculas': 14, 'duracion_promedio': 108.92857142857143}
# {'_id': ['John Sayles'], 'total_peliculas': 14, 'duracion_promedio': 124.14285714285714}
# {'_id': ['John Woo'], 'total_peliculas': 14, 'duracion_promedio': 113.14285714285714}
# {'_id': ['Ettore Scola'], 'total_peliculas': 14, 'duracion_promedio': 116.5}
# {'_id': ['Michael Mann'], 'total_peliculas': 14, 'duracion_promedio': 133.64285714285714}
# {'_id': ['Francesco Rosi'], 'total_peliculas': 14, 'duracion_promedio': 111.0}
# {'_id': ['Mervyn LeRoy'], 'total_peliculas': 14, 'duracion_promedio': 120.0}
# {'_id': ['Ivan Reitman'], 'total_peliculas': 14, 'duracion_promedio': 103.78571428571429}
# {'_id': ['Sydney Pollack'], 'total_peliculas': 14, 'duracion_promedio': 124.21428571428571}
# {'_id': ['Billy Wilder'], 'total_peliculas': 14, 'duracion_promedio': 117.78571428571429}
# {'_id': ['Rob Reiner'], 'total_peliculas': 14, 'duracion_promedio': 101.85714285714286}
# {'_id': ['Gabriele Salvatores'], 'total_peliculas': 14, 'duracion_promedio': 100.71428571428571}
# {'_id': ['Hsiao-hsien Hou'], 'total_peliculas': 14, 'duracion_promedio': 114.5}
# {'_id': ['Bille August'], 'total_peliculas': 14, 'duracion_promedio': 125.57142857142857}
# {'_id': ['Elia Kazan'], 'total_peliculas': 14, 'duracion_promedio': 115.71428571428571}
# {'_id': ['Richard Donner'], 'total_peliculas': 14, 'duracion_promedio': 118.57142857142857}
# {'_id': ['Garry Marshall'], 'total_peliculas': 14, 'duracion_promedio': 117.14285714285714}
# {'_id': ['Atom Egoyan'], 'total_peliculas': 14, 'duracion_promedio': 100.14285714285714}
# {'_id': ['Johnnie To'], 'total_peliculas': 14, 'duracion_promedio': 98.71428571428571}
# {'_id': ['Phillip Noyce'], 'total_peliculas': 14, 'duracion_promedio': 106.35714285714286}
# {'_id': ['Alan Rudolph'], 'total_peliculas': 13, 'duracion_promedio': 107.76923076923077}
# {'_id': ['Robert Mulligan'], 'total_peliculas': 13, 'duracion_promedio': 110.61538461538461}
# {'_id': ['Roman Polanski'], 'total_peliculas': 13, 'duracion_promedio': 130.92307692307693}
# {'_id': ['Mauro Bolognini'], 'total_peliculas': 13, 'duracion_promedio': 100.07692307692308}
# {'_id': ['Simon Wincer'], 'total_peliculas': 13, 'duracion_promedio': 101.6923076923077}
# {'_id': ['Joe Dante'], 'total_peliculas': 13, 'duracion_promedio': 100.38461538461539}
# {'_id': ['Robert Rodriguez'], 'total_peliculas': 13, 'duracion_promedio': 95.6923076923077}
# {'_id': ['Andrzej Wajda'], 'total_peliculas': 13, 'duracion_promedio': 136.30769230769232}
# {'_id': ['Roger Spottiswoode'], 'total_peliculas': 13, 'duracion_promedio': 110.07692307692308}
# {'_id': ['Sean McNamara'], 'total_peliculas': 13, 'duracion_promedio': 99.0}
# {'_id': ['Taylor Hackford'], 'total_peliculas': 13, 'duracion_promedio': 133.07692307692307}
# {'_id': ['Mike Leigh'], 'total_peliculas': 13, 'duracion_promedio': 112.6923076923077}
# {'_id': ['Henry Koster'], 'total_peliculas': 13, 'duracion_promedio': 101.46153846153847}
# {'_id': ['Ming-liang Tsai'], 'total_peliculas': 13, 'duracion_promedio': 101.38461538461539}
# {'_id': ['Alan Parker'], 'total_peliculas': 13, 'duracion_promedio': 123.0}
# {'_id': ['Peter Weir'], 'total_peliculas': 13, 'duracion_promedio': 114.84615384615384}
# {'_id': ['Luc Besson'], 'total_peliculas': 13, 'duracion_promedio': 115.3076923076923}
# {'_id': ['John Boorman'], 'total_peliculas': 13, 'duracion_promedio': 112.0}
# {'_id': ['Louis Malle'], 'total_peliculas': 13, 'duracion_promedio': 111.23076923076923}
# {'_id': ['Henry King'], 'total_peliculas': 13, 'duracion_promedio': 113.46153846153847}
# {'_id': ['Andrè Tèchinè'], 'total_peliculas': 13, 'duracion_promedio': 106.92307692307692}
# {'_id': ['Mika Kaurismèki'], 'total_peliculas': 12, 'duracion_promedio': 89.16666666666667}
# {'_id': ['John G. Avildsen'], 'total_peliculas': 12, 'duracion_promedio': 108.25}
# {'_id': ['Bob Clark'], 'total_peliculas': 12, 'duracion_promedio': 101.41666666666667}
# {'_id': ['Peter Jackson'], 'total_peliculas': 12, 'duracion_promedio': 147.0}
# {'_id': ['Aleksandr Sokurov'], 'total_peliculas': 12, 'duracion_promedio': 87.0}
# {'_id': ['Orson Welles'], 'total_peliculas': 12, 'duracion_promedio': 87.5}
# {'_id': ['George Roy Hill'], 'total_peliculas': 12, 'duracion_promedio': 123.08333333333333}
# {'_id': ['Michael Curtiz'], 'total_peliculas': 12, 'duracion_promedio': 109.25}
# {'_id': ['Federico Fellini'], 'total_peliculas': 12, 'duracion_promedio': 117.08333333333333}
# {'_id': ['Dennis Dugan'], 'total_peliculas': 12, 'duracion_promedio': 99.16666666666667}
# {'_id': ['Volker Schlèndorff'], 'total_peliculas': 12, 'duracion_promedio': 109.5}
# {'_id': ['Luchino Visconti'], 'total_peliculas': 12, 'duracion_promedio': 145.25}
# {'_id': ['Jim Jarmusch'], 'total_peliculas': 12, 'duracion_promedio': 107.75}
# {'_id': ['Franèois Truffaut'], 'total_peliculas': 12, 'duracion_promedio': 103.58333333333333}
# {'_id': ['Patrice Leconte'], 'total_peliculas': 12, 'duracion_promedio': 93.16666666666667}
# {'_id': ['Pedro Almodèvar'], 'total_peliculas': 12, 'duracion_promedio': 107.83333333333333}
# {'_id': ['Charles Walters'], 'total_peliculas': 12, 'duracion_promedio': 106.91666666666667}
# {'_id': ['John Landis'], 'total_peliculas': 12, 'duracion_promedio': 103.41666666666667}
# {'_id': ['Roger Donaldson'], 'total_peliculas': 12, 'duracion_promedio': 115.16666666666667}
# {'_id': ['Mani Ratnam'], 'total_peliculas': 12, 'duracion_promedio': 145.9}
# {'_id': ['James Mangold'], 'total_peliculas': 12, 'duracion_promedio': 112.5}
# {'_id': ['Shawn Levy'], 'total_peliculas': 12, 'duracion_promedio': 101.83333333333333}
# {'_id': ['Edward Dmytryk'], 'total_peliculas': 12, 'duracion_promedio': 121.16666666666667}
# {'_id': ['Vittorio De Sica'], 'total_peliculas': 12, 'duracion_promedio': 102.33333333333333}
# {'_id': ['Marco Ferreri'], 'total_peliculas': 12, 'duracion_promedio': 100.25}
# {'_id': ['Roland Emmerich'], 'total_peliculas': 11, 'duracion_promedio': 126.36363636363636}
# {'_id': ['Kar Wai Wong'], 'total_peliculas': 11, 'duracion_promedio': 104.0}
# {'_id': ['Steve Barron'], 'total_peliculas': 11, 'duracion_promedio': 98.27272727272727}
# {'_id': ['Franèois Ozon'], 'total_peliculas': 11, 'duracion_promedio': 99.0909090909091}
# {'_id': ['Paul Mazursky'], 'total_peliculas': 11, 'duracion_promedio': 113.45454545454545}
# {'_id': ['Henry Hathaway'], 'total_peliculas': 11, 'duracion_promedio': 113.36363636363636}
# {'_id': ['Benny Chan'], 'total_peliculas': 11, 'duracion_promedio': 118.63636363636364}
# {'_id': ['Theodoros Angelopoulos'], 'total_peliculas': 11, 'duracion_promedio': 153.63636363636363}
# {'_id': ['Michael Ritchie'], 'total_peliculas': 11, 'duracion_promedio': 102.63636363636364}
# {'_id': ['George Stevens'], 'total_peliculas': 11, 'duracion_promedio': 125.45454545454545}
# {'_id': ['Mark Rydell'], 'total_peliculas': 11, 'duracion_promedio': 117.54545454545455}
# {'_id': ['Howard Hawks'], 'total_peliculas': 11, 'duracion_promedio': 114.9090909090909}
# {'_id': ['Sam Raimi'], 'total_peliculas': 11, 'duracion_promedio': 115.36363636363636}
# {'_id': ['Jean-Jacques Annaud'], 'total_peliculas': 11, 'duracion_promedio': 113.36363636363636}
# {'_id': ['Miklès Jancsè'], 'total_peliculas': 11, 'duracion_promedio': 92.0909090909091}
# {'_id': ['Juliusz Machulski'], 'total_peliculas': 11, 'duracion_promedio': 109.36363636363636}
# {'_id': ['Ang Lee'], 'total_peliculas': 11, 'duracion_promedio': 112.45454545454545}
# {'_id': ['Agnieszka Holland'], 'total_peliculas': 11, 'duracion_promedio': 107.36363636363636}
# {'_id': ['Jerzy Skolimowski'], 'total_peliculas': 11, 'duracion_promedio': 86.72727272727273}
# {'_id': ['Damiano Damiani'], 'total_peliculas': 11, 'duracion_promedio': 107.5}
# {'_id': ['Jacques Rivette'], 'total_peliculas': 11, 'duracion_promedio': 161.9090909090909}
# {'_id': ['Joel Coen', 'Ethan Coen'], 'total_peliculas': 11, 'duracion_promedio': 107.0909090909091}
# {'_id': ['Jon Turteltaub'], 'total_peliculas': 11, 'duracion_promedio': 112.0909090909091}
# {'_id': ['Peter Bogdanovich'], 'total_peliculas': 11, 'duracion_promedio': 120.63636363636364}
# {'_id': ['Robert Vince'], 'total_peliculas': 11, 'duracion_promedio': 88.18181818181819}
# {'_id': ['Alan J. Pakula'], 'total_peliculas': 11, 'duracion_promedio': 119.72727272727273}
# {'_id': ['Frank Oz'], 'total_peliculas': 11, 'duracion_promedio': 98.54545454545455}
# {'_id': ['èlex de la Iglesia'], 'total_peliculas': 11, 'duracion_promedio': 106.54545454545455}
# {'_id': ['Paul W.S. Anderson'], 'total_peliculas': 11, 'duracion_promedio': 99.72727272727273}
# {'_id': ['J. Lee Thompson'], 'total_peliculas': 11, 'duracion_promedio': 113.54545454545455}
# {'_id': ['Franco Zeffirelli'], 'total_peliculas': 11, 'duracion_promedio': 120.0}
# {'_id': ['Michael Bay'], 'total_peliculas': 11, 'duracion_promedio': 146.63636363636363}
# {'_id': ['Bryan Singer'], 'total_peliculas': 11, 'duracion_promedio': 117.0}
# {'_id': ['Jack Gold'], 'total_peliculas': 11, 'duracion_promedio': 115.18181818181819}
# {'_id': ['Martin Campbell'], 'total_peliculas': 11, 'duracion_promedio': 122.9090909090909}
# {'_id': ["Shin'ya Tsukamoto"], 'total_peliculas': 11, 'duracion_promedio': 82.54545454545455}
# {'_id': ['Costa-Gavras'], 'total_peliculas': 11, 'duracion_promedio': 114.0909090909091}
# {'_id': ['Richard Attenborough'], 'total_peliculas': 11, 'duracion_promedio': 137.8181818181818}
# {'_id': ['Ted Kotcheff'], 'total_peliculas': 11, 'duracion_promedio': 107.9090909090909}
# {'_id': ['Stephen Herek'], 'total_peliculas': 11, 'duracion_promedio': 104.54545454545455}
# {'_id': ['Fred Zinnemann'], 'total_peliculas': 11, 'duracion_promedio': 107.72727272727273}
# {'_id': ['Abel Ferrara'], 'total_peliculas': 11, 'duracion_promedio': 92.0}
# {'_id': ['Aleksi Mèkelè'], 'total_peliculas': 11, 'duracion_promedio': 104.0}
# {'_id': ['Edward Zwick'], 'total_peliculas': 10, 'duracion_promedio': 124.9}
# {'_id': ['Wayne Wang'], 'total_peliculas': 10, 'duracion_promedio': 105.5}
# {'_id': ['Joseph Losey'], 'total_peliculas': 10, 'duracion_promedio': 113.6}
# {'_id': ['Uli Edel'], 'total_peliculas': 10, 'duracion_promedio': 133.2}
# {'_id': ['Walter Lang'], 'total_peliculas': 10, 'duracion_promedio': 107.6}
# {'_id': ['Alex Gibney'], 'total_peliculas': 10, 'duracion_promedio': 114.0}
# {'_id': ['Michael Anderson'], 'total_peliculas': 10, 'duracion_promedio': 118.2}
# {'_id': ['Brian Levant'], 'total_peliculas': 10, 'duracion_promedio': 94.0}
# {'_id': ['Kevin Smith'], 'total_peliculas': 10, 'duracion_promedio': 103.6}
# {'_id': ['Bobby Farrelly', 'Peter Farrelly'], 'total_peliculas': 10, 'duracion_promedio': 110.2}
# {'_id': ['Howard Deutch'], 'total_peliculas': 10, 'duracion_promedio': 103.6}
# {'_id': ['Danny Boyle'], 'total_peliculas': 10, 'duracion_promedio': 99.7}
# {'_id': ['Benoèt Jacquot'], 'total_peliculas': 10, 'duracion_promedio': 96.2}
# {'_id': ['Robert Harmon'], 'total_peliculas': 10, 'duracion_promedio': 95.5}
# {'_id': ['Frank Capra'], 'total_peliculas': 10, 'duracion_promedio': 106.4}
# {'_id': ['Sam Peckinpah'], 'total_peliculas': 10, 'duracion_promedio': 115.5}
# {'_id': ['Delbert Mann'], 'total_peliculas': 10, 'duracion_promedio': 106.3}
# {'_id': ['Raoul Ruiz'], 'total_peliculas': 10, 'duracion_promedio': 134.2}
# {'_id': ['Francis Veber'], 'total_peliculas': 10, 'duracion_promedio': 89.1}
# {'_id': ['Peter Hyams'], 'total_peliculas': 10, 'duracion_promedio': 109.4}
# {'_id': ['Bernardo Bertolucci'], 'total_peliculas': 10, 'duracion_promedio': 141.3}
# {'_id': ['Curtis Hanson'], 'total_peliculas': 10, 'duracion_promedio': 112.7}
# {'_id': ['Jean-Luc Godard'], 'total_peliculas': 10, 'duracion_promedio': 88.9}
# {'_id': ['Brett Ratner'], 'total_peliculas': 10, 'duracion_promedio': 102.8}
# {'_id': ['Stanley Kramer'], 'total_peliculas': 10, 'duracion_promedio': 133.5}
# {'_id': ['Abbas Alibhai Burmawalla', 'Mastan Alibhai Burmawalla'], 'total_peliculas': 10, 'duracion_promedio': 162.5}
# {'_id': ['Nikita Mikhalkov'], 'total_peliculas': 10, 'duracion_promedio': 134.7}
# {'_id': ['Hal Ashby'], 'total_peliculas': 10, 'duracion_promedio': 113.5}
# {'_id': ['Glenn Jordan'], 'total_peliculas': 10, 'duracion_promedio': 111.0}
# {'_id': ['Richard Benjamin'], 'total_peliculas': 10, 'duracion_promedio': 104.1}
# {'_id': ['Brian Robbins'], 'total_peliculas': 10, 'duracion_promedio': 99.1}
# {'_id': ['Stuart Gordon'], 'total_peliculas': 10, 'duracion_promedio': 87.7}
# {'_id': ['Ken Russell'], 'total_peliculas': 10, 'duracion_promedio': 112.4}
# {'_id': ['Richard Lester'], 'total_peliculas': 10, 'duracion_promedio': 98.7}
# {'_id': ['Rob Cohen'], 'total_peliculas': 10, 'duracion_promedio': 109.8}
# {'_id': ['Milos Forman'], 'total_peliculas': 10, 'duracion_promedio': 124.4}
# {'_id': ['Manoel de Oliveira'], 'total_peliculas': 10, 'duracion_promedio': 101.3}
# {'_id': ['Fred Schepisi'], 'total_peliculas': 10, 'duracion_promedio': 112.6}
# {'_id': ['Yèji Yamada'], 'total_peliculas': 10, 'duracion_promedio': 121.2}
# {'_id': ['Otto Preminger'], 'total_peliculas': 10, 'duracion_promedio': 127.9}
# {'_id': ['Roger Michell'], 'total_peliculas': 10, 'duracion_promedio': 103.0}
# {'_id': ['George Miller'], 'total_peliculas': 10, 'duracion_promedio': 103.44444444444444}
# {'_id': ['Martha Coolidge'], 'total_peliculas': 10, 'duracion_promedio': 109.5}
# {'_id': ['Wolfgang Petersen'], 'total_peliculas': 10, 'duracion_promedio': 122.7}
# {'_id': ['Luigi Comencini'], 'total_peliculas': 10, 'duracion_promedio': 106.3}
# {'_id': ['Paolo Taviani', 'Vittorio Taviani'], 'total_peliculas': 10, 'duracion_promedio': 114.3}
# {'_id': ['Ferzan Ozpetek'], 'total_peliculas': 10, 'duracion_promedio': 108.2}
# {'_id': ['Jim Sheridan'], 'total_peliculas': 10, 'duracion_promedio': 109.3}
# {'_id': ['David Fincher'], 'total_peliculas': 10, 'duracion_promedio': 137.1}
# {'_id': ['Peter Yates'], 'total_peliculas': 10, 'duracion_promedio': 111.7}
# {'_id': ['Michael Haneke'], 'total_peliculas': 10, 'duracion_promedio': 122.5}
# {'_id': ['Robert Aldrich'], 'total_peliculas': 10, 'duracion_promedio': 118.9}
# {'_id': ['Terry Gilliam'], 'total_peliculas': 10, 'duracion_promedio': 122.0}
# {'_id': ['Mira Nair'], 'total_peliculas': 10, 'duracion_promedio': 115.7}
# {'_id': ['Paul Greengrass'], 'total_peliculas': 9, 'duracion_promedio': 110.44444444444444}
# {'_id': ['Bob Rafelson'], 'total_peliculas': 9, 'duracion_promedio': 107.22222222222223}
# {'_id': ['Bryan Forbes'], 'total_peliculas': 9, 'duracion_promedio': 116.11111111111111}
# {'_id': ['Gianni Amelio'], 'total_peliculas': 9, 'duracion_promedio': 110.11111111111111}
# {'_id': ['Ram Gopal Varma'], 'total_peliculas': 9, 'duracion_promedio': 132.55555555555554}
# {'_id': ['Carol Reed'], 'total_peliculas': 9, 'duracion_promedio': 111.0}
# {'_id': ['Peter Greenaway'], 'total_peliculas': 9, 'duracion_promedio': 130.0}
# {'_id': ['Marc Forster'], 'total_peliculas': 9, 'duracion_promedio': 108.0}
# {'_id': ['Tony Richardson'], 'total_peliculas': 9, 'duracion_promedio': 114.55555555555556}
# {'_id': ['Oxide Pang Chun', 'Danny Pang'], 'total_peliculas': 9, 'duracion_promedio': 98.66666666666667}
# {'_id': ['M. Night Shyamalan'], 'total_peliculas': 9, 'duracion_promedio': 102.11111111111111}
# {'_id': ['Clarence Brown'], 'total_peliculas': 9, 'duracion_promedio': 100.77777777777777}
# {'_id': ['Russell Mulcahy'], 'total_peliculas': 9, 'duracion_promedio': 114.0}
# {'_id': ['John Sturges'], 'total_peliculas': 9, 'duracion_promedio': 119.11111111111111}
# {'_id': ['Adrian Lyne'], 'total_peliculas': 9, 'duracion_promedio': 115.66666666666667}
# {'_id': ['John McTiernan'], 'total_peliculas': 9, 'duracion_promedio': 116.55555555555556}
# {'_id': ['Peter Medak'], 'total_peliculas': 9, 'duracion_promedio': 121.88888888888889}
# {'_id': ['Christopher Nolan'], 'total_peliculas': 9, 'duracion_promedio': 133.77777777777777}
# {'_id': ['Krzysztof Zanussi'], 'total_peliculas': 9, 'duracion_promedio': 97.22222222222223}
# {'_id': ['Raja Gosnell'], 'total_peliculas': 9, 'duracion_promedio': 97.33333333333333}
# {'_id': ['Hal Hartley'], 'total_peliculas': 9, 'duracion_promedio': 100.11111111111111}
# {'_id': ['Nicolas Roeg'], 'total_peliculas': 9, 'duracion_promedio': 107.55555555555556}
# {'_id': ['Krzysztof Kieslowski'], 'total_peliculas': 9, 'duracion_promedio': 81.66666666666667}
# {'_id': ['Mohsen Makhmalbaf'], 'total_peliculas': 9, 'duracion_promedio': 85.11111111111111}
# {'_id': ['Jay Roach'], 'total_peliculas': 9, 'duracion_promedio': 103.77777777777777}
# {'_id': ['Kaige Chen'], 'total_peliculas': 9, 'duracion_promedio': 125.22222222222223}
# {'_id': ['Robert Redford'], 'total_peliculas': 9, 'duracion_promedio': 125.77777777777777}
# {'_id': ['Michael Hoffman'], 'total_peliculas': 9, 'duracion_promedio': 107.11111111111111}
# {'_id': ['Giuliano Montaldo'], 'total_peliculas': 9, 'duracion_promedio': 104.44444444444444}
# {'_id': ['Ronny Yu'], 'total_peliculas': 9, 'duracion_promedio': 94.66666666666667}
# {'_id': ['Wes Anderson'], 'total_peliculas': 9, 'duracion_promedio': 98.11111111111111}
# {'_id': ['Peter Chelsom'], 'total_peliculas': 9, 'duracion_promedio': 105.33333333333333}
# {'_id': ['Adam Shankman'], 'total_peliculas': 9, 'duracion_promedio': 104.66666666666667}
# {'_id': ['Cameron Crowe'], 'total_peliculas': 9, 'duracion_promedio': 118.5}
# {'_id': ['Giuseppe Tornatore'], 'total_peliculas': 9, 'duracion_promedio': 131.11111111111111}
# {'_id': ['Lawrence Kasdan'], 'total_peliculas': 9, 'duracion_promedio': 128.22222222222223}
# {'_id': ['Bertrand Blier'], 'total_peliculas': 9, 'duracion_promedio': 97.33333333333333}
# {'_id': ['David Gordon Green'], 'total_peliculas': 9, 'duracion_promedio': 102.77777777777777}
# {'_id': ['Betty Thomas'], 'total_peliculas': 9, 'duracion_promedio': 93.88888888888889}
# {'_id': ['SABU'], 'total_peliculas': 9, 'duracion_promedio': 95.875}
# {'_id': ['Tom McLoughlin'], 'total_peliculas': 9, 'duracion_promedio': 92.44444444444444}
# {'_id': ['Akira Kurosawa'], 'total_peliculas': 9, 'duracion_promedio': 126.77777777777777}
# {'_id': ['Roland Joffè'], 'total_peliculas': 9, 'duracion_promedio': 120.33333333333333}
# {'_id': ['Richard Loncraine'], 'total_peliculas': 9, 'duracion_promedio': 97.33333333333333}
# {'_id': ['Jan Svankmajer'], 'total_peliculas': 9, 'duracion_promedio': 65.44444444444444}
# {'_id': ['Aki Kaurismèki'], 'total_peliculas': 9, 'duracion_promedio': 81.55555555555556}
# {'_id': ['Steve Rash'], 'total_peliculas': 9, 'duracion_promedio': 98.66666666666667}
# {'_id': ['Robert Stevenson'], 'total_peliculas': 9, 'duracion_promedio': 106.88888888888889}
# {'_id': ['Rajkumar Santoshi'], 'total_peliculas': 9, 'duracion_promedio': 174.75}
# {'_id': ['Mel Brooks'], 'total_peliculas': 9, 'duracion_promedio': 94.77777777777777}
# {'_id': ['Isabel Coixet'], 'total_peliculas': 9, 'duracion_promedio': 102.44444444444444}
# {'_id': ['Uwe Boll'], 'total_peliculas': 9, 'duracion_promedio': 98.33333333333333}
# {'_id': ['Stuart Gillard'], 'total_peliculas': 9, 'duracion_promedio': 123.375}
# {'_id': ['Claude Miller'], 'total_peliculas': 9, 'duracion_promedio': 103.22222222222223}
# {'_id': ['Lone Scherfig'], 'total_peliculas': 9, 'duracion_promedio': 102.44444444444444}
# {'_id': ['James Foley'], 'total_peliculas': 9, 'duracion_promedio': 103.44444444444444}
# {'_id': ['Tobe Hooper'], 'total_peliculas': 9, 'duracion_promedio': 101.55555555555556}
# {'_id': ['Joe Johnston'], 'total_peliculas': 9, 'duracion_promedio': 106.66666666666667}
# {'_id': ['Walter Hill'], 'total_peliculas': 9, 'duracion_promedio': 97.88888888888889}
# {'_id': ['Guy Hamilton'], 'total_peliculas': 9, 'duracion_promedio': 117.22222222222223}
# {'_id': ['Elio Petri'], 'total_peliculas': 9, 'duracion_promedio': 106.11111111111111}
# {'_id': ['Robert Benton'], 'total_peliculas': 9, 'duracion_promedio': 100.0}
# {'_id': ['Ken Kwapis'], 'total_peliculas': 9, 'duracion_promedio': 103.33333333333333}
# {'_id': ['Aleksey Balabanov'], 'total_peliculas': 9, 'duracion_promedio': 103.22222222222223}
# {'_id': ['Neil LaBute'], 'total_peliculas': 9, 'duracion_promedio': 101.0}
# {'_id': ['Daniel Mann'], 'total_peliculas': 9, 'duracion_promedio': 107.55555555555556}
# {'_id': ['John Singleton'], 'total_peliculas': 9, 'duracion_promedio': 115.44444444444444}
# {'_id': ['Barbet Schroeder'], 'total_peliculas': 9, 'duracion_promedio': 107.22222222222223}
# {'_id': ['Emir Kusturica'], 'total_peliculas': 8, 'duracion_promedio': 129.875}
# {'_id': ['Kenneth Johnson'], 'total_peliculas': 8, 'duracion_promedio': 95.625}
# {'_id': ['Paul Verhoeven'], 'total_peliculas': 8, 'duracion_promedio': 125.125}
# {'_id': ['William Dear'], 'total_peliculas': 8, 'duracion_promedio': 97.71428571428571}
# {'_id': ['Chan-wook Park'], 'total_peliculas': 8, 'duracion_promedio': 118.5}
# {'_id': ['Susanne Bier'], 'total_peliculas': 8, 'duracion_promedio': 113.875}
# {'_id': ['Michel Gondry'], 'total_peliculas': 8, 'duracion_promedio': 100.875}
# {'_id': ['Todd Phillips'], 'total_peliculas': 8, 'duracion_promedio': 97.375}
# {'_id': ['David Lynch'], 'total_peliculas': 8, 'duracion_promedio': 136.125}
# {'_id': ['Guillermo del Toro'], 'total_peliculas': 8, 'duracion_promedio': 114.125}
# {'_id': ['Jon Amiel'], 'total_peliculas': 8, 'duracion_promedio': 112.14285714285714}
# {'_id': ['Shion Sono'], 'total_peliculas': 8, 'duracion_promedio': 124.0}
# {'_id': ['Tom Shadyac'], 'total_peliculas': 8, 'duracion_promedio': 96.125}
# {'_id': ['James Cameron'], 'total_peliculas': 8, 'duracion_promedio': 135.25}
# {'_id': ['Michelangelo Antonioni'], 'total_peliculas': 8, 'duracion_promedio': 111.375}
# {'_id': ['Sharunas Bartas'], 'total_peliculas': 8, 'duracion_promedio': 90.125}
# {'_id': ['Sidney J. Furie'], 'total_peliculas': 8, 'duracion_promedio': 113.0}
# {'_id': ['Stephen Hopkins'], 'total_peliculas': 8, 'duracion_promedio': 118.375}
# {'_id': ['Errol Morris'], 'total_peliculas': 8, 'duracion_promedio': 92.875}
# {'_id': ['Philip Kaufman'], 'total_peliculas': 8, 'duracion_promedio': 134.375}
# {'_id': ['Quentin Tarantino'], 'total_peliculas': 8, 'duracion_promedio': 137.25}
# {'_id': ['George Sidney'], 'total_peliculas': 8, 'duracion_promedio': 110.25}
# {'_id': ['Julien Duvivier'], 'total_peliculas': 8, 'duracion_promedio': 98.5}
# {'_id': ['Lewis Gilbert'], 'total_peliculas': 8, 'duracion_promedio': 113.125}
# {'_id': ['Olivier Assayas'], 'total_peliculas': 8, 'duracion_promedio': 120.25}
# {'_id': ['Tung-Shing Yee'], 'total_peliculas': 8, 'duracion_promedio': 111.5}
# {'_id': ['Sammo Kam-Bo Hung'], 'total_peliculas': 8, 'duracion_promedio': 98.375}
# {'_id': ['Joseph Ruben'], 'total_peliculas': 8, 'duracion_promedio': 99.25}
# {'_id': ['Ole Bornedal'], 'total_peliculas': 8, 'duracion_promedio': 105.375}
# {'_id': ['Stanley Kubrick'], 'total_peliculas': 8, 'duracion_promedio': 143.125}
# {'_id': ['Wilson Yip'], 'total_peliculas': 8, 'duracion_promedio': 96.125}
# {'_id': ['Luis Mandoki'], 'total_peliculas': 8, 'duracion_promedio': 113.5}
# {'_id': ['Tony Gatlif'], 'total_peliculas': 8, 'duracion_promedio': 96.625}
# {'_id': ['Roberto Rossellini'], 'total_peliculas': 8, 'duracion_promedio': 93.125}
# {'_id': ['Giovanni Veronesi'], 'total_peliculas': 8, 'duracion_promedio': 114.0}
# {'_id': ['John Badham'], 'total_peliculas': 8, 'duracion_promedio': 111.5}
# {'_id': ['David Mamet'], 'total_peliculas': 8, 'duracion_promedio': 101.75}
# {'_id': ['Guy Ritchie'], 'total_peliculas': 8, 'duracion_promedio': 98.375}
# {'_id': ['Ryèhei Kitamura'], 'total_peliculas': 8, 'duracion_promedio': 108.625}
# {'_id': ['Matti Kassila'], 'total_peliculas': 8, 'duracion_promedio': 87.625}
# {'_id': ['Frank Coraci'], 'total_peliculas': 8, 'duracion_promedio': 105.125}
# {'_id': ['Jerry Schatzberg'], 'total_peliculas': 8, 'duracion_promedio': 104.625}
# {'_id': ['Alex van Warmerdam'], 'total_peliculas': 8, 'duracion_promedio': 98.875}
# {'_id': ['Michael Caton-Jones'], 'total_peliculas': 8, 'duracion_promedio': 116.0}
# {'_id': ['Andy Tennant'], 'total_peliculas': 8, 'duracion_promedio': 115.875}
# {'_id': ['Jean Renoir'], 'total_peliculas': 8, 'duracion_promedio': 93.875}
# {'_id': ['Aku Louhimies'], 'total_peliculas': 8, 'duracion_promedio': 114.25}
# {'_id': ['Bahman Ghobadi'], 'total_peliculas': 8, 'duracion_promedio': 95.625}
# {'_id': ['Carlo Lizzani'], 'total_peliculas': 8, 'duracion_promedio': 100.0}
# {'_id': ['Antoine Fuqua'], 'total_peliculas': 8, 'duracion_promedio': 122.375}
# {'_id': ['Peter Hewitt'], 'total_peliculas': 8, 'duracion_promedio': 92.0}
# {'_id': ['Kenji Mizoguchi'], 'total_peliculas': 8, 'duracion_promedio': 101.125}
# {'_id': ['Kathryn Bigelow'], 'total_peliculas': 8, 'duracion_promedio': 125.25}
# {'_id': ['Youssef Chahine'], 'total_peliculas': 8, 'duracion_promedio': 112.85714285714286}
# {'_id': ['Ronald Neame'], 'total_peliculas': 8, 'duracion_promedio': 106.0}
# {'_id': ['Donald Petrie'], 'total_peliculas': 8, 'duracion_promedio': 105.125}
# {'_id': ['Gillies MacKinnon'], 'total_peliculas': 8, 'duracion_promedio': 102.0}
# {'_id': ['Rolf de Heer'], 'total_peliculas': 8, 'duracion_promedio': 101.42857142857143}
# {'_id': ['Jane Campion'], 'total_peliculas': 8, 'duracion_promedio': 118.625}
# {'_id': ['Gore Verbinski'], 'total_peliculas': 8, 'duracion_promedio': 131.875}
# {'_id': ['John Dahl'], 'total_peliculas': 8, 'duracion_promedio': 107.75}
# {'_id': ['Majid Majidi'], 'total_peliculas': 8, 'duracion_promedio': 92.5}
# {'_id': ['Claude Berri'], 'total_peliculas': 8, 'duracion_promedio': 112.0}
# {'_id': ['Renè Clèment'], 'total_peliculas': 8, 'duracion_promedio': 114.75}
# {'_id': ['Harold Becker'], 'total_peliculas': 8, 'duracion_promedio': 107.625}
# {'_id': ['Mike Figgis'], 'total_peliculas': 8, 'duracion_promedio': 101.75}
# {'_id': ['Guy Maddin'], 'total_peliculas': 8, 'duracion_promedio': 74.375}
# {'_id': ['Randal Kleiser'], 'total_peliculas': 8, 'duracion_promedio': 99.0}
# {'_id': ['Barry Sonnenfeld'], 'total_peliculas': 8, 'duracion_promedio': 99.375}
# {'_id': ['Mark Waters'], 'total_peliculas': 8, 'duracion_promedio': 96.0}
# {'_id': ['Anthony Mann'], 'total_peliculas': 8, 'duracion_promedio': 100.875}
# {'_id': ['Anatole Litvak'], 'total_peliculas': 8, 'duracion_promedio': 107.5}
# {'_id': ['Jack Clayton'], 'total_peliculas': 8, 'duracion_promedio': 103.5}
# {'_id': ['Franklin J. Schaffner'], 'total_peliculas': 8, 'duracion_promedio': 132.375}
# {'_id': ['Mikio Naruse'], 'total_peliculas': 8, 'duracion_promedio': 99.375}
# {'_id': ['Peter Segal'], 'total_peliculas': 8, 'duracion_promedio': 103.375}
# {'_id': ['Steve Miner'], 'total_peliculas': 8, 'duracion_promedio': 91.25}
# {'_id': ['Johnnie To', 'Ka-Fai Wai'], 'total_peliculas': 8, 'duracion_promedio': 100.375}
# {'_id': ['Joseph L. Mankiewicz'], 'total_peliculas': 8, 'duracion_promedio': 122.375}
# {'_id': ['David Lean'], 'total_peliculas': 8, 'duracion_promedio': 157.875}
# {'_id': ['John Irvin'], 'total_peliculas': 8, 'duracion_promedio': 99.625}
# {'_id': ['David Twohy'], 'total_peliculas': 8, 'duracion_promedio': 109.125}
# {'_id': ['Christopher Cain'], 'total_peliculas': 8, 'duracion_promedio': 102.5}
# {'_id': ['Gene Kelly'], 'total_peliculas': 8, 'duracion_promedio': 108.125}
# {'_id': ['Karen Shakhnazarov'], 'total_peliculas': 7, 'duracion_promedio': 100.0}
# {'_id': ['Richard Quine'], 'total_peliculas': 7, 'duracion_promedio': 115.0}
# {'_id': ['Shunji Iwai'], 'total_peliculas': 7, 'duracion_promedio': 100.0}
# {'_id': ['Don Siegel'], 'total_peliculas': 7, 'duracion_promedio': 99.42857142857143}
# {'_id': ['Lamont Johnson'], 'total_peliculas': 7, 'duracion_promedio': 98.14285714285714}
# {'_id': ['Tom DiCillo'], 'total_peliculas': 7, 'duracion_promedio': 95.85714285714286}
# {'_id': ['Fatih Akin'], 'total_peliculas': 7, 'duracion_promedio': 110.14285714285714}
# {'_id': ['Nagisa èshima'], 'total_peliculas': 7, 'duracion_promedio': 110.57142857142857}
# {'_id': ['Arthur Penn'], 'total_peliculas': 7, 'duracion_promedio': 109.0}
# {'_id': ['Marco Bellocchio'], 'total_peliculas': 7, 'duracion_promedio': 105.57142857142857}
# {'_id': ['Paul Hoen'], 'total_peliculas': 7, 'duracion_promedio': 94.57142857142857}
# {'_id': ['John Guillermin'], 'total_peliculas': 7, 'duracion_promedio': 123.71428571428571}
# {'_id': ['Sergey Loznitsa'], 'total_peliculas': 7, 'duracion_promedio': 100.28571428571429}
# {'_id': ['Risto Jarva'], 'total_peliculas': 7, 'duracion_promedio': 107.71428571428571}
# {'_id': ['Howard Zieff'], 'total_peliculas': 7, 'duracion_promedio': 102.71428571428571}
# {'_id': ['Tomas Alfredson'], 'total_peliculas': 7, 'duracion_promedio': 139.57142857142858}
# {'_id': ['George Clooney'], 'total_peliculas': 7, 'duracion_promedio': 107.57142857142857}
# {'_id': ['Priyadarshan'], 'total_peliculas': 7, 'duracion_promedio': 158.33333333333334}
# {'_id': ['King Vidor'], 'total_peliculas': 7, 'duracion_promedio': 117.57142857142857}
# {'_id': ['Greg Beeman'], 'total_peliculas': 7, 'duracion_promedio': 94.28571428571429}
# {'_id': ['Bernard Rose'], 'total_peliculas': 7, 'duracion_promedio': 105.28571428571429}
# {'_id': ['Cèdric Klapisch'], 'total_peliculas': 7, 'duracion_promedio': 113.71428571428571}
# {'_id': ['Jèzè Itami'], 'total_peliculas': 7, 'duracion_promedio': 122.28571428571429}
# {'_id': ['Terrence Malick'], 'total_peliculas': 7, 'duracion_promedio': 123.14285714285714}
# {'_id': ['Harold Ramis'], 'total_peliculas': 7, 'duracion_promedio': 96.71428571428571}
# {'_id': ['Naomi Kawase'], 'total_peliculas': 7, 'duracion_promedio': 86.57142857142857}
# {'_id': ['Tim Story'], 'total_peliculas': 7, 'duracion_promedio': 103.42857142857143}
# {'_id': ['Jan Hrebejk'], 'total_peliculas': 7, 'duracion_promedio': 108.0}
# {'_id': ['Nanni Moretti'], 'total_peliculas': 7, 'duracion_promedio': 98.71428571428571}
# {'_id': ['Mark Sandrich'], 'total_peliculas': 7, 'duracion_promedio': 105.14285714285714}
# {'_id': ['Nick Cassavetes'], 'total_peliculas': 7, 'duracion_promedio': 111.71428571428571}
# {'_id': ['Gregory Hoblit'], 'total_peliculas': 7, 'duracion_promedio': 118.28571428571429}
# {'_id': ['Nora Ephron'], 'total_peliculas': 7, 'duracion_promedio': 109.14285714285714}
# {'_id': ['Sam Mendes'], 'total_peliculas': 7, 'duracion_promedio': 117.42857142857143}
# {'_id': ['Robert Luketic'], 'total_peliculas': 7, 'duracion_promedio': 102.42857142857143}
# {'_id': ['Yasujirè Ozu'], 'total_peliculas': 7, 'duracion_promedio': 105.42857142857143}
# {'_id': ['Andy Fickman'], 'total_peliculas': 7, 'duracion_promedio': 104.14285714285714}
# {'_id': ['Frank Capra', 'Anatole Litvak'], 'total_peliculas': 7, 'duracion_promedio': 60.714285714285715}
# {'_id': ['Denis Villeneuve'], 'total_peliculas': 7, 'duracion_promedio': 98.57142857142857}
# {'_id': ['Bruce McDonald'], 'total_peliculas': 7, 'duracion_promedio': 86.42857142857143}
# {'_id': ['Joèo Cèsar Monteiro'], 'total_peliculas': 7, 'duracion_promedio': 118.85714285714286}
# {'_id': ['Charles Chaplin'], 'total_peliculas': 7, 'duracion_promedio': 105.57142857142857}
# {'_id': ['Pen-Ek Ratanaruang'], 'total_peliculas': 7, 'duracion_promedio': 105.57142857142857}
# {'_id': ['Charles Jarrott'], 'total_peliculas': 7, 'duracion_promedio': 116.42857142857143}
# {'_id': ['Jee-woon Kim'], 'total_peliculas': 7, 'duracion_promedio': 113.85714285714286}
# {'_id': ['Stanley Donen'], 'total_peliculas': 7, 'duracion_promedio': 101.42857142857143}
# {'_id': ['Charles Grosvenor'], 'total_peliculas': 7, 'duracion_promedio': 75.28571428571429}
# {'_id': ['Roberto Benigni'], 'total_peliculas': 7, 'duracion_promedio': 109.28571428571429}
# {'_id': ['Gordon Chan'], 'total_peliculas': 7, 'duracion_promedio': 104.0}
# {'_id': ['Keisuke Kinoshita'], 'total_peliculas': 7, 'duracion_promedio': 115.28571428571429}
# {'_id': ['Gary Fleder'], 'total_peliculas': 7, 'duracion_promedio': 113.57142857142857}
# {'_id': ['Gillian Armstrong'], 'total_peliculas': 7, 'duracion_promedio': 111.42857142857143}
# {'_id': ['Peter Berg'], 'total_peliculas': 7, 'duracion_promedio': 110.85714285714286}
# {'_id': ['Frièrik èèr Frièriksson'], 'total_peliculas': 7, 'duracion_promedio': 93.57142857142857}
# {'_id': ['Avi Nesher'], 'total_peliculas': 7, 'duracion_promedio': 112.57142857142857}
# {'_id': ['Claude Lelouch'], 'total_peliculas': 7, 'duracion_promedio': 133.14285714285714}
# {'_id': ['Nadia Tass'], 'total_peliculas': 7, 'duracion_promedio': 97.14285714285714}
# {'_id': ['David R. Ellis'], 'total_peliculas': 7, 'duracion_promedio': 91.28571428571429}
# {'_id': ['John Duigan'], 'total_peliculas': 7, 'duracion_promedio': 104.0}
# {'_id': ['Stuart Rosenberg'], 'total_peliculas': 7, 'duracion_promedio': 121.0}
# {'_id': ['Zhangke Jia'], 'total_peliculas': 7, 'duracion_promedio': 129.42857142857142}
# {'_id': ['George A. Romero'], 'total_peliculas': 7, 'duracion_promedio': 104.57142857142857}
# {'_id': ['Tom Tykwer'], 'total_peliculas': 7, 'duracion_promedio': 101.28571428571429}
# {'_id': ['Bill Condon'], 'total_peliculas': 7, 'duracion_promedio': 116.71428571428571}
# {'_id': ['F. Gary Gray'], 'total_peliculas': 7, 'duracion_promedio': 114.42857142857143}
# {'_id': ['Mick Jackson'], 'total_peliculas': 7, 'duracion_promedio': 108.85714285714286}
# {'_id': ['Ernest R. Dickerson'], 'total_peliculas': 7, 'duracion_promedio': 96.42857142857143}
# {'_id': ['Gabriele Muccino'], 'total_peliculas': 7, 'duracion_promedio': 116.0}
# {'_id': ['Daniel Lee'], 'total_peliculas': 7, 'duracion_promedio': 107.0}
# {'_id': ['Shane Meadows'], 'total_peliculas': 7, 'duracion_promedio': 88.42857142857143}
# {'_id': ['Pietro Germi'], 'total_peliculas': 7, 'duracion_promedio': 97.0}
# {'_id': ['Paul Thomas Anderson'], 'total_peliculas': 7, 'duracion_promedio': 141.28571428571428}
# {'_id': ['Oliver Hirschbiegel'], 'total_peliculas': 7, 'duracion_promedio': 123.0}
# {'_id': ['Stephen Sommers'], 'total_peliculas': 7, 'duracion_promedio': 120.85714285714286}
# {'_id': ['John Cassavetes'], 'total_peliculas': 7, 'duracion_promedio': 127.71428571428571}
# {'_id': ['Sylvester Stallone'], 'total_peliculas': 7, 'duracion_promedio': 99.85714285714286}
# {'_id': ['Jonathan Kaplan'], 'total_peliculas': 7, 'duracion_promedio': 126.57142857142857}
# {'_id': ['Rohit Shetty'], 'total_peliculas': 7, 'duracion_promedio': 144.66666666666666}
# {'_id': ['Michael Almereyda'], 'total_peliculas': 7, 'duracion_promedio': 96.42857142857143}
# {'_id': ['Kevin Macdonald'], 'total_peliculas': 7, 'duracion_promedio': 115.57142857142857}
# {'_id': ['Alfonso Cuarèn'], 'total_peliculas': 7, 'duracion_promedio': 106.71428571428571}
# {'_id': ['Doug Liman'], 'total_peliculas': 7, 'duracion_promedio': 106.57142857142857}
# {'_id': ['Kenny Ortega'], 'total_peliculas': 7, 'duracion_promedio': 105.42857142857143}
# {'_id': ['Markku Pèlènen'], 'total_peliculas': 7, 'duracion_promedio': 87.57142857142857}
# {'_id': ['Ralph Nelson'], 'total_peliculas': 7, 'duracion_promedio': 105.14285714285714}
# {'_id': ['Corey Yuen'], 'total_peliculas': 7, 'duracion_promedio': 97.0}
# {'_id': ['Jean-Pierre Jeunet'], 'total_peliculas': 7, 'duracion_promedio': 102.14285714285714}
# {'_id': ['Bruno Barreto'], 'total_peliculas': 7, 'duracion_promedio': 105.71428571428571}
# {'_id': ['Lee Tamahori'], 'total_peliculas': 7, 'duracion_promedio': 107.42857142857143}
# {'_id': ['Lina Wertmèller'], 'total_peliculas': 7, 'duracion_promedio': 109.28571428571429}
# {'_id': ['Frank Pierson'], 'total_peliculas': 7, 'duracion_promedio': 108.85714285714286}
# {'_id': ['Jan Sverèk'], 'total_peliculas': 7, 'duracion_promedio': 102.57142857142857}
# {'_id': ['Andrew Fleming'], 'total_peliculas': 7, 'duracion_promedio': 95.0}
# {'_id': ['Andy Wachowski', 'Lana Wachowski'], 'total_peliculas': 7, 'duracion_promedio': 128.57142857142858}
# {'_id': ['Terence Davies'], 'total_peliculas': 7, 'duracion_promedio': 100.42857142857143}
# {'_id': ['Nikos Nikolaidis'], 'total_peliculas': 7, 'duracion_promedio': 119.85714285714286}
# {'_id': ['Hal Needham'], 'total_peliculas': 7, 'duracion_promedio': 97.71428571428571}
# {'_id': ['Jon Favreau'], 'total_peliculas': 7, 'duracion_promedio': 110.85714285714286}
# {'_id': ['Brad Anderson'], 'total_peliculas': 7, 'duracion_promedio': 104.14285714285714}
# {'_id': ['Andrew Davis'], 'total_peliculas': 7, 'duracion_promedio': 115.71428571428571}
# {'_id': ['Alberto Lattuada'], 'total_peliculas': 7, 'duracion_promedio': 93.71428571428571}
# {'_id': ['Stephen Gyllenhaal'], 'total_peliculas': 7, 'duracion_promedio': 103.14285714285714}
# {'_id': ['George Lucas'], 'total_peliculas': 7, 'duracion_promedio': 107.14285714285714}
# {'_id': ['Karel Reisz'], 'total_peliculas': 7, 'duracion_promedio': 111.28571428571429}
# {'_id': ['Arturo Ripstein'], 'total_peliculas': 7, 'duracion_promedio': 105.0}
# {'_id': ['John Madden'], 'total_peliculas': 7, 'duracion_promedio': 113.85714285714286}
# {'_id': ['Rouben Mamoulian'], 'total_peliculas': 7, 'duracion_promedio': 102.42857142857143}
# {'_id': ['Robert Townsend'], 'total_peliculas': 7, 'duracion_promedio': 99.28571428571429}
# {'_id': ['Jeff Bleckner'], 'total_peliculas': 7, 'duracion_promedio': 141.14285714285714}
# {'_id': ['Abbas Kiarostami'], 'total_peliculas': 6, 'duracion_promedio': 97.5}
# {'_id': ['Noah Baumbach'], 'total_peliculas': 6, 'duracion_promedio': 94.66666666666667}
# {'_id': ['Ousmane Sembene'], 'total_peliculas': 6, 'duracion_promedio': 107.66666666666667}
# {'_id': ['Todd Haynes'], 'total_peliculas': 6, 'duracion_promedio': 105.5}
# {'_id': ['Darren Aronofsky'], 'total_peliculas': 6, 'duracion_promedio': 106.16666666666667}
# {'_id': ['Andrew Niccol'], 'total_peliculas': 6, 'duracion_promedio': 113.5}
# {'_id': ["Pat O'Connor"], 'total_peliculas': 6, 'duracion_promedio': 101.5}
# {'_id': ['Patricio Guzmèn'], 'total_peliculas': 6, 'duracion_promedio': 105.33333333333333}
# {'_id': ['Christopher Guest'], 'total_peliculas': 6, 'duracion_promedio': 87.5}
# {'_id': ['Eloy de la Iglesia'], 'total_peliculas': 6, 'duracion_promedio': 106.33333333333333}
# {'_id': ['Nick Castle'], 'total_peliculas': 6, 'duracion_promedio': 96.5}
# {'_id': ['John Schultz'], 'total_peliculas': 6, 'duracion_promedio': 93.33333333333333}
# {'_id': ['Jon Avnet'], 'total_peliculas': 6, 'duracion_promedio': 118.5}
# {'_id': ['Martin Brest'], 'total_peliculas': 6, 'duracion_promedio': 130.5}
# {'_id': ['Ash Baron-Cohen'], 'total_peliculas': 6, 'duracion_promedio': 99.16666666666667}
# {'_id': ['Eric Till'], 'total_peliculas': 6, 'duracion_promedio': 99.5}
# {'_id': ['Albert Hughes', 'Allen Hughes'], 'total_peliculas': 6, 'duracion_promedio': 110.16666666666667}
# {'_id': ['Sanjay Leela Bhansali'], 'total_peliculas': 6, 'duracion_promedio': 147.33333333333334}
# {'_id': ['Jean-Pierre Dardenne', 'Luc Dardenne'], 'total_peliculas': 6, 'duracion_promedio': 96.0}
# {'_id': ['Brian Yuzna'], 'total_peliculas': 6, 'duracion_promedio': 96.66666666666667}
# {'_id': ['David Miller'], 'total_peliculas': 6, 'duracion_promedio': 111.16666666666667}
# {'_id': ['Matti Ijès'], 'total_peliculas': 6, 'duracion_promedio': 90.5}
# {'_id': ['Marcus H. Rosenmèller'], 'total_peliculas': 6, 'duracion_promedio': 102.66666666666667}
# {'_id': ['John Kent Harrison'], 'total_peliculas': 6, 'duracion_promedio': 186.4}
# {'_id': ['Marcelo Pièeyro'], 'total_peliculas': 6, 'duracion_promedio': 115.0}
# {'_id': ['McG'], 'total_peliculas': 6, 'duracion_promedio': 109.33333333333333}
# {'_id': ['Stewart Raffill'], 'total_peliculas': 6, 'duracion_promedio': 96.0}
# {'_id': ['Walter Salles'], 'total_peliculas': 6, 'duracion_promedio': 116.16666666666667}
# {'_id': ['Bent Hamer'], 'total_peliculas': 6, 'duracion_promedio': 91.33333333333333}
# {'_id': ['Jackie Chan'], 'total_peliculas': 6, 'duracion_promedio': 105.33333333333333}
# {'_id': ['Luc Jacquet'], 'total_peliculas': 6, 'duracion_promedio': 85.5}
# {'_id': ['Vishal Bhardwaj'], 'total_peliculas': 6, 'duracion_promedio': 134.0}
# {'_id': ['Olivier Megaton'], 'total_peliculas': 6, 'duracion_promedio': 105.5}
# {'_id': ['Norman Taurog'], 'total_peliculas': 6, 'duracion_promedio': 98.5}
# {'_id': ['Don Coscarelli'], 'total_peliculas': 6, 'duracion_promedio': 97.5}
# {'_id': ['Hirokazu Koreeda'], 'total_peliculas': 6, 'duracion_promedio': 125.33333333333333}
# {'_id': ['Daniel Petrie'], 'total_peliculas': 6, 'duracion_promedio': 110.16666666666667}
# {'_id': ['Simon West'], 'total_peliculas': 6, 'duracion_promedio': 102.33333333333333}
# {'_id': ['Michael Polish'], 'total_peliculas': 6, 'duracion_promedio': 96.0}
# {'_id': ['Miguel Arteta'], 'total_peliculas': 6, 'duracion_promedio': 88.83333333333333}
# {'_id': ['Bill Forsyth'], 'total_peliculas': 6, 'duracion_promedio': 101.83333333333333}
# {'_id': ['Dick Maas'], 'total_peliculas': 6, 'duracion_promedio': 104.16666666666667}
# {'_id': ['Zack Snyder'], 'total_peliculas': 6, 'duracion_promedio': 121.66666666666667}
# {'_id': ['John Stockwell'], 'total_peliculas': 6, 'duracion_promedio': 98.5}
# {'_id': ['Renè Clair'], 'total_peliculas': 6, 'duracion_promedio': 98.0}
# {'_id': ['Sam Weisman'], 'total_peliculas': 6, 'duracion_promedio': 94.33333333333333}
# {'_id': ['Amy Heckerling'], 'total_peliculas': 6, 'duracion_promedio': 92.33333333333333}
# {'_id': ['Brad Silberling'], 'total_peliculas': 6, 'duracion_promedio': 103.83333333333333}
# {'_id': ['Tom Hooper'], 'total_peliculas': 6, 'duracion_promedio': 116.16666666666667}
# {'_id': ['Gary Winick'], 'total_peliculas': 6, 'duracion_promedio': 93.0}
# {'_id': ['Julien Temple'], 'total_peliculas': 6, 'duracion_promedio': 114.5}
# {'_id': ['Michael Lembeck'], 'total_peliculas': 6, 'duracion_promedio': 96.16666666666667}
# {'_id': ['Peter Markle'], 'total_peliculas': 6, 'duracion_promedio': 102.83333333333333}
# ...
# {'_id': ['Jeff Blyth'], 'total_peliculas': 1, 'duracion_promedio': 83.0}
# {'_id': ['John Ford', 'Henry Hathaway', 'George Marshall', 'Richard Thorpe'], 'total_peliculas': 1, 'duracion_promedio': 164.0}
# {'_id': ['Jennifer Yuh'], 'total_peliculas': 1, 'duracion_promedio': 91.0}
# {'_id': ['Rune Schjètt'], 'total_peliculas': 1, 'duracion_promedio': 90.0}
# {'_id': ['Jerry Kramer', 'Jim Blashfield', 'Colin Chilvers'], 'total_peliculas': 1, 'duracion_promedio': 93.0}
# {'_id': ['Nick Holt'], 'total_peliculas': 1, 'duracion_promedio': 50.0}
# {'_id': ['Marcus Cole'], 'total_peliculas': 1, 'duracion_promedio': 100.0}
# {'_id': ['Abby Epstein'], 'total_peliculas': 1, 'duracion_promedio': 87.0}
# {'_id': ['Juliano Ribeiro Salgado', 'Wim Wenders'], 'total_peliculas': 1, 'duracion_promedio': 110.0}
# {'_id': ['Kevin Goetz', 'Michael Goetz'], 'total_peliculas': 1, 'duracion_promedio': 82.0}
# {'_id': ['Edgar Selwyn'], 'total_peliculas': 1, 'duracion_promedio': 75.0}
# {'_id': ['Andrej Kosak'], 'total_peliculas': 1, 'duracion_promedio': None}
# {'_id': ['Goran Radovanovic'], 'total_peliculas': 1, 'duracion_promedio': 92.0}
# {'_id': ['Clèudio Assis'], 'total_peliculas': 1, 'duracion_promedio': 110.0}
# {'_id': ['Jennifer Yee'], 'total_peliculas': 1, 'duracion_promedio': None}
# {'_id': ['Daniel Schweizer'], 'total_peliculas': 1, 'duracion_promedio': 90.0}
# {'_id': ['Frank Novak'], 'total_peliculas': 1, 'duracion_promedio': 90.0}
# {'_id': ['Filippos Koutsaftis'], 'total_peliculas': 1, 'duracion_promedio': 87.0}
# {'_id': ['Andrew Neel'], 'total_peliculas': 1, 'duracion_promedio': 84.0}
# {'_id': ['Peter Pau'], 'total_peliculas': 1, 'duracion_promedio': 103.0}
# {'_id': ['Almut Getto'], 'total_peliculas': 1, 'duracion_promedio': 104.0}
# {'_id': ['Garret Daly', 'Martina McGlynn'], 'total_peliculas': 1, 'duracion_promedio': 110.0}
# {'_id': ['Gabriel London'], 'total_peliculas': 1, 'duracion_promedio': 92.0}
# {'_id': ['Brad Mirman'], 'total_peliculas': 1, 'duracion_promedio': 98.0}
# {'_id': ['Jack Lee'], 'total_peliculas': 1, 'duracion_promedio': 117.0}
# {'_id': ['David Ryan Keith'], 'total_peliculas': 1, 'duracion_promedio': 82.0}
# {'_id': ['Rob Lemkin', 'Thet Sambath'], 'total_peliculas': 1, 'duracion_promedio': 93.0}
# {'_id': ['Marcin Wrona'], 'total_peliculas': 1, 'duracion_promedio': 90.0}
# {'_id': ['Juliet May'], 'total_peliculas': 1, 'duracion_promedio': 90.0}
# {'_id': ['Do-yun Lee'], 'total_peliculas': 1, 'duracion_promedio': 114.0}
# {'_id': ['Kevin Yagher'], 'total_peliculas': 1, 'duracion_promedio': 85.0}
# {'_id': ['Oliver Irving'], 'total_peliculas': 1, 'duracion_promedio': 85.0}
# {'_id': ['Francesco Amato'], 'total_peliculas': 1, 'duracion_promedio': 100.0}
# {'_id': ['Valdès èskarsdèttir'], 'total_peliculas': 1, 'duracion_promedio': None}
# {'_id': ["Brendon O'Loughlin"], 'total_peliculas': 1, 'duracion_promedio': 96.0}
# {'_id': ['Luke Moran'], 'total_peliculas': 1, 'duracion_promedio': 102.0}
# {'_id': ['Shirin Neshat', 'Shoja Azari'], 'total_peliculas': 1, 'duracion_promedio': 95.0}
# {'_id': ['John Krokidas'], 'total_peliculas': 1, 'duracion_promedio': 104.0}
# {'_id': ['Kevin Tancharoen'], 'total_peliculas': 1, 'duracion_promedio': 107.0}
# {'_id': ['John H. Williams'], 'total_peliculas': 1, 'duracion_promedio': 76.0}
# {'_id': ['Fabrice Gobert'], 'total_peliculas': 1, 'duracion_promedio': 87.0}
# {'_id': ['Michael Gunton', 'Martha Holmes'], 'total_peliculas': 1, 'duracion_promedio': 85.0}
# {'_id': ['Stefan Scaini'], 'total_peliculas': 1, 'duracion_promedio': 185.0}
# {'_id': ['Hampton Fancher'], 'total_peliculas': 1, 'duracion_promedio': 111.0}
# {'_id': ['Shashanka Ghosh'], 'total_peliculas': 1, 'duracion_promedio': 130.0}
# {'_id': ['Akiz'], 'total_peliculas': 1, 'duracion_promedio': 88.0}
# {'_id': ['Arthur Allan Seidelman'], 'total_peliculas': 1, 'duracion_promedio': 100.0}
# {'_id': ['Ryan Redford'], 'total_peliculas': 1, 'duracion_promedio': 82.0}
# {'_id': ['Eva Stotz'], 'total_peliculas': 1, 'duracion_promedio': 61.0}
# {'_id': ['Brian Iglesias'], 'total_peliculas': 1, 'duracion_promedio': 86.0}
# {'_id': ['Paolo Franchi'], 'total_peliculas': 1, 'duracion_promedio': 89.0}
# {'_id': ['Peter Callahan'], 'total_peliculas': 1, 'duracion_promedio': 98.0}
# {'_id': ['Phillip Guzman'], 'total_peliculas': 1, 'duracion_promedio': 104.0}
# {'_id': ['Philip Brophy'], 'total_peliculas': 1, 'duracion_promedio': 81.0}
# {'_id': ['Elaine Madsen'], 'total_peliculas': 1, 'duracion_promedio': None}
# {'_id': ['Mark Christopher Covino', 'Jeff Howlett'], 'total_peliculas': 1, 'duracion_promedio': 96.0}
# {'_id': ['Jared Moshe'], 'total_peliculas': 1, 'duracion_promedio': 93.0}
# {'_id': ['Joseph Zito'], 'total_peliculas': 1, 'duracion_promedio': 91.0}
# {'_id': ['Scott Ryan'], 'total_peliculas': 1, 'duracion_promedio': 85.0}
# {'_id': ['Jesse Wolfe'], 'total_peliculas': 1, 'duracion_promedio': None}
# {'_id': ['Joseph Strick'], 'total_peliculas': 1, 'duracion_promedio': 123.0}
# {'_id': ['Eugene Corr'], 'total_peliculas': 1, 'duracion_promedio': 105.0}
# {'_id': ['Ryan Eslinger'], 'total_peliculas': 1, 'duracion_promedio': 86.0}
# {'_id': ['Lance W. Dreesen'], 'total_peliculas': 1, 'duracion_promedio': 95.0}
# {'_id': ['Tony Cookson'], 'total_peliculas': 1, 'duracion_promedio': 92.0}
# {'_id': ['Jamie Travis'], 'total_peliculas': 1, 'duracion_promedio': 13.0}
# {'_id': ['Enrique Gato'], 'total_peliculas': 1, 'duracion_promedio': 92.0}
# {'_id': ['Zach Niles', 'Banker White'], 'total_peliculas': 1, 'duracion_promedio': 78.0}
# {'_id': ['Christoph Stark'], 'total_peliculas': 1, 'duracion_promedio': 100.0}
# {'_id': ['Douglas Day Stewart'], 'total_peliculas': 1, 'duracion_promedio': 100.0}
# {'_id': ['Aleksey Sidorov'], 'total_peliculas': 1, 'duracion_promedio': 132.0}
# {'_id': ['Michael Petroni'], 'total_peliculas': 1, 'duracion_promedio': 101.0}
# {'_id': ['Nick Vallelonga'], 'total_peliculas': 1, 'duracion_promedio': 89.0}
# {'_id': ['Brett Gaylor'], 'total_peliculas': 1, 'duracion_promedio': 80.0}
# {'_id': ['Martin Hègdahl'], 'total_peliculas': 1, 'duracion_promedio': 80.0}
# {'_id': ['Behnam Behzadi'], 'total_peliculas': 1, 'duracion_promedio': 93.0}
# {'_id': ['Paul Johansson'], 'total_peliculas': 1, 'duracion_promedio': 97.0}
# {'_id': ['John Palmer'], 'total_peliculas': 1, 'duracion_promedio': 78.0}
# {'_id': ['Jerry Rothwell'], 'total_peliculas': 1, 'duracion_promedio': 110.0}
# {'_id': ['Nicholas Jasenovec'], 'total_peliculas': 1, 'duracion_promedio': 88.0}
# {'_id': ['Mina Shum'], 'total_peliculas': 1, 'duracion_promedio': 87.0}
# {'_id': ['John Borowski'], 'total_peliculas': 1, 'duracion_promedio': None}
# {'_id': ['Jeremy Grant'], 'total_peliculas': 1, 'duracion_promedio': 81.0}
# {'_id': ['Eskil Vogt'], 'total_peliculas': 1, 'duracion_promedio': 96.0}
# {'_id': ['Michel Spinosa'], 'total_peliculas': 1, 'duracion_promedio': 106.0}
# {'_id': ['Kris Swanberg'], 'total_peliculas': 1, 'duracion_promedio': 90.0}
# {'_id': ['Marcus Mittermeier'], 'total_peliculas': 1, 'duracion_promedio': 89.0}
# {'_id': ['Valerie Breiman'], 'total_peliculas': 1, 'duracion_promedio': 82.0}
# {'_id': ['Paul Quinn'], 'total_peliculas': 1, 'duracion_promedio': 119.0}
# {'_id': ['Faiza Ahmad Khan'], 'total_peliculas': 1, 'duracion_promedio': 52.0}
# {'_id': ['Mitra Farahani'], 'total_peliculas': 1, 'duracion_promedio': 96.0}
# {'_id': ['Fez Noriega'], 'total_peliculas': 1, 'duracion_promedio': 90.0}
# {'_id': ['Brent Maddock'], 'total_peliculas': 1, 'duracion_promedio': 104.0}
# {'_id': ['Adam Schindler'], 'total_peliculas': 1, 'duracion_promedio': 90.0}
# {'_id': ['Kat Coiro'], 'total_peliculas': 1, 'duracion_promedio': 83.0}
# {'_id': ['Maja Borg'], 'total_peliculas': 1, 'duracion_promedio': 97.0}
# {'_id': ['Mark Jarrett'], 'total_peliculas': 1, 'duracion_promedio': 105.0}
# {'_id': ['Marcos Paulo'], 'total_peliculas': 1, 'duracion_promedio': 101.0}
# {'_id': ['Katherine Dieckmann'], 'total_peliculas': 1, 'duracion_promedio': 90.0}
# {'_id': ['Seth Green'], 'total_peliculas': 1, 'duracion_promedio': 30.0}
# {'_id': ['Martha Fiennes'], 'total_peliculas': 1, 'duracion_promedio': 106.0}
# {'_id': ['Tommy Stovall'], 'total_peliculas': 1, 'duracion_promedio': 103.0}
# {'_id': ['Edward S. Curtis'], 'total_peliculas': 1, 'duracion_promedio': 65.0}
# {'_id': ['Shimmy Marcus'], 'total_peliculas': 1, 'duracion_promedio': 80.0}
# {'_id': ['Joe Pytka'], 'total_peliculas': 1, 'duracion_promedio': 88.0}
# {'_id': ['Jouni Hokkanen'], 'total_peliculas': 1, 'duracion_promedio': 29.0}
# {'_id': ['John Stainton'], 'total_peliculas': 1, 'duracion_promedio': 90.0}
# {'_id': ['Nick Whitfield'], 'total_peliculas': 1, 'duracion_promedio': 94.0}
# {'_id': ['Matt Muir'], 'total_peliculas': 1, 'duracion_promedio': 85.0}
# {'_id': ['Ravi Jadhav'], 'total_peliculas': 1, 'duracion_promedio': 127.0}
# {'_id': ['Andrew Horn'], 'total_peliculas': 1, 'duracion_promedio': 98.0}
# {'_id': ['Benny Chan', 'Jackie Chan'], 'total_peliculas': 1, 'duracion_promedio': 108.0}
# {'_id': ['Tim Sullivan'], 'total_peliculas': 1, 'duracion_promedio': 87.0}
# {'_id': ['Glenn Standring'], 'total_peliculas': 1, 'duracion_promedio': 90.0}
# {'_id': ['Yi-chi Lien'], 'total_peliculas': 1, 'duracion_promedio': 113.0}
# {'_id': ['Stefan Forbes'], 'total_peliculas': 1, 'duracion_promedio': 86.0}
# {'_id': ['Robert Kurtzman'], 'total_peliculas': 1, 'duracion_promedio': 90.0}
# {'_id': ['Bryan Lefler'], 'total_peliculas': 1, 'duracion_promedio': 103.0}
# {'_id': ["Jun'ichi Mori"], 'total_peliculas': 1, 'duracion_promedio': 118.0}
# {'_id': ['Jordan Walker-Pearlman'], 'total_peliculas': 1, 'duracion_promedio': 107.0}
# {'_id': ['Young Man Kang'], 'total_peliculas': 1, 'duracion_promedio': 90.0}
# {'_id': ['Lee Demarbre'], 'total_peliculas': 1, 'duracion_promedio': 85.0}
# {'_id': ['Dae-min Park'], 'total_peliculas': 1, 'duracion_promedio': 111.0}
# {'_id': ['Jeremiah Birnbaum'], 'total_peliculas': 1, 'duracion_promedio': 80.0}
# {'_id': ['Marisa Sistach'], 'total_peliculas': 1, 'duracion_promedio': 104.0}
# {'_id': ['Colin Strause', 'Greg Strause'], 'total_peliculas': 1, 'duracion_promedio': 94.0}
# {'_id': ['A. Dean Bell'], 'total_peliculas': 1, 'duracion_promedio': 96.0}
# {'_id': ['Michael DeCarlo'], 'total_peliculas': 1, 'duracion_promedio': None}
# {'_id': ['Armando Bo'], 'total_peliculas': 1, 'duracion_promedio': 91.0}
# {'_id': ['Steve Loter', 'Lisa Schaffer', 'Victor Cook', 'Don MacKinnon'], 'total_peliculas': 1, 'duracion_promedio': 75.0}
# {'_id': ['Janet Tobias'], 'total_peliculas': 1, 'duracion_promedio': 83.0}
# {'_id': ['Hiroshi Shinagawa'], 'total_peliculas': 1, 'duracion_promedio': 122.0}
# {'_id': ['Paul Nicholas'], 'total_peliculas': 1, 'duracion_promedio': 95.0}
# {'_id': ['Danfung Dennis'], 'total_peliculas': 1, 'duracion_promedio': 88.0}
# {'_id': ['Tom Morris'], 'total_peliculas': 1, 'duracion_promedio': 94.0}
# {'_id': ['Keiichi Kobayashi'], 'total_peliculas': 1, 'duracion_promedio': 113.0}
# {'_id': ['Gregory J. Corrado'], 'total_peliculas': 1, 'duracion_promedio': 120.0}
# {'_id': ['Cheol-hie Park'], 'total_peliculas': 1, 'duracion_promedio': 113.0}
# {'_id': ['Henry Alex Rubin', 'Dana Adam Shapiro'], 'total_peliculas': 1, 'duracion_promedio': 88.0}
# {'_id': ['Kenneth Glenaan'], 'total_peliculas': 1, 'duracion_promedio': 87.0}
# {'_id': ['Andrei Konchalovsky'], 'total_peliculas': 1, 'duracion_promedio': 102.0}
# {'_id': ['Harry Lachman'], 'total_peliculas': 1, 'duracion_promedio': 89.0}
# {'_id': ['James Redford'], 'total_peliculas': 1, 'duracion_promedio': 107.0}
# {'_id': ['Sophie Hyde'], 'total_peliculas': 1, 'duracion_promedio': 114.0}
# {'_id': ['Eli Craig'], 'total_peliculas': 1, 'duracion_promedio': 89.0}
# {'_id': ['Stacy Title'], 'total_peliculas': 1, 'duracion_promedio': 92.0}
# {'_id': ['Udi Aloni'], 'total_peliculas': 1, 'duracion_promedio': 97.0}
# {'_id': ['Alfonso Albacete', 'David Menkes'], 'total_peliculas': 1, 'duracion_promedio': 107.0}
# {'_id': ['Gavin Millar'], 'total_peliculas': 1, 'duracion_promedio': 94.0}
# {'_id': ['Naoto Kumazawa'], 'total_peliculas': 1, 'duracion_promedio': 119.0}
# {'_id': ['Michael Maren'], 'total_peliculas': 1, 'duracion_promedio': 94.0}
# {'_id': ['Tze Chun'], 'total_peliculas': 1, 'duracion_promedio': 90.0}
# {'_id': ['Marcos Bernstein'], 'total_peliculas': 1, 'duracion_promedio': 99.0}
# {'_id': ['Gabor Csupo'], 'total_peliculas': 1, 'duracion_promedio': 96.0}
# {'_id': ['Jacob Gentry'], 'total_peliculas': 1, 'duracion_promedio': 101.0}
# {'_id': ['Stewart Sugg'], 'total_peliculas': 1, 'duracion_promedio': 101.0}
# {'_id': ['Don Hartman'], 'total_peliculas': 1, 'duracion_promedio': 85.0}
# {'_id': ['Anusha Rizvi', 'Mahmood Farooqui'], 'total_peliculas': 1, 'duracion_promedio': 95.0}
# {'_id': ['Frederick De Cordova'], 'total_peliculas': 1, 'duracion_promedio': 87.0}
# {'_id': ['Joji Matsuoka'], 'total_peliculas': 1, 'duracion_promedio': 98.0}
# {'_id': ['Jeff Stephenson'], 'total_peliculas': 1, 'duracion_promedio': 80.0}
# {'_id': ['Jeong-beom Lee'], 'total_peliculas': 1, 'duracion_promedio': 119.0}
# {'_id': ['Peter Glanz'], 'total_peliculas': 1, 'duracion_promedio': 86.0}
# {'_id': ['Jim Wynorski'], 'total_peliculas': 1, 'duracion_promedio': 88.0}
# {'_id': ['Johannes Jaeger'], 'total_peliculas': 1, 'duracion_promedio': 102.0}
# {'_id': ['Carles Bosch'], 'total_peliculas': 1, 'duracion_promedio': 96.0}
# {'_id': ['Jacques Dorfmann'], 'total_peliculas': 1, 'duracion_promedio': 120.0}
# {'_id': ['Nick Lyon'], 'total_peliculas': 1, 'duracion_promedio': 103.0}
# {'_id': ['Avishai Sivan'], 'total_peliculas': 1, 'duracion_promedio': 120.0}
# {'_id': ['Aik Karapetian'], 'total_peliculas': 1, 'duracion_promedio': 71.0}
# {'_id': ['Steve Jacobs'], 'total_peliculas': 1, 'duracion_promedio': 119.0}
# {'_id': ['Kihachi Okamoto'], 'total_peliculas': 1, 'duracion_promedio': 157.0}
# {'_id': ['Paule Baillargeon'], 'total_peliculas': 1, 'duracion_promedio': 104.0}
# {'_id': ['John Ottman'], 'total_peliculas': 1, 'duracion_promedio': 97.0}
# {'_id': ['Sydney Sibilia'], 'total_peliculas': 1, 'duracion_promedio': 100.0}
# {'_id': ['Sean Durkin'], 'total_peliculas': 1, 'duracion_promedio': 102.0}
# {'_id': ['Jean Eustache'], 'total_peliculas': 1, 'duracion_promedio': 210.0}
# {'_id': ['Ezra Edelman'], 'total_peliculas': 1, 'duracion_promedio': 85.0}
# {'_id': ['Nancy Walker'], 'total_peliculas': 1, 'duracion_promedio': 124.0}
# {'_id': ['Pooja Bhatt'], 'total_peliculas': 1, 'duracion_promedio': 120.0}
# {'_id': ['Tareque Masud'], 'total_peliculas': 1, 'duracion_promedio': 95.0}
# {'_id': ['Tyron Montgomery'], 'total_peliculas': 1, 'duracion_promedio': 12.0}
# {'_id': ['Christopher Spencer'], 'total_peliculas': 1, 'duracion_promedio': 138.0}
# {'_id': ['Sally Field'], 'total_peliculas': 1, 'duracion_promedio': 112.0}
# {'_id': ['Chung-ryoul Lee'], 'total_peliculas': 1, 'duracion_promedio': 78.0}
# {'_id': ['Jay Silverman'], 'total_peliculas': 1, 'duracion_promedio': 100.0}
# {'_id': ['Chike Ozah', 'Coodie Simmons'], 'total_peliculas': 1, 'duracion_promedio': 79.0}
# {'_id': ['James Algar', 'Clyde Geronimi', 'Jack Kinney', 'H.C. Potter'], 'total_peliculas': 1, 'duracion_promedio': 70.0}
# {'_id': ['Mike Gabriel', 'Eric Goldberg'], 'total_peliculas': 1, 'duracion_promedio': 81.0}
# {'_id': ['Nitesh Tiwari'], 'total_peliculas': 1, 'duracion_promedio': 155.0}
# {'_id': ['Bènèdicte Galup', 'Michel Ocelot'], 'total_peliculas': 1, 'duracion_promedio': 75.0}
# {'_id': ['Jason Gileno'], 'total_peliculas': 1, 'duracion_promedio': 90.0}
# {'_id': ['Jon Shenk'], 'total_peliculas': 1, 'duracion_promedio': 101.0}
# {'_id': ['Dustin Hoffman'], 'total_peliculas': 1, 'duracion_promedio': 98.0}
# {'_id': ['Desmond Nakano'], 'total_peliculas': 1, 'duracion_promedio': 105.0}
# {'_id': ['Deborah Kampmeier'], 'total_peliculas': 1, 'duracion_promedio': 102.0}
# {'_id': ['Soon-Mi Yoo'], 'total_peliculas': 1, 'duracion_promedio': 72.0}
# {'_id': ['Michael Lee Nirenberg'], 'total_peliculas': 1, 'duracion_promedio': 89.0}
# {'_id': ['Nicolas Provost'], 'total_peliculas': 1, 'duracion_promedio': 95.0}
# {'_id': ['David Jung'], 'total_peliculas': 1, 'duracion_promedio': 83.0}
# {'_id': ['Ben Rivers', 'Ben Russell'], 'total_peliculas': 1, 'duracion_promedio': 98.0}
# {'_id': ['Vuk Rsumovic'], 'total_peliculas': 1, 'duracion_promedio': 95.0}
# {'_id': ['Daniel Gordon'], 'total_peliculas': 1, 'duracion_promedio': 94.0}

# %% [markdown]
# ## 5. Encuentra la distribución de películas basadas en su clasificación MPAA

# %%
result = db.movies.aggregate([
    { '$group': { '_id': '$rated', 'total': { '$sum': 1 } } },
    { '$sort': { 'total': -1 } }
])
for doc in result:
    print(doc)
# Out:
# {'_id': None, 'total': 9894}
# {'_id': 'R', 'total': 5537}
# {'_id': 'PG-13', 'total': 2321}
# {'_id': 'PG', 'total': 1852}
# {'_id': 'APPROVED', 'total': 709}
# {'_id': 'G', 'total': 477}
# {'_id': 'PASSED', 'total': 181}
# {'_id': 'TV-14', 'total': 89}
# {'_id': 'TV-PG', 'total': 76}
# {'_id': 'TV-MA', 'total': 60}
# {'_id': 'TV-G', 'total': 59}
# {'_id': 'GP', 'total': 44}
# {'_id': 'M', 'total': 37}
# {'_id': 'Approved', 'total': 5}
# {'_id': 'AO', 'total': 3}
# {'_id': 'TV-Y7', 'total': 3}
# {'_id': 'Not Rated', 'total': 1}
# {'_id': 'OPEN', 'total': 1}

# %% [markdown]
# ## 6. Encuentra los 3 países que producen el mayor número de películas

# %%
result = db.movies.aggregate([
    { '$unwind': '$countries' },
    { '$group': { '_id': '$countries', 'total': { '$sum': 1 } } },
    { '$sort': { 'total': -1 } },
    { '$limit': 3 }
])
for doc in result:
    print(doc)
# Out:
# {'_id': 'USA', 'total': 10921}
# {'_id': 'UK', 'total': 2652}
# {'_id': 'France', 'total': 2647}

# %% [markdown]
# ## 7. Para películas lanzadas después del 2000, calcula el número promedio de miembros del reparto

# %%
result = db.movies.aggregate([
    { '$match': { 'year': { '$gt': 2000 } } },
    { '$project': { 'cast_count': { '$size': { '$ifNull': ['$cast', []] } } } },
    { '$group': { '_id': None, 'promedio_reparto': { '$avg': '$cast_count' } } }
])
for doc in result:
    print(doc)
# Out:
# {'_id': None, 'promedio_reparto': 3.8223223223223224}

# %% [markdown]
# ## 8. Determina la calificación promedio de IMDb para las películas y su respectivo número de comentarios
# Limité la cantidad de películas porque $lookup es costoso ya que las colecciones de películas y comentarios son grandes.

# %%
result = db.movies.aggregate([
    { '$match': { 'imdb.rating': { '$type': 'number', '$ne': None } } },
    { '$sort': { 'imdb.rating': -1 } },
    { '$limit': 20 },
    { '$lookup': {
        'from': 'comments',
        'localField': '_id',
        'foreignField': 'movie_id',
        'as': 'comentarios'
    }},
    { '$project': { 'title': 1, 'imdb': 1, 'num_comentarios': { '$size': '$comentarios' } } }
])
for doc in result:
    print(doc)
# Out:
# {'_id': ObjectId('573a139ff29313caabd003c4'), 'title': 'Band of Brothers', 'imdb': {'rating': 9.6, 'votes': 183802, 'id': 185906}, 'num_comentarios': 0}
# {'_id': ObjectId('573a13b8f29313caabd4c241'), 'title': 'Planet Earth', 'imdb': {'rating': 9.5, 'votes': 82896, 'id': 795176}, 'num_comentarios': 0}
# {'_id': ObjectId('573a1398f29313caabcebc0b'), 'title': 'The Civil War', 'imdb': {'rating': 9.4, 'votes': 4625, 'id': 98769}, 'num_comentarios': 1}
# {'_id': ObjectId('573a13a3f29313caabd0e77b'), 'title': 'The Civil War', 'imdb': {'rating': 9.4, 'votes': 4624, 'id': 98769}, 'num_comentarios': 0}
# {'_id': ObjectId('573a13f0f29313caabdda542'), 'title': 'A Brave Heart: The Lizzie Velasquez Story', 'imdb': {'rating': 9.4, 'votes': 45, 'id': 3735302}, 'num_comentarios': 0}
# {'_id': ObjectId('573a139ff29313caabd015b9'), 'imdb': {'rating': 9.3, 'votes': 1513145, 'id': 111161}, 'title': 'The Shawshank Redemption', 'num_comentarios': 131}
# {'_id': ObjectId('573a1399f29313caabceeb20'), 'imdb': {'rating': 9.3, 'votes': 1521105, 'id': 111161}, 'title': 'The Shawshank Redemption', 'num_comentarios': 122}
# {'_id': ObjectId('573a13daf29313caabdad25f'), 'title': 'The Real Miyagi', 'imdb': {'rating': 9.3, 'votes': 41, 'id': 2313306}, 'num_comentarios': 0}
# {'_id': ObjectId('573a1397f29313caabce7c4b'), 'title': 'Cosmos', 'imdb': {'rating': 9.3, 'votes': 17174, 'id': 81846}, 'num_comentarios': 0}
# {'_id': ObjectId('573a1396f29313caabce4a9a'), 'imdb': {'rating': 9.2, 'votes': 1038358, 'id': 68646}, 'title': 'The Godfather', 'num_comentarios': 131}
# {'_id': ObjectId('573a13d1f29313caabd8e8c6'), 'title': 'Human Planet', 'imdb': {'rating': 9.2, 'votes': 9057, 'id': 1806234}, 'num_comentarios': 0}
# {'_id': ObjectId('573a13d6f29313caabda05f3'), 'title': 'Frozen Planet', 'imdb': {'rating': 9.2, 'votes': 5903, 'id': 2092588}, 'num_comentarios': 1}
# {'_id': ObjectId('573a1398f29313caabcea40a'), 'title': 'The Decalogue', 'imdb': {'rating': 9.2, 'votes': 10958, 'id': 92337}, 'num_comentarios': 0}
# {'_id': ObjectId('573a13f0f29313caabdd9d6e'), 'title': 'Over the Garden Wall', 'imdb': {'rating': 9.2, 'votes': 4139, 'id': 3718778}, 'num_comentarios': 1}
# {'_id': ObjectId('573a13a7f29313caabd1a365'), 'title': 'The Blue Planet', 'imdb': {'rating': 9.2, 'votes': 7093, 'id': 296310}, 'num_comentarios': 0}
# {'_id': ObjectId('573a13c9f29313caabd7a481'), 'title': 'Life', 'imdb': {'rating': 9.2, 'votes': 16807, 'id': 1533395}, 'num_comentarios': 0}
# {'_id': ObjectId('573a1397f29313caabce7621'), 'title': 'Hollywood', 'imdb': {'rating': 9.1, 'votes': 511, 'id': 80230}, 'num_comentarios': 0}
# {'_id': ObjectId('573a1396f29313caabce557f'), 'imdb': {'rating': 9.1, 'votes': 700857, 'id': 71562}, 'title': 'The Godfather: Part II', 'num_comentarios': 0}
# {'_id': ObjectId('573a1399f29313caabcee1aa'), 'title': 'Baseball', 'imdb': {'rating': 9.1, 'votes': 2460, 'id': 108700}, 'num_comentarios': 0}
# {'_id': ObjectId('573a1399f29313caabceeead'), 'title': 'Pride and Prejudice', 'imdb': {'rating': 9.1, 'votes': 45725, 'id': 112130}, 'num_comentarios': 0}

# %% [markdown]
# ## 9. Encuentra el número total de películas en las que cada usuario ha comentado

# %%
result = db.comments.aggregate([
    { '$group': { '_id': '$email', 'total_peliculas': { '$addToSet': '$movie_id' } } },
    { '$project': { 'usuario': '$_id', 'total_peliculas': { '$size': '$total_peliculas' }, '_id': 0 } },
    { '$sort': { 'total_peliculas': -1 } }
])
for doc in result:
    print(doc)
# Out:
# {'usuario': 'roger_ashton-griffiths@gameofthron.es', 'total_peliculas': 219}
# {'usuario': 'nathalie_emmanuel@gameofthron.es', 'total_peliculas': 197}
# {'usuario': 'paul_kaye@gameofthron.es', 'total_peliculas': 197}
# {'usuario': 'sophie_turner@gameofthron.es', 'total_peliculas': 197}
# {'usuario': 'denise_bryant@fakegmail.com', 'total_peliculas': 196}
# {'usuario': 'jonathan_pryce@gameofthron.es', 'total_peliculas': 194}
# {'usuario': 'robert_jordan@fakegmail.com', 'total_peliculas': 194}
# {'usuario': 'ron_donachie@gameofthron.es', 'total_peliculas': 193}
# {'usuario': 'dean-charles_chapman@gameofthron.es', 'total_peliculas': 193}
# {'usuario': 'nicholas_johnson@fakegmail.com', 'total_peliculas': 193}
# {'usuario': 'richard_dormer@gameofthron.es', 'total_peliculas': 192}
# {'usuario': 'liam_cunningham@gameofthron.es', 'total_peliculas': 192}
# {'usuario': 'luke_barnes@gameofthron.es', 'total_peliculas': 188}
# {'usuario': 'andrea_le@fakegmail.com', 'total_peliculas': 187}
# {'usuario': 'edward_barrett@fakegmail.com', 'total_peliculas': 187}
# {'usuario': 'john_rice@fakegmail.com', 'total_peliculas': 187}
# {'usuario': 'elizabeth_wiggins@fakegmail.com', 'total_peliculas': 187}
# {'usuario': 'aidan_gillen@gameofthron.es', 'total_peliculas': 186}
# {'usuario': 'donna_smith@fakegmail.com', 'total_peliculas': 186}
# {'usuario': 'bradley_brooks@fakegmail.com', 'total_peliculas': 185}
# {'usuario': 'paul_bailey@fakegmail.com', 'total_peliculas': 184}
# {'usuario': 'yvette_roth@fakegmail.com', 'total_peliculas': 184}
# {'usuario': 'hafthór_júlíus_björnsson@gameofthron.es', 'total_peliculas': 184}
# {'usuario': 'maisie_williams@gameofthron.es', 'total_peliculas': 184}
# {'usuario': 'blake_sellers@fakegmail.com', 'total_peliculas': 183}
# {'usuario': 'anthony_hurst@fakegmail.com', 'total_peliculas': 183}
# {'usuario': 'michael_day@fakegmail.com', 'total_peliculas': 183}
# {'usuario': 'nikolaj_coster-waldau@gameofthron.es', 'total_peliculas': 183}
# {'usuario': 'john_bishop@fakegmail.com', 'total_peliculas': 183}
# {'usuario': 'roxanne_mckee@gameofthron.es', 'total_peliculas': 182}
# {'usuario': 'kathryn_sosa@fakegmail.com', 'total_peliculas': 182}
# {'usuario': 'catherine_romero@fakegmail.com', 'total_peliculas': 182}
# {'usuario': 'megan_turner@fakegmail.com', 'total_peliculas': 182}
# {'usuario': 'michael_mcelhatton@gameofthron.es', 'total_peliculas': 182}
# {'usuario': 'barbara_gonzalez@fakegmail.com', 'total_peliculas': 181}
# {'usuario': 'julian_glover@gameofthron.es', 'total_peliculas': 181}
# {'usuario': 'desiree_pierce@fakegmail.com', 'total_peliculas': 181}
# {'usuario': 'jason_momoa@gameofthron.es', 'total_peliculas': 181}
# {'usuario': 'mrs._ariana_nunez@fakegmail.com', 'total_peliculas': 181}
# {'usuario': 'keith_phillips@fakegmail.com', 'total_peliculas': 181}
# {'usuario': 'javier_smith@fakegmail.com', 'total_peliculas': 180}
# {'usuario': 'justin_williams@fakegmail.com', 'total_peliculas': 180}
# {'usuario': 'kristen_schmidt@fakegmail.com', 'total_peliculas': 180}
# {'usuario': 'gwendoline_christie@gameofthron.es', 'total_peliculas': 180}
# {'usuario': 'joe_dempsie@gameofthron.es', 'total_peliculas': 180}
# {'usuario': 'peter_vaughan@gameofthron.es', 'total_peliculas': 180}
# {'usuario': 'kristian_nairn@gameofthron.es', 'total_peliculas': 179}
# {'usuario': 'iain_glen@gameofthron.es', 'total_peliculas': 179}
# {'usuario': 'ben_crompton@gameofthron.es', 'total_peliculas': 179}
# {'usuario': 'kenneth_chandler@fakegmail.com', 'total_peliculas': 179}
# {'usuario': 'anthony_thompson@fakegmail.com', 'total_peliculas': 178}
# {'usuario': 'alfie_allen@gameofthron.es', 'total_peliculas': 178}
# {'usuario': 'megan_richards@fakegmail.com', 'total_peliculas': 178}
# {'usuario': 'phillip_collins@fakegmail.com', 'total_peliculas': 178}
# {'usuario': 'richard_schmidt@fakegmail.com', 'total_peliculas': 178}
# {'usuario': 'anthony_smith@fakegmail.com', 'total_peliculas': 177}
# {'usuario': 'teresa_thomas@fakegmail.com', 'total_peliculas': 177}
# {'usuario': 'april_cole@fakegmail.com', 'total_peliculas': 177}
# {'usuario': 'brandon_hardy@fakegmail.com', 'total_peliculas': 177}
# {'usuario': 'mercedes_tyler@fakegmail.com', 'total_peliculas': 177}
# {'usuario': 'melissa_young@fakegmail.com', 'total_peliculas': 177}
# {'usuario': 'donald_sumpter@gameofthron.es', 'total_peliculas': 176}
# {'usuario': 'sean_bean@gameofthron.es', 'total_peliculas': 176}
# {'usuario': 'faye_marsay@gameofthron.es', 'total_peliculas': 176}
# {'usuario': 'richard_davis@fakegmail.com', 'total_peliculas': 176}
# {'usuario': 'denise_davidson@fakegmail.com', 'total_peliculas': 175}
# {'usuario': 'ian_beattie@gameofthron.es', 'total_peliculas': 175}
# {'usuario': 'mary_mitchell@fakegmail.com', 'total_peliculas': 175}
# {'usuario': 'kerry_ingram@gameofthron.es', 'total_peliculas': 175}
# {'usuario': 'nichole_miller@fakegmail.com', 'total_peliculas': 175}
# {'usuario': 'rory_mccann@gameofthron.es', 'total_peliculas': 175}
# {'usuario': 'natalia_tena@gameofthron.es', 'total_peliculas': 175}
# {'usuario': 'diana_rigg@gameofthron.es', 'total_peliculas': 175}
# {'usuario': 'paula_sullivan@fakegmail.com', 'total_peliculas': 174}
# {'usuario': 'donna_russell@fakegmail.com', 'total_peliculas': 174}
# {'usuario': 'kelsey_smith@fakegmail.com', 'total_peliculas': 174}
# {'usuario': 'taylor_hill@fakegmail.com', 'total_peliculas': 173}
# {'usuario': 'cameron_duran@fakegmail.com', 'total_peliculas': 173}
# {'usuario': 'amy_phillips@fakegmail.com', 'total_peliculas': 173}
# {'usuario': 'richard_madden@gameofthron.es', 'total_peliculas': 173}
# {'usuario': 'art_parkinson@gameofthron.es', 'total_peliculas': 173}
# {'usuario': 'melissa_jones@fakegmail.com', 'total_peliculas': 173}
# {'usuario': 'kristofer_hivju@gameofthron.es', 'total_peliculas': 173}
# {'usuario': 'greg_powell@fakegmail.com', 'total_peliculas': 172}
# {'usuario': 'sarah_lewis@fakegmail.com', 'total_peliculas': 172}
# {'usuario': 'garrett_obrien@fakegmail.com', 'total_peliculas': 172}
# {'usuario': 'michelle_fairley@gameofthron.es', 'total_peliculas': 172}
# {'usuario': 'thomas_morris@fakegmail.com', 'total_peliculas': 172}
# {'usuario': 'harry_lloyd@gameofthron.es', 'total_peliculas': 172}
# {'usuario': 'oona_chaplin@gameofthron.es', 'total_peliculas': 172}
# {'usuario': 'thomas_green@fakegmail.com', 'total_peliculas': 172}
# {'usuario': 'indira_varma@gameofthron.es', 'total_peliculas': 171}
# {'usuario': 'rose_leslie@gameofthron.es', 'total_peliculas': 171}
# {'usuario': 'christian_williams@fakegmail.com', 'total_peliculas': 171}
# {'usuario': 'heather_leonard@fakegmail.com', 'total_peliculas': 171}
# {'usuario': 'eugene_simon@gameofthron.es', 'total_peliculas': 171}
# {'usuario': 'jason_hernandez@fakegmail.com', 'total_peliculas': 171}
# {'usuario': 'conleth_hill@gameofthron.es', 'total_peliculas': 171}
# {'usuario': 'tara_fitzgerald@gameofthron.es', 'total_peliculas': 171}
# {'usuario': 'emilia_clarke@gameofthron.es', 'total_peliculas': 171}
# {'usuario': 'lori_blankenship@fakegmail.com', 'total_peliculas': 170}
# {'usuario': 'jacob_anderson@gameofthron.es', 'total_peliculas': 170}
# {'usuario': 'patricia_good@fakegmail.com', 'total_peliculas': 170}
# {'usuario': 'julia_nichols@fakegmail.com', 'total_peliculas': 170}
# {'usuario': 'mark_addy@gameofthron.es', 'total_peliculas': 170}
# {'usuario': 'jonathon_mccullough@fakegmail.com', 'total_peliculas': 170}
# {'usuario': 'jack_gleeson@gameofthron.es', 'total_peliculas': 170}
# {'usuario': 'iwan_rheon@gameofthron.es', 'total_peliculas': 170}
# {'usuario': 'daniel_simmons@fakegmail.com', 'total_peliculas': 170}
# {'usuario': 'victoria_sanders@fakegmail.com', 'total_peliculas': 170}
# {'usuario': 'esme_bianco@gameofthron.es', 'total_peliculas': 169}
# {'usuario': 'james_cosmo@gameofthron.es', 'total_peliculas': 169}
# {'usuario': 'brenda_martin@fakegmail.com', 'total_peliculas': 169}
# {'usuario': 'kimberly_gates@fakegmail.com', 'total_peliculas': 169}
# {'usuario': 'thomas_buckley@fakegmail.com', 'total_peliculas': 169}
# {'usuario': 'lisa_rasmussen@fakegmail.com', 'total_peliculas': 168}
# {'usuario': 'patrick_knight@fakegmail.com', 'total_peliculas': 168}
# {'usuario': 'tom_wlaschiha@gameofthron.es', 'total_peliculas': 168}
# {'usuario': 'daniel_portman@gameofthron.es', 'total_peliculas': 167}
# {'usuario': 'connie_barton@fakegmail.com', 'total_peliculas': 167}
# {'usuario': 'anthony_cline@fakegmail.com', 'total_peliculas': 167}
# {'usuario': 'ashlee_hart@fakegmail.com', 'total_peliculas': 167}
# {'usuario': 'lisa_russo@fakegmail.com', 'total_peliculas': 167}
# {'usuario': 'jerome_flynn@gameofthron.es', 'total_peliculas': 167}
# {'usuario': 'theresa_holmes@fakegmail.com', 'total_peliculas': 167}
# {'usuario': 'ian_gelder@gameofthron.es', 'total_peliculas': 166}
# {'usuario': 'charles_dance@gameofthron.es', 'total_peliculas': 166}
# {'usuario': 'thomas_brodie-sangster@gameofthron.es', 'total_peliculas': 166}
# {'usuario': 'shawn_mccormick@fakegmail.com', 'total_peliculas': 166}
# {'usuario': 'karina_martin@fakegmail.com', 'total_peliculas': 166}
# {'usuario': 'ben_hawkey@gameofthron.es', 'total_peliculas': 165}
# {'usuario': 'finn_jones@gameofthron.es', 'total_peliculas': 165}
# {'usuario': 'natalie_dormer@gameofthron.es', 'total_peliculas': 165}
# {'usuario': 'michael_moore@fakegmail.com', 'total_peliculas': 165}
# {'usuario': 'jordan_medina@fakegmail.com', 'total_peliculas': 165}
# {'usuario': 'ronald_cox@fakegmail.com', 'total_peliculas': 165}
# {'usuario': 'amy_ramirez@fakegmail.com', 'total_peliculas': 165}
# {'usuario': "brenock_o'connor@gameofthron.es", 'total_peliculas': 164}
# {'usuario': 'jason_smith@fakegmail.com', 'total_peliculas': 164}
# {'usuario': 'ellie_kendrick@gameofthron.es', 'total_peliculas': 164}
# {'usuario': 'josef_altin@gameofthron.es', 'total_peliculas': 164}
# {'usuario': 'ian_mcelhinney@gameofthron.es', 'total_peliculas': 164}
# {'usuario': 'kit_harington@gameofthron.es', 'total_peliculas': 164}
# {'usuario': 'brian_fortune@gameofthron.es', 'total_peliculas': 164}
# {'usuario': 'jeffrey_roberts@fakegmail.com', 'total_peliculas': 164}
# {'usuario': 'lori_franklin@fakegmail.com', 'total_peliculas': 164}
# {'usuario': 'john_bradley-west@gameofthron.es', 'total_peliculas': 164}
# {'usuario': 'gemma_whelan@gameofthron.es', 'total_peliculas': 163}
# {'usuario': 'john_roman@fakegmail.com', 'total_peliculas': 163}
# {'usuario': 'mark_stanley@gameofthron.es', 'total_peliculas': 163}
# {'usuario': 'morgan_smith@fakegmail.com', 'total_peliculas': 163}
# {'usuario': 'deborah_kennedy@fakegmail.com', 'total_peliculas': 163}
# {'usuario': 'lisa_silva@fakegmail.com', 'total_peliculas': 163}
# {'usuario': 'blake_fitzgerald@fakegmail.com', 'total_peliculas': 162}
# {'usuario': 'victor_fleming@fakegmail.com', 'total_peliculas': 162}
# {'usuario': 'taylor_scott@fakegmail.com', 'total_peliculas': 162}
# {'usuario': 'amrita_acharia@gameofthron.es', 'total_peliculas': 161}
# {'usuario': 'nell_tiger_free@gameofthron.es', 'total_peliculas': 161}
# {'usuario': 'joshua_kent@fakegmail.com', 'total_peliculas': 161}
# {'usuario': 'isaac_hempstead_wright@gameofthron.es', 'total_peliculas': 161}
# {'usuario': 'yolanda_owen@fakegmail.com', 'total_peliculas': 161}
# {'usuario': 'nicholas_webster@fakegmail.com', 'total_peliculas': 161}
# {'usuario': 'owen_teale@gameofthron.es', 'total_peliculas': 161}
# {'usuario': 'anton_lesser@gameofthron.es', 'total_peliculas': 161}
# {'usuario': 'jose_hall@fakegmail.com', 'total_peliculas': 161}
# {'usuario': 'michiel_huisman@gameofthron.es', 'total_peliculas': 160}
# {'usuario': 'hannah_murray@gameofthron.es', 'total_peliculas': 160}
# {'usuario': 'ms._cathy_miller@fakegmail.com', 'total_peliculas': 160}
# {'usuario': 'carice_van_houten@gameofthron.es', 'total_peliculas': 160}
# {'usuario': 'lena_headey@gameofthron.es', 'total_peliculas': 159}
# {'usuario': 'dominic_carter@gameofthron.es', 'total_peliculas': 158}
# {'usuario': 'sibel_kekilli@gameofthron.es', 'total_peliculas': 157}
# {'usuario': 'eric_navarro@fakegmail.com', 'total_peliculas': 157}
# {'usuario': 'peter_dinklage@gameofthron.es', 'total_peliculas': 157}
# {'usuario': 'christopher_robinson@fakegmail.com', 'total_peliculas': 156}
# {'usuario': 'emily_ellis@fakegmail.com', 'total_peliculas': 156}
# {'usuario': 'jennifer_frazier@fakegmail.com', 'total_peliculas': 156}
# {'usuario': 'stephen_dillane@gameofthron.es', 'total_peliculas': 155}
# {'usuario': 'jamie_santana@fakegmail.com', 'total_peliculas': 154}
# {'usuario': 'jerry_cabrera@fakegmail.com', 'total_peliculas': 153}
# {'usuario': 'michael_condron@gameofthron.es', 'total_peliculas': 153}
# {'usuario': 'victor_patel@fakegmail.com', 'total_peliculas': 147}
# {'usuario': 'connie_johnson@fakegmail.com', 'total_peliculas': 145}
# {'usuario': 'catherine_diaz@fakegmail.com', 'total_peliculas': 1}
# {'usuario': 'cindy_cameron@fakegmail.com', 'total_peliculas': 1}
# {'usuario': 'joseph_tran@fakegmail.com', 'total_peliculas': 1}
# {'usuario': 'james_conner@fakegmail.com', 'total_peliculas': 1}
# {'usuario': 'sharon_dunn@fakegmail.com', 'total_peliculas': 1}
# {'usuario': 'anthony_cooley@fakegmail.com', 'total_peliculas': 1}
# {'usuario': 'peggy_heath@fakegmail.com', 'total_peliculas': 1}
# {'usuario': 'jared_mitchell@fakegmail.com', 'total_peliculas': 1}
# {'usuario': 'jonathan_ingram@fakegmail.com', 'total_peliculas': 1}
# {'usuario': 'tyler_chan@fakegmail.com', 'total_peliculas': 1}
# {'usuario': 'terri_berg@fakegmail.com', 'total_peliculas': 1}
# {'usuario': 'craig_smith@fakegmail.com', 'total_peliculas': 1}
# {'usuario': 'edward_patton@fakegmail.com', 'total_peliculas': 1}
# {'usuario': 'richard_matthews@fakegmail.com', 'total_peliculas': 1}
# {'usuario': 'aaron_church@fakegmail.com', 'total_peliculas': 1}
# {'usuario': 'robin_harrington@fakegmail.com', 'total_peliculas': 1}
# {'usuario': 'janet_clark@fakegmail.com', 'total_peliculas': 1}
# {'usuario': 'lorraine_moon@fakegmail.com', 'total_peliculas': 1}
# {'usuario': 'amanda_delgado@fakegmail.com', 'total_peliculas': 1}
# {'usuario': 'karen_schultz@fakegmail.com', 'total_peliculas': 1}
# {'usuario': 'michelle_norris@fakegmail.com', 'total_peliculas': 1}
# {'usuario': 'lauren_carr@fakegmail.com', 'total_peliculas': 1}
# {'usuario': 'ricky_jones@fakegmail.com', 'total_peliculas': 1}
# {'usuario': 'james_salazar@fakegmail.com', 'total_peliculas': 1}
# {'usuario': 'elizabeth_delacruz@fakegmail.com', 'total_peliculas': 1}
# {'usuario': 'karen_johnson@fakegmail.com', 'total_peliculas': 1}
# {'usuario': 'vickie_lopez@fakegmail.com', 'total_peliculas': 1}
# {'usuario': 'melissa_walters@fakegmail.com', 'total_peliculas': 1}
# {'usuario': 'lisa_rivers@fakegmail.com', 'total_peliculas': 1}
# {'usuario': 'jim_olson@fakegmail.com', 'total_peliculas': 1}
# {'usuario': 'sue_blankenship@fakegmail.com', 'total_peliculas': 1}
# {'usuario': 'anthony_mayo@fakegmail.com', 'total_peliculas': 1}
# {'usuario': 'jeffrey_richardson@fakegmail.com', 'total_peliculas': 1}
# {'usuario': 'kaitlin_mccoy@fakegmail.com', 'total_peliculas': 1}
# {'usuario': 'lindsay_gutierrez@fakegmail.com', 'total_peliculas': 1}
# {'usuario': 'amanda_jordan@fakegmail.com', 'total_peliculas': 1}
# {'usuario': 'jacqueline_bright@fakegmail.com', 'total_peliculas': 1}
# {'usuario': 'ryan_fisher@fakegmail.com', 'total_peliculas': 1}
# {'usuario': 'emily_walters@fakegmail.com', 'total_peliculas': 1}
# {'usuario': 'amy_williams@fakegmail.com', 'total_peliculas': 1}
# {'usuario': 'susan_johnson@fakegmail.com', 'total_peliculas': 1}
# {'usuario': 'kenneth_gross@fakegmail.com', 'total_peliculas': 1}
# {'usuario': 'deborah_perez@fakegmail.com', 'total_peliculas': 1}
# {'usuario': 'taylor_williams@fakegmail.com', 'total_peliculas': 1}
# {'usuario': 'timothy_mason@fakegmail.com', 'total_peliculas': 1}
# {'usuario': 'scott_melton@fakegmail.com', 'total_peliculas': 1}
# {'usuario': 'chad_zimmerman@fakegmail.com', 'total_peliculas': 1}
# {'usuario': 'shannon_sellers@fakegmail.com', 'total_peliculas': 1}
# {'usuario': 'anna_jones@fakegmail.com', 'total_peliculas': 1}
# {'usuario': 'kelsey_english@fakegmail.com', 'total_peliculas': 1}
# {'usuario': 'amanda_hill@fakegmail.com', 'total_peliculas': 1}

# %% [markdown]
# ## 10. Encuentra películas del género 'Western' y sus respectivos comentarios antes del '2020-01-01'

# %%
from datetime import datetime
fecha_limite = datetime(2020, 1, 1)
result = db.movies.aggregate([
    { '$match': { 'genres': 'Western' } },
    { '$lookup': {
        'from': 'comments',
        'localField': '_id',
        'foreignField': 'movie_id',
        'as': 'comentarios'
    } },
    { '$project': { 'title': 1, 'comentarios': { '$filter': { 'input': '$comentarios', 'as': 'comentario', 'cond': { '$lt': ['$$comentario.date', fecha_limite] } } } } }
])
for doc in result:
    print(doc)
# Out:
# {'_id': ObjectId('573a1390f29313caabcd42e8'), 'title': 'The Great Train Robbery', 'comentarios': []}
# {'_id': ObjectId('573a1390f29313caabcd6377'), 'title': 'Wild and Woolly', 'comentarios': []}
# {'_id': ObjectId('573a1391f29313caabcd7bc3'), 'title': 'The Iron Horse', 'comentarios': []}
# {'_id': ObjectId('573a1391f29313caabcd7e6e'), 'title': 'Clash of the Wolves', 'comentarios': []}
# {'_id': ObjectId('573a1391f29313caabcd8f66'), 'title': 'In Old Arizona', 'comentarios': []}
# {'_id': ObjectId('573a1391f29313caabcd91dc'), 'title': 'The Big Trail', 'comentarios': []}
# {'_id': ObjectId('573a1391f29313caabcd95f6'), 'title': 'Cimarron', 'comentarios': [{'_id': ObjectId('5a9427648b0beebeb6957ce5'), 'name': 'Tommen Baratheon', 'email': 'dean-charles_chapman@gameofthron.es', 'movie_id': ObjectId('573a1391f29313caabcd95f6'), 'text': 'Eaque quia a fuga non. Possimus facere natus omnis. Perspiciatis magnam est illo ipsum ullam at reprehenderit. Quidem distinctio sapiente eos velit mollitia iure qui.', 'date': datetime.datetime(2001, 4, 2, 4, 43, 49)}]}
# {'_id': ObjectId('573a1392f29313caabcda654'), 'title': 'Viva Villa!', 'comentarios': [{'_id': ObjectId('5a9427648b0beebeb6957efb'), 'name': 'Osha', 'email': 'natalia_tena@gameofthron.es', 'movie_id': ObjectId('573a1392f29313caabcda654'), 'text': 'Voluptatem quae pariatur ut rem laudantium. Quasi sed iste ipsum laborum. Quia placeat qui vero adipisci.', 'date': datetime.datetime(1973, 2, 23, 15, 15, 58)}]}
# {'_id': ObjectId('573a1392f29313caabcdadb7'), 'title': 'Der Kaiser von Kalifornien', 'comentarios': []}
# {'_id': ObjectId('573a1392f29313caabcdb82f'), 'title': 'Of Human Hearts', 'comentarios': []}
# {'_id': ObjectId('573a1392f29313caabcdbaef'), 'title': 'Destry Rides Again', 'comentarios': []}
# {'_id': ObjectId('573a1393f29313caabcdc2e2'), 'title': 'The Westerner', 'comentarios': []}
# {'_id': ObjectId('573a1393f29313caabcdd852'), 'title': 'My Darling Clementine', 'comentarios': [{'_id': ObjectId('5a9427648b0beebeb6958765'), 'name': 'Maester Luwin', 'email': 'donald_sumpter@gameofthron.es', 'movie_id': ObjectId('573a1393f29313caabcdd852'), 'text': 'Fugiat deleniti accusamus totam accusantium dolores maxime porro. Error praesentium ipsa magnam sequi perferendis. Accusantium placeat assumenda deleniti vel corrupti dignissimos natus.', 'date': datetime.datetime(1976, 9, 1, 12, 57, 9)}]}
# {'_id': ObjectId('573a1393f29313caabcdda18'), 'title': 'Bowery Buckaroos', 'comentarios': [{'_id': ObjectId('5a9427648b0beebeb69587bd'), 'name': 'Tormund Giantsbane', 'email': 'kristofer_hivju@gameofthron.es', 'movie_id': ObjectId('573a1393f29313caabcdda18'), 'text': 'Commodi eum ipsa aliquid nisi officiis. Recusandae nemo rem natus magni nemo sit aliquid consequatur. Explicabo nemo expedita magni animi atque at mollitia.', 'date': datetime.datetime(1977, 3, 2, 18, 10, 37)}]}
# {'_id': ObjectId('573a1393f29313caabcddea3'), 'title': 'Fort Apache', 'comentarios': [{'_id': ObjectId('5a9427648b0beebeb6958893'), 'name': 'Lori Blankenship', 'email': 'lori_blankenship@fakegmail.com', 'movie_id': ObjectId('573a1393f29313caabcddea3'), 'text': 'Inventore odit ratione ipsum placeat eius. Velit accusamus distinctio quae ad quis inventore quas earum. A alias impedit facilis sit dolor.', 'date': datetime.datetime(2005, 4, 29, 12, 12, 52)}]}
# {'_id': ObjectId('573a1393f29313caabcddfcf'), 'title': 'The Paleface', 'comentarios': []}
# {'_id': ObjectId('573a1393f29313caabcde0f0'), 'title': 'Yellow Sky', 'comentarios': []}
# {'_id': ObjectId('573a1394f29313caabcde60a'), 'title': 'Broken Arrow', 'comentarios': []}
# {'_id': ObjectId('573a1394f29313caabcde681'), 'title': "Devil's Doorway", 'comentarios': []}
# {'_id': ObjectId('573a1394f29313caabcde87e'), 'title': 'Rio Grande', 'comentarios': []}
# {'_id': ObjectId('573a1394f29313caabcde95b'), 'title': "Winchester '73", 'comentarios': []}
# {'_id': ObjectId('573a1394f29313caabcdee62'), 'title': 'The Big Sky', 'comentarios': []}
# {'_id': ObjectId('573a1394f29313caabcdef7f'), 'title': 'High Noon', 'comentarios': []}
# {'_id': ObjectId('573a1394f29313caabcdf06b'), 'title': 'The Naked Spur', 'comentarios': []}
# {'_id': ObjectId('573a1394f29313caabcdf2ee'), 'title': 'Calamity Jane', 'comentarios': []}
# {'_id': ObjectId('573a1394f29313caabcdf2f6'), 'title': 'Carne de horca', 'comentarios': [{'_id': ObjectId('5a9427648b0beebeb6958e0a'), 'name': 'Shae', 'email': 'sibel_kekilli@gameofthron.es', 'movie_id': ObjectId('573a1394f29313caabcdf2f6'), 'text': 'Cum incidunt asperiores fugiat veniam atque pariatur quo. Sapiente voluptatibus dolor perferendis non. Et aliquid iure eum error repudiandae quas quo.', 'date': datetime.datetime(1992, 1, 9, 12, 43, 46)}]}
# {'_id': ObjectId('573a1394f29313caabcdf5aa'), 'title': 'Shane', 'comentarios': []}
# {'_id': ObjectId('573a1394f29313caabcdf61c'), 'title': 'The Sun Shines Bright', 'comentarios': []}
# {'_id': ObjectId('573a1394f29313caabcdf621'), 'title': 'Carne de horca', 'comentarios': []}
# {'_id': ObjectId('573a1394f29313caabcdf7b6'), 'title': 'Broken Lance', 'comentarios': []}
# {'_id': ObjectId('573a1394f29313caabcdfd4c'), 'title': 'The Kentuckian', 'comentarios': [{'_id': ObjectId('5a9427648b0beebeb6959021'), 'name': 'Brenda Martin', 'email': 'brenda_martin@fakegmail.com', 'movie_id': ObjectId('573a1394f29313caabcdfd4c'), 'text': 'Id incidunt molestiae veniam voluptate esse necessitatibus doloribus. Temporibus distinctio corporis rem magni. Perferendis delectus facere reiciendis corporis praesentium necessitatibus corporis.', 'date': datetime.datetime(2002, 4, 8, 11, 51, 47)}, {'_id': ObjectId('5a9427648b0beebeb6959022'), 'name': 'Janos Slynt', 'email': 'dominic_carter@gameofthron.es', 'movie_id': ObjectId('573a1394f29313caabcdfd4c'), 'text': 'Facere dolore aperiam et unde. Alias ea iste nihil similique. Ex eligendi officiis architecto voluptates architecto. Rerum sint sint suscipit modi cum. Iure laborum ipsam odio.', 'date': datetime.datetime(1994, 8, 18, 7, 47, 24)}]}
# {'_id': ObjectId('573a1394f29313caabcdfdf9'), 'title': 'Oklahoma!', 'comentarios': [{'_id': ObjectId('5a9427648b0beebeb69591e7'), 'name': 'Maester Luwin', 'email': 'donald_sumpter@gameofthron.es', 'movie_id': ObjectId('573a1394f29313caabcdfdf9'), 'text': 'In corrupti quis neque aliquam. Omnis non error dicta mollitia magni eos. Occaecati esse consequuntur expedita nihil voluptatum eos tenetur. Alias numquam eos quae necessitatibus sed sed.', 'date': datetime.datetime(1985, 12, 22, 10, 28, 23)}]}
# {'_id': ObjectId('573a1394f29313caabcdff62'), 'title': 'The Violent Men', 'comentarios': []}
# {'_id': ObjectId('573a1394f29313caabce02ac'), 'title': 'The Rainmaker', 'comentarios': [{'_id': ObjectId('5a9427648b0beebeb69592e1'), 'name': 'Gregor Clegane', 'email': 'hafthór_júlíus_björnsson@gameofthron.es', 'movie_id': ObjectId('573a1394f29313caabce02ac'), 'text': 'Sapiente deserunt provident consequatur eligendi. Mollitia nobis consequuntur ducimus autem delectus blanditiis commodi non. Voluptate quo sapiente deleniti beatae nobis libero id.', 'date': datetime.datetime(2015, 12, 20, 5, 1, 46)}]}
# {'_id': ObjectId('573a1394f29313caabce0302'), 'title': 'The Searchers', 'comentarios': [{'_id': ObjectId('5a9427648b0beebeb69592e8'), 'name': 'Christian Williams', 'email': 'christian_williams@fakegmail.com', 'movie_id': ObjectId('573a1394f29313caabce0302'), 'text': 'Fugiat dolores qui ratione a quibusdam culpa enim. Natus laborum recusandae facere animi corrupti. Eveniet commodi error eveniet voluptatibus provident modi adipisci illo.', 'date': datetime.datetime(1995, 5, 29, 6, 11, 50)}]}
# {'_id': ObjectId('573a1394f29313caabce031a'), 'title': 'Seven Men from Now', 'comentarios': [{'_id': ObjectId('5a9427648b0beebeb69592f6'), 'name': 'Shawn Mccormick', 'email': 'shawn_mccormick@fakegmail.com', 'movie_id': ObjectId('573a1394f29313caabce031a'), 'text': 'Reprehenderit odio neque officiis facere accusantium nam debitis voluptatem. Rem expedita quibusdam nihil consectetur nulla. Ullam voluptates cum reprehenderit delectus.', 'date': datetime.datetime(1976, 10, 22, 12, 46, 41)}]}
# {'_id': ObjectId('573a1394f29313caabce0484'), 'title': '3:10 to Yuma', 'comentarios': []}
# {'_id': ObjectId('573a1394f29313caabce05e0'), 'title': 'Gunfight at the O.K. Corral', 'comentarios': []}
# {'_id': ObjectId('573a1394f29313caabce06f9'), 'title': 'Night Passage', 'comentarios': []}
# {'_id': ObjectId('573a1394f29313caabce081e'), 'title': 'The Tall T', 'comentarios': []}
# {'_id': ObjectId('573a1394f29313caabce0845'), 'title': 'The Tin Star', 'comentarios': []}
# {'_id': ObjectId('573a1394f29313caabce0993'), 'title': 'The Bravados', 'comentarios': [{'_id': ObjectId('5a9427648b0beebeb695945c'), 'name': 'Margaery Tyrell', 'email': 'natalie_dormer@gameofthron.es', 'movie_id': ObjectId('573a1394f29313caabce0993'), 'text': 'Eius ex earum dolor mollitia at incidunt error. Delectus assumenda dolorem vero porro exercitationem excepturi nam illo.', 'date': datetime.datetime(1990, 9, 15, 4, 53, 21)}]}
# {'_id': ObjectId('573a1394f29313caabce09f0'), 'title': 'Cowboy', 'comentarios': []}
# {'_id': ObjectId('573a1394f29313caabce0c56'), 'title': 'Ride a Crooked Trail', 'comentarios': [{'_id': ObjectId('5a9427648b0beebeb69594fc'), 'name': 'Lori Blankenship', 'email': 'lori_blankenship@fakegmail.com', 'movie_id': ObjectId('573a1394f29313caabce0c56'), 'text': 'Quis id qui asperiores. Illo eveniet neque eos ad.\nEaque possimus laboriosam labore. Laborum nobis consequatur commodi odit quasi iste consequatur. Ex recusandae id minima ex impedit odio.', 'date': datetime.datetime(1987, 6, 2, 8, 37, 33)}, {'_id': ObjectId('5a9427648b0beebeb69594fd'), 'name': 'Sansa Stark', 'email': 'sophie_turner@gameofthron.es', 'movie_id': ObjectId('573a1394f29313caabce0c56'), 'text': 'Ab consequatur iusto ipsa saepe dolorum esse. Incidunt officiis laborum id aut nam sed quas. Consectetur laboriosam fuga vero tenetur dignissimos dicta dolores in.', 'date': datetime.datetime(2009, 10, 15, 12, 11, 21)}]}
# {'_id': ObjectId('573a1394f29313caabce0c83'), 'title': 'The Sheriff of Fractured Jaw', 'comentarios': []}
# {'_id': ObjectId('573a1394f29313caabce0c85'), 'title': 'The Sheepman', 'comentarios': []}
# {'_id': ObjectId('573a1394f29313caabce0f42'), 'title': 'The Hanging Tree', 'comentarios': []}
# {'_id': ObjectId('573a1394f29313caabce0f53'), 'title': 'The Horse Soldiers', 'comentarios': []}
# {'_id': ObjectId('573a1394f29313caabce0fb4'), 'title': 'Last Train from Gun Hill', 'comentarios': [{'_id': ObjectId('5a9427648b0beebeb69595a5'), 'name': 'Daario Naharis', 'email': 'michiel_huisman@gameofthron.es', 'movie_id': ObjectId('573a1394f29313caabce0fb4'), 'text': 'Tempore commodi sint quos mollitia nobis temporibus. Aspernatur cumque quas ab sed dolorem fugit enim. Tenetur maxime voluptatum vel animi eum error.', 'date': datetime.datetime(1995, 12, 6, 23, 14, 35)}]}
# {'_id': ObjectId('573a1395f29313caabce115f'), 'title': 'Warlock', 'comentarios': []}
# {'_id': ObjectId('573a1395f29313caabce1261'), 'title': 'Cimarron', 'comentarios': [{'_id': ObjectId('5a9427648b0beebeb6959629'), 'name': 'Olenna Tyrell', 'email': 'diana_rigg@gameofthron.es', 'movie_id': ObjectId('573a1395f29313caabce1261'), 'text': 'Doloremque voluptatem asperiores saepe accusamus error illum velit. Esse sed non placeat veritatis. Asperiores consectetur sed totam iure. Nulla maxime blanditiis tempore quo nesciunt aut.', 'date': datetime.datetime(1986, 12, 17, 14, 14, 59)}]}
# {'_id': ObjectId('573a1395f29313caabce13fe'), 'title': 'North to Alaska', 'comentarios': []}
# {'_id': ObjectId('573a1395f29313caabce166c'), 'title': 'The Comancheros', 'comentarios': []}
# {'_id': ObjectId('573a1395f29313caabce17b1'), 'title': 'The Last Sunset', 'comentarios': []}
# {'_id': ObjectId('573a1395f29313caabce1811'), 'title': 'The Misfits', 'comentarios': [{'_id': ObjectId('5a9427648b0beebeb695974a'), 'name': 'Justin Williams', 'email': 'justin_williams@fakegmail.com', 'movie_id': ObjectId('573a1395f29313caabce1811'), 'text': 'Libero exercitationem aspernatur illo at praesentium enim numquam. Quas quibusdam dolore reprehenderit assumenda alias ducimus. Laudantium rem molestiae quo iusto modi tenetur placeat.', 'date': datetime.datetime(1971, 4, 4, 14, 32, 28)}]}
# {'_id': ObjectId('573a1395f29313caabce18f8'), 'title': 'The Second Time Around', 'comentarios': [{'_id': ObjectId('5a9427648b0beebeb6959917'), 'name': 'Anthony Cline', 'email': 'anthony_cline@fakegmail.com', 'movie_id': ObjectId('573a1395f29313caabce18f8'), 'text': 'Distinctio provident unde est officiis expedita sapiente quis. Pariatur ipsam modi vel mollitia totam soluta. Saepe inventore possimus sunt similique. Quidem impedit quasi iusto cumque numquam magni.', 'date': datetime.datetime(1988, 7, 29, 10, 18, 45)}]}
# {'_id': ObjectId('573a1395f29313caabce1974'), 'title': 'Two Rode Together', 'comentarios': []}
# {'_id': ObjectId('573a1395f29313caabce1b78'), 'title': 'How the West Was Won', 'comentarios': []}
# {'_id': ObjectId('573a1395f29313caabce1be7'), 'title': 'Lonely Are the Brave', 'comentarios': []}
# {'_id': ObjectId('573a1395f29313caabce1bfc'), 'title': 'The Man Who Shot Liberty Valance', 'comentarios': [{'_id': ObjectId('5a9427648b0beebeb69599bf'), 'name': 'Jason Hernandez', 'email': 'jason_hernandez@fakegmail.com', 'movie_id': ObjectId('573a1395f29313caabce1bfc'), 'text': 'Voluptate error sint officiis. Voluptatibus assumenda facilis accusantium aut illum. Voluptas in laudantium porro dolor harum. Aperiam quasi magni nobis commodi ea.', 'date': datetime.datetime(2003, 9, 25, 13, 41, 24)}]}
# {'_id': ObjectId('573a1395f29313caabce1cb7'), 'title': 'Ride the High Country', 'comentarios': [{'_id': ObjectId('5a9427648b0beebeb69599e9'), 'name': 'Irri', 'email': 'amrita_acharia@gameofthron.es', 'movie_id': ObjectId('573a1395f29313caabce1cb7'), 'text': 'In aperiam saepe vitae illo modi nesciunt. Assumenda magnam et ipsum rem officiis amet. Adipisci harum asperiores quibusdam eaque eos. Mollitia magnam quis accusantium nesciunt rerum quis dolor.', 'date': datetime.datetime(2015, 4, 13, 18, 38, 58)}]}
# {'_id': ObjectId('573a1395f29313caabce1cf0'), 'title': 'Sergeants 3', 'comentarios': []}
# {'_id': ObjectId('573a1395f29313caabce1f52'), 'title': '4 for Texas', 'comentarios': []}
# {'_id': ObjectId('573a1395f29313caabce201c'), 'title': 'McLintock!', 'comentarios': [{'_id': ObjectId('5a9427648b0beebeb6959aa4'), 'name': 'Cersei Lannister', 'email': 'lena_headey@gameofthron.es', 'movie_id': ObjectId('573a1395f29313caabce201c'), 'text': 'Dolor id doloremque tenetur ea doloribus. Id consequatur occaecati enim iste laudantium maiores.\nQuisquam corrupti enim facere. Magni vel molestiae iste et quia non.', 'date': datetime.datetime(1971, 11, 25, 9, 41, 41)}]}
# {'_id': ObjectId('573a1395f29313caabce206e'), 'title': 'Old Shatterhand', 'comentarios': []}
# {'_id': ObjectId('573a1395f29313caabce2217'), 'title': '7 Faces of Dr. Lao', 'comentarios': []}
# {'_id': ObjectId('573a1395f29313caabce229e'), 'title': 'Cheyenne Autumn', 'comentarios': []}
# {'_id': ObjectId('573a1395f29313caabce22aa'), 'title': 'Circus World', 'comentarios': []}
# {'_id': ObjectId('573a1395f29313caabce2498'), 'title': 'A Fistful of Dollars', 'comentarios': []}
# {'_id': ObjectId('573a1395f29313caabce25b6'), 'title': 'Winnetou: The Red Gentleman', 'comentarios': []}
# {'_id': ObjectId('573a1395f29313caabce26b3'), 'title': 'Cat Ballou', 'comentarios': []}
# {'_id': ObjectId('573a1395f29313caabce2799'), 'title': 'The Hallelujah Trail', 'comentarios': []}
# {'_id': ObjectId('573a1395f29313caabce2949'), 'title': 'Shenandoah', 'comentarios': []}
# {'_id': ObjectId('573a1395f29313caabce296f'), 'title': 'The Sons of Katie Elder', 'comentarios': []}
# {'_id': ObjectId('573a1395f29313caabce29cb'), 'title': 'Time to Die', 'comentarios': []}
# {'_id': ObjectId('573a1395f29313caabce2a08'), 'title': 'Winnetou: The Last Shot', 'comentarios': [{'_id': ObjectId('5a9427648b0beebeb6959e62'), 'name': 'Brandon Hardy', 'email': 'brandon_hardy@fakegmail.com', 'movie_id': ObjectId('573a1395f29313caabce2a08'), 'text': 'Quo voluptatibus commodi in neque maxime incidunt totam. Explicabo delectus placeat unde ducimus odit ducimus. Autem reprehenderit cum porro suscipit.', 'date': datetime.datetime(2003, 12, 19, 19, 37, 47)}]}
# {'_id': ObjectId('573a1395f29313caabce2a33'), 'title': 'The Oil Prince', 'comentarios': []}
# {'_id': ObjectId('573a1395f29313caabce2b21'), 'title': 'A Big Hand for the Little Lady', 'comentarios': []}
# {'_id': ObjectId('573a1395f29313caabce2be8'), 'title': 'Duel at Diablo', 'comentarios': []}
# {'_id': ObjectId('573a1395f29313caabce2d36'), 'title': 'Nevada Smith', 'comentarios': []}
# {'_id': ObjectId('573a1395f29313caabce2d92'), 'title': 'The Ugly Ones', 'comentarios': []}
# {'_id': ObjectId('573a1395f29313caabce2dc0'), 'title': 'The Professionals', 'comentarios': [{'_id': ObjectId('5a9427648b0beebeb6959f2b'), 'name': 'Victor Patel', 'email': 'victor_patel@fakegmail.com', 'movie_id': ObjectId('573a1395f29313caabce2dc0'), 'text': 'Numquam at dolorum optio cupiditate in occaecati laborum. Iusto numquam iure saepe rem. Ad officia iusto provident quisquam provident.', 'date': datetime.datetime(2005, 11, 29, 3, 9, 40)}]}
# {'_id': ObjectId('573a1395f29313caabce2ee2'), 'title': 'Winnetou and Old Firehand', 'comentarios': []}
# {'_id': ObjectId('573a1395f29313caabce3040'), 'title': 'Blood River', 'comentarios': [{'_id': ObjectId('5a9427648b0beebeb6959fbc'), 'name': 'Kathryn Sosa', 'email': 'kathryn_sosa@fakegmail.com', 'movie_id': ObjectId('573a1395f29313caabce3040'), 'text': 'Placeat nostrum hic nulla mollitia magni corporis consectetur. Blanditiis culpa dolore error asperiores vel quod. Corporis ratione aspernatur est esse in.', 'date': datetime.datetime(1996, 11, 6, 8, 32, 37)}, {'_id': ObjectId('5a9427648b0beebeb6959fbe'), 'name': 'Thomas Green', 'email': 'thomas_green@fakegmail.com', 'movie_id': ObjectId('573a1395f29313caabce3040'), 'text': 'Odio iusto odit iste sunt illo a vero facilis. Minima aspernatur aut repellendus eveniet sed esse. Libero fugiat ullam facere animi possimus.', 'date': datetime.datetime(2009, 10, 3, 14, 24, 58)}]}
# {'_id': ObjectId('573a1395f29313caabce30fa'), 'title': 'Hombre', 'comentarios': [{'_id': ObjectId('5a9427648b0beebeb6959ffb'), 'name': 'Lori Franklin', 'email': 'lori_franklin@fakegmail.com', 'movie_id': ObjectId('573a1395f29313caabce30fa'), 'text': 'Odio pariatur enim earum minima autem. Quae quam at eaque earum modi. Explicabo distinctio sit commodi expedita modi aperiam. Eos sapiente dignissimos laudantium dolorem perspiciatis beatae modi.', 'date': datetime.datetime(1994, 3, 13, 13, 27, 13)}]}
# {'_id': ObjectId('573a1396f29313caabce37ad'), 'title': 'The Scalphunters', 'comentarios': [{'_id': ObjectId('5a9427648b0beebeb695a32a'), 'name': 'Tyrion Lannister', 'email': 'peter_dinklage@gameofthron.es', 'movie_id': ObjectId('573a1396f29313caabce37ad'), 'text': 'Neque molestias explicabo molestiae facere sequi. Quo minima maxime officia harum iusto quod ad quaerat. Quaerat nulla repudiandae harum consequatur libero dolores.', 'date': datetime.datetime(2001, 11, 1, 2, 3, 51)}]}
# {'_id': ObjectId('573a1396f29313caabce3896'), 'title': 'Will Penny', 'comentarios': []}
# {'_id': ObjectId('573a1396f29313caabce39c5'), 'title': 'Butch Cassidy and the Sundance Kid', 'comentarios': []}
# {'_id': ObjectId('573a1396f29313caabce39e5'), 'title': 'Once Upon a Time in the West', 'comentarios': [{'_id': ObjectId('5a9427648b0beebeb695a392'), 'name': 'Lisa Rasmussen', 'email': 'lisa_rasmussen@fakegmail.com', 'movie_id': ObjectId('573a1396f29313caabce39e5'), 'text': 'Sit laboriosam quo quis laborum. Nisi nobis laudantium quam non atque accusamus. Cumque adipisci consequuntur nesciunt ratione quas.', 'date': datetime.datetime(1980, 5, 22, 3, 24, 8)}]}
# {'_id': ObjectId('573a1396f29313caabce3b9e'), 'title': "Mackenna's Gold", 'comentarios': [{'_id': ObjectId('5a9427648b0beebeb695a411'), 'name': 'Daario Naharis', 'email': 'michiel_huisman@gameofthron.es', 'movie_id': ObjectId('573a1396f29313caabce3b9e'), 'text': 'Ea est sunt magnam deserunt nesciunt sed. Odit commodi quia incidunt nihil. Voluptas repudiandae vel atque.', 'date': datetime.datetime(1984, 4, 11, 20, 2, 15)}]}
# {'_id': ObjectId('573a1396f29313caabce3d4c'), 'title': 'The Stalking Moon', 'comentarios': []}
# {'_id': ObjectId('573a1396f29313caabce3d4f'), 'title': 'Tell Them Willie Boy Is Here', 'comentarios': [{'_id': ObjectId('5a9427648b0beebeb695a48d'), 'name': 'Ashlee Hart', 'email': 'ashlee_hart@fakegmail.com', 'movie_id': ObjectId('573a1396f29313caabce3d4f'), 'text': 'Quo dolorum a nesciunt rem deleniti dolor. Harum numquam autem sapiente vitae nam optio. Facilis ut recusandae error laborum aspernatur provident. Provident amet eos aliquam ducimus ipsa.', 'date': datetime.datetime(1993, 1, 31, 15, 51, 2)}]}
# {'_id': ObjectId('573a1396f29313caabce3d7c'), 'title': 'True Grit', 'comentarios': []}
# {'_id': ObjectId('573a1396f29313caabce3dcf'), 'title': 'The Wild Bunch', 'comentarios': [{'_id': ObjectId('5a9427648b0beebeb695a4a6'), 'name': 'Hot Pie', 'email': 'ben_hawkey@gameofthron.es', 'movie_id': ObjectId('573a1396f29313caabce3dcf'), 'text': 'Eos nesciunt soluta error minima. Doloribus accusamus dolor sit nostrum facilis ullam eum. Enim eaque placeat minus vero earum. Commodi incidunt veniam amet perferendis ullam vero.', 'date': datetime.datetime(1986, 8, 18, 11, 13, 39)}]}
# {'_id': ObjectId('573a1396f29313caabce3f23'), 'title': 'The Cheyenne Social Club', 'comentarios': []}
# {'_id': ObjectId('573a1396f29313caabce3f31'), 'title': 'Chisum', 'comentarios': []}
# {'_id': ObjectId('573a1396f29313caabce40c0'), 'title': 'Little Big Man', 'comentarios': []}
# {'_id': ObjectId('573a1396f29313caabce4106'), 'title': 'A Man Called Horse', 'comentarios': []}
# {'_id': ObjectId('573a1396f29313caabce4453'), 'title': 'Cut-Throats Nine', 'comentarios': []}
# {'_id': ObjectId('573a1396f29313caabce4485'), 'title': "'Doc'", 'comentarios': []}
# {'_id': ObjectId('573a1396f29313caabce451a'), 'title': 'Duck, You Sucker', 'comentarios': [{'_id': ObjectId('5a9427648b0beebeb695a671'), 'name': 'Emily Ellis', 'email': 'emily_ellis@fakegmail.com', 'movie_id': ObjectId('573a1396f29313caabce451a'), 'text': 'Ratione beatae libero facilis totam nostrum sequi quo. Consectetur libero ex necessitatibus hic inventore. Velit eum fuga dolorum. Repudiandae earum itaque voluptatum non quae aliquid.', 'date': datetime.datetime(1975, 11, 28, 2, 33, 48)}, {'_id': ObjectId('5a9427648b0beebeb695a672'), 'name': 'Jerry Cabrera', 'email': 'jerry_cabrera@fakegmail.com', 'movie_id': ObjectId('573a1396f29313caabce451a'), 'text': 'Qui fugiat quisquam deserunt quis cumque inventore suscipit. Maiores quas illo natus reprehenderit ipsum. Possimus autem nesciunt repellendus cum.', 'date': datetime.datetime(2008, 8, 27, 3, 29, 16)}, {'_id': ObjectId('5a9427648b0beebeb695a673'), 'name': 'Khal Drogo', 'email': 'jason_momoa@gameofthron.es', 'movie_id': ObjectId('573a1396f29313caabce451a'), 'text': 'Optio optio aut autem debitis. Exercitationem unde asperiores sequi neque sequi optio asperiores dignissimos.', 'date': datetime.datetime(1987, 1, 26, 8, 6, 32)}]}
# {'_id': ObjectId('573a1396f29313caabce4562'), 'title': 'The Hired Hand', 'comentarios': []}
# {'_id': ObjectId('573a1396f29313caabce4600'), 'title': 'McCabe & Mrs. Miller', 'comentarios': []}
# {'_id': ObjectId('573a1396f29313caabce4817'), 'title': 'Whity', 'comentarios': [{'_id': ObjectId('5a9427648b0beebeb695a753'), 'name': 'Shawn Mccormick', 'email': 'shawn_mccormick@fakegmail.com', 'movie_id': ObjectId('573a1396f29313caabce4817'), 'text': 'Rerum asperiores velit unde natus soluta repellat. Quo fugiat minus repellat impedit excepturi neque. Necessitatibus nobis odio placeat non a eos.', 'date': datetime.datetime(1995, 10, 11, 1, 2, 58)}]}
# {'_id': ObjectId('573a1396f29313caabce491f'), 'title': 'Bad Company', 'comentarios': [{'_id': ObjectId('5a9427648b0beebeb695a915'), 'name': 'Varys', 'email': 'conleth_hill@gameofthron.es', 'movie_id': ObjectId('573a1396f29313caabce491f'), 'text': 'Unde dicta mollitia corrupti necessitatibus. Earum corporis ipsa soluta corporis. Hic possimus minus dolore eum adipisci accusantium cum. Dolorem optio id omnis quod porro minus totam totam.', 'date': datetime.datetime(1999, 11, 3, 0, 16, 33)}]}
# {'_id': ObjectId('573a1396f29313caabce498c'), 'title': 'Charley-One-Eye', 'comentarios': []}
# {'_id': ObjectId('573a1396f29313caabce49bf'), 'title': 'The Cowboys', 'comentarios': []}
# {'_id': ObjectId('573a1396f29313caabce4abe'), 'title': 'The Great Northfield Minnesota Raid', 'comentarios': []}
# {'_id': ObjectId('573a1396f29313caabce4b17'), 'title': 'Jeremiah Johnson', 'comentarios': []}
# {'_id': ObjectId('573a1396f29313caabce4b31'), 'title': 'Junior Bonner', 'comentarios': []}
# {'_id': ObjectId('573a1396f29313caabce4c18'), 'title': 'The New Land', 'comentarios': []}
# {'_id': ObjectId('573a1396f29313caabce5074'), 'title': 'My Name Is Nobody', 'comentarios': []}
# {'_id': ObjectId('573a1396f29313caabce516d'), 'title': 'Oklahoma Crude', 'comentarios': [{'_id': ObjectId('5a9427648b0beebeb695acef'), 'name': 'Melissa Young', 'email': 'melissa_young@fakegmail.com', 'movie_id': ObjectId('573a1396f29313caabce516d'), 'text': 'Reiciendis soluta eveniet odit provident cupiditate excepturi hic. Ullam porro mollitia ratione. Occaecati aperiam animi saepe consequuntur.', 'date': datetime.datetime(2012, 7, 13, 5, 16, 5)}, {'_id': ObjectId('5a9427648b0beebeb695acf0'), 'name': 'Sandor Clegane', 'email': 'rory_mccann@gameofthron.es', 'movie_id': ObjectId('573a1396f29313caabce516d'), 'text': 'Voluptas eum beatae fugiat dolorum praesentium. Saepe rem ex eum ipsam. Magni soluta alias architecto occaecati.', 'date': datetime.datetime(2010, 4, 11, 16, 3, 52)}]}
# {'_id': ObjectId('573a1396f29313caabce5197'), 'title': 'Pat Garrett & Billy the Kid', 'comentarios': [{'_id': ObjectId('5a9427648b0beebeb695acfb'), 'name': 'Jordan Medina', 'email': 'jordan_medina@fakegmail.com', 'movie_id': ObjectId('573a1396f29313caabce5197'), 'text': 'Sed sapiente alias eum asperiores architecto. Amet culpa rerum autem molestiae. Consequuntur mollitia corporis cupiditate voluptate facilis. Ab culpa sequi repellat animi rerum vero.', 'date': datetime.datetime(2001, 10, 30, 19, 16, 35)}]}
# {'_id': ObjectId('573a1396f29313caabce51b3'), 'title': 'Pioneer Woman', 'comentarios': []}
# {'_id': ObjectId('573a1396f29313caabce5445'), 'title': 'Blazing Saddles', 'comentarios': [{'_id': ObjectId('5a9427648b0beebeb695ad93'), 'name': 'Emily Ellis', 'email': 'emily_ellis@fakegmail.com', 'movie_id': ObjectId('573a1396f29313caabce5445'), 'text': 'Atque fugiat voluptas error occaecati. Voluptatibus iusto ratione impedit voluptatem vel placeat incidunt. Aut commodi voluptas recusandae explicabo. Perferendis quaerat vitae dignissimos dicta.', 'date': datetime.datetime(1984, 9, 26, 20, 4, 8)}]}
# {'_id': ObjectId('573a1396f29313caabce58cf'), 'title': "Zandy's Bride", 'comentarios': [{'_id': ObjectId('5a9427648b0beebeb695aec6'), 'name': 'Patrick Knight', 'email': 'patrick_knight@fakegmail.com', 'movie_id': ObjectId('573a1396f29313caabce58cf'), 'text': 'Vero similique vel explicabo modi id aspernatur. Id exercitationem quod qui porro deserunt aliquid nesciunt. Aperiam ad molestiae illum deleniti earum optio. Ipsam sapiente vel sit libero cumque ab.', 'date': datetime.datetime(2014, 1, 31, 9, 9)}]}
# {'_id': ObjectId('573a1396f29313caabce59d4'), 'title': 'Bite the Bullet', 'comentarios': []}
# {'_id': ObjectId('573a1396f29313caabce5b00'), 'title': 'A Genius, Two Friends, and an Idiot', 'comentarios': []}
# {'_id': ObjectId('573a1396f29313caabce5b41'), 'title': 'Hearts of the West', 'comentarios': []}
# {'_id': ObjectId('573a1397f29313caabce5d06'), 'title': 'Posse', 'comentarios': []}
# {'_id': ObjectId('573a1397f29313caabce5f9e'), 'title': "Buffalo Bill and the Indians, or Sitting Bull's History Lesson", 'comentarios': []}
# {'_id': ObjectId('573a1397f29313caabce626b'), 'title': 'The Outlaw Josey Wales', 'comentarios': [{'_id': ObjectId('5a9427648b0beebeb695b25b'), 'name': 'Ms. Cathy Miller', 'email': 'ms._cathy_miller@fakegmail.com', 'movie_id': ObjectId('573a1397f29313caabce626b'), 'text': 'Vitae repudiandae ipsa nihil. Labore voluptates asperiores in possimus dolorem.', 'date': datetime.datetime(2012, 9, 19, 21, 9, 57)}]}
# {'_id': ObjectId('573a1397f29313caabce6331'), 'title': 'The Shootist', 'comentarios': []}
# {'_id': ObjectId('573a1397f29313caabce6b49'), 'title': 'Comes a Horseman', 'comentarios': []}
# {'_id': ObjectId('573a1397f29313caabce718a'), 'title': 'Que Viva Mexico', 'comentarios': []}
# {'_id': ObjectId('573a1397f29313caabce71cd'), 'title': 'The Electric Horseman', 'comentarios': []}
# {'_id': ObjectId('573a1397f29313caabce71d2'), 'title': "Eagle's Wing", 'comentarios': []}
# {'_id': ObjectId('573a1397f29313caabce7906'), 'title': 'Kenny Rogers as The Gambler', 'comentarios': []}
# {'_id': ObjectId('573a1397f29313caabce799a'), 'title': 'The Long Riders', 'comentarios': []}
# {'_id': ObjectId('573a1397f29313caabce7bba'), 'title': 'Urban Cowboy', 'comentarios': []}
# {'_id': ObjectId('573a1397f29313caabce7bf3'), 'title': 'Windwalker', 'comentarios': []}
# {'_id': ObjectId('573a1397f29313caabce7d75'), 'title': 'Cattle Annie and Little Britches', 'comentarios': [{'_id': ObjectId('5a9427648b0beebeb695bfeb'), 'name': 'Petyr Baelish', 'email': 'aidan_gillen@gameofthron.es', 'movie_id': ObjectId('573a1397f29313caabce7d75'), 'text': 'Officiis eius minus consectetur ducimus. Perspiciatis rerum nam repellat repellendus. Repellendus mollitia pariatur quos aperiam a facere.', 'date': datetime.datetime(1985, 11, 7, 21, 35, 43)}, {'_id': ObjectId('5a9427648b0beebeb695bfec'), 'name': 'Sarah Lewis', 'email': 'sarah_lewis@fakegmail.com', 'movie_id': ObjectId('573a1397f29313caabce7d75'), 'text': 'Sint provident a eaque facilis molestiae veniam. Ullam quas enim molestiae quod odit dolorem sequi.', 'date': datetime.datetime(2006, 8, 25, 10, 16, 19)}]}
# {'_id': ObjectId('573a1397f29313caabce7f76'), 'title': 'The Legend of the Lone Ranger', 'comentarios': []}
# {'_id': ObjectId('573a1397f29313caabce8014'), 'title': 'Buddy Goes West', 'comentarios': [{'_id': ObjectId('5a9427648b0beebeb695c0a0'), 'name': 'Theon Greyjoy', 'email': 'alfie_allen@gameofthron.es', 'movie_id': ObjectId('573a1397f29313caabce8014'), 'text': 'Suscipit sunt eligendi illo accusamus. Earum provident necessitatibus quam iste. Ab omnis laboriosam sit. Temporibus nihil numquam repudiandae perspiciatis nesciunt placeat quis labore.', 'date': datetime.datetime(1979, 8, 10, 10, 54, 23)}]}
# {'_id': ObjectId('573a1397f29313caabce855e'), 'title': 'Red Bells Part I: Mexico on Fire', 'comentarios': [{'_id': ObjectId('5a9427648b0beebeb695c653'), 'name': 'Nicholas Johnson', 'email': 'nicholas_johnson@fakegmail.com', 'movie_id': ObjectId('573a1397f29313caabce855e'), 'text': 'Blanditiis aut nostrum est. Sed ea excepturi minima adipisci odit. Magni similique nisi officiis et nihil consequatur quisquam. Quidem veritatis laborum sunt eaque.', 'date': datetime.datetime(2010, 5, 19, 14, 49, 57)}]}
# {'_id': ObjectId('573a1397f29313caabce8aac'), 'title': 'The Grey Fox', 'comentarios': []}
# {'_id': ObjectId('573a1398f29313caabce9a51'), 'title': 'Pale Rider', 'comentarios': []}
# {'_id': ObjectId('573a1398f29313caabce9aff'), 'title': "Rustlers' Rhapsody", 'comentarios': []}
# {'_id': ObjectId('573a1398f29313caabce9f6e'), 'title': 'Shanghai Express', 'comentarios': [{'_id': ObjectId('5a9427648b0beebeb695cbdb'), 'name': 'Connie Johnson', 'email': 'connie_johnson@fakegmail.com', 'movie_id': ObjectId('573a1398f29313caabce9f6e'), 'text': 'Optio quod alias iste iure hic. Occaecati alias laboriosam voluptatem adipisci adipisci. Vitae tempore est amet nobis numquam similique. Earum mollitia necessitatibus sequi maxime soluta.', 'date': datetime.datetime(1983, 11, 3, 2, 6, 7)}]}
# {'_id': ObjectId('573a1398f29313caabcea2ed'), 'title': 'Tampopo', 'comentarios': [{'_id': ObjectId('5a9427648b0beebeb695cc93'), 'name': 'Shireen Baratheon', 'email': 'kerry_ingram@gameofthron.es', 'movie_id': ObjectId('573a1398f29313caabcea2ed'), 'text': 'Esse repellat minus distinctio fugiat architecto iste. Quos in minus aliquid dolores incidunt impedit. Quam ullam eos exercitationem consequuntur impedit. Laudantium adipisci ut nostrum quos.', 'date': datetime.datetime(2008, 4, 20, 1, 10, 28)}]}
# {'_id': ObjectId('573a1398f29313caabceb1b7'), 'title': 'Return to Snowy River', 'comentarios': []}
# {'_id': ObjectId('573a1398f29313caabceb40c'), 'title': 'Lonesome Dove', 'comentarios': [{'_id': ObjectId('5a9427648b0beebeb695d385'), 'name': 'Megan Turner', 'email': 'megan_turner@fakegmail.com', 'movie_id': ObjectId('573a1398f29313caabceb40c'), 'text': 'Illo nulla voluptatum quos quas animi eveniet voluptates. Mollitia veritatis et ipsam expedita. Numquam temporibus possimus vero tempore doloribus.', 'date': datetime.datetime(1974, 9, 27, 15, 43, 15)}]}
# {'_id': ObjectId('573a1398f29313caabcebe42'), 'title': 'Dances with Wolves', 'comentarios': []}
# {'_id': ObjectId('573a1399f29313caabcec3a5'), 'title': 'Thousand Pieces of Gold', 'comentarios': []}
# {'_id': ObjectId('573a1399f29313caabcec46d'), 'title': 'Young Guns II', 'comentarios': []}
# {'_id': ObjectId('573a1399f29313caabcec999'), 'title': 'Lucky Luke', 'comentarios': [{'_id': ObjectId('5a9427648b0beebeb695eaa9'), 'name': 'Blake Fitzgerald', 'email': 'blake_fitzgerald@fakegmail.com', 'movie_id': ObjectId('573a1399f29313caabcec999'), 'text': 'Quod deleniti autem dolor nobis sint. Vero adipisci aliquid labore eaque quae atque fuga. Architecto laboriosam quibusdam dignissimos fuga officia.', 'date': datetime.datetime(1974, 8, 29, 4, 24, 20)}, {'_id': ObjectId('5a9427648b0beebeb695eaab'), 'name': 'Kelsey Smith', 'email': 'kelsey_smith@fakegmail.com', 'movie_id': ObjectId('573a1399f29313caabcec999'), 'text': 'Dolorum pariatur sit eum delectus dolorum voluptatibus. Totam at perferendis maxime animi ducimus ad. In incidunt accusamus vel.', 'date': datetime.datetime(2010, 1, 13, 17, 55, 1)}]}
# {'_id': ObjectId('573a1399f29313caabced0fc'), 'title': 'Four Eyes and Six-Guns', 'comentarios': [{'_id': ObjectId('5a9427648b0beebeb695f0a4'), 'name': 'Christopher Robinson', 'email': 'christopher_robinson@fakegmail.com', 'movie_id': ObjectId('573a1399f29313caabced0fc'), 'text': 'Harum officiis officia molestiae. Eaque omnis mollitia voluptatum. Veniam vel facere itaque assumenda quidem itaque tempora.', 'date': datetime.datetime(2007, 3, 12, 11, 43, 34)}]}
# {'_id': ObjectId('573a1399f29313caabced644'), 'title': 'Unforgiven', 'comentarios': [{'_id': ObjectId('5a9427648b0beebeb695f4e7'), 'name': 'Lori Franklin', 'email': 'lori_franklin@fakegmail.com', 'movie_id': ObjectId('573a1399f29313caabced644'), 'text': 'Vero provident eligendi placeat expedita aspernatur id. Dolores incidunt nam aspernatur eveniet. Dolore corporis labore quasi minus unde mollitia.', 'date': datetime.datetime(2012, 5, 10, 3, 46, 10)}, {'_id': ObjectId('5a9427648b0beebeb695f4f3'), 'name': 'Barristan Selmy', 'email': 'ian_mcelhinney@gameofthron.es', 'movie_id': ObjectId('573a1399f29313caabced644'), 'text': 'Provident aspernatur mollitia in rerum. Impedit cumque architecto voluptas quae. Vel aperiam dignissimos iusto hic dicta nesciunt. Quibusdam ut et facilis maiores voluptatibus commodi numquam dolore.', 'date': datetime.datetime(2011, 2, 21, 12, 57, 55)}]}
# {'_id': ObjectId('573a1399f29313caabced7e1'), 'title': 'Return to Lonesome Dove', 'comentarios': [{'_id': ObjectId('5a9427648b0beebeb695f506'), 'name': 'Rickon Stark', 'email': 'art_parkinson@gameofthron.es', 'movie_id': ObjectId('573a1399f29313caabced7e1'), 'text': 'Accusantium perferendis suscipit quia consequuntur modi atque. Dolores necessitatibus atque dicta fugit iure dolor. Quidem repudiandae minima aspernatur blanditiis illo harum.', 'date': datetime.datetime(1972, 12, 8, 0, 47, 25)}]}
# {'_id': ObjectId('573a1399f29313caabced8d1'), 'title': 'The Ballad of Little Jo', 'comentarios': []}
# {'_id': ObjectId('573a1399f29313caabcedb50'), 'title': 'Geronimo: An American Legend', 'comentarios': []}
# {'_id': ObjectId('573a1399f29313caabcede8f'), 'title': 'Posse', 'comentarios': []}
# {'_id': ObjectId('573a1399f29313caabcedf95'), 'title': 'Silent Tongue', 'comentarios': []}
# {'_id': ObjectId('573a1399f29313caabceee5e'), 'title': 'Streets of Laredo', 'comentarios': []}
# {'_id': ObjectId('573a139af29313caabceefbd'), 'title': 'Atolladero', 'comentarios': [{'_id': ObjectId('5a9427648b0beebeb6960f88'), 'name': 'Cersei Lannister', 'email': 'lena_headey@gameofthron.es', 'movie_id': ObjectId('573a139af29313caabceefbd'), 'text': 'Minima consectetur accusantium magnam consequuntur. Omnis sapiente voluptate eveniet. Voluptatem ullam consequuntur praesentium. Modi nihil dicta quidem ab aut.', 'date': datetime.datetime(1970, 11, 8, 20, 39, 41)}]}
# {'_id': ObjectId('573a139af29313caabcef150'), 'title': 'Dead Man', 'comentarios': []}
# {'_id': ObjectId('573a139af29313caabcef2cd'), 'title': 'The Good Old Boys', 'comentarios': []}
# {'_id': ObjectId('573a139af29313caabcef6a8'), 'title': 'The Quick and the Dead', 'comentarios': []}
# {'_id': ObjectId('573a139af29313caabcef964'), 'title': 'Wild Bill', 'comentarios': []}
# {'_id': ObjectId('573a139af29313caabcefa82'), 'title': "Dead Man's Walk", 'comentarios': [{'_id': ObjectId('5a9427648b0beebeb6961ae8'), 'name': 'Anthony Hurst', 'email': 'anthony_hurst@fakegmail.com', 'movie_id': ObjectId('573a139af29313caabcefa82'), 'text': 'Vitae iste esse similique eveniet. Ex consequatur rem rerum blanditiis saepe. Quaerat distinctio quod tenetur est.', 'date': datetime.datetime(1990, 8, 25, 19, 59, 37)}, {'_id': ObjectId('5a9427648b0beebeb6961ae9'), 'name': 'Loras Tyrell', 'email': 'finn_jones@gameofthron.es', 'movie_id': ObjectId('573a139af29313caabcefa82'), 'text': 'Officiis incidunt optio totam fugiat ut nisi. Unde itaque earum vel a doloribus illum reiciendis. Excepturi porro aliquam nostrum vitae.', 'date': datetime.datetime(1971, 3, 9, 17, 56, 47)}, {'_id': ObjectId('5a9427648b0beebeb6961aea'), 'name': 'Olenna Tyrell', 'email': 'diana_rigg@gameofthron.es', 'movie_id': ObjectId('573a139af29313caabcefa82'), 'text': 'Facilis dolore corrupti mollitia iusto nam ducimus. Iste enim suscipit quae eaque occaecati. Illum voluptatum neque aut amet nulla neque. Quas rerum voluptatum quod quisquam quaerat explicabo.', 'date': datetime.datetime(2001, 4, 12, 2, 41, 59)}]}
# {'_id': ObjectId('573a139af29313caabcf02fd'), 'title': 'Riders of the Purple Sage', 'comentarios': []}
# {'_id': ObjectId('573a139af29313caabcf0320'), 'title': 'Rose Hill', 'comentarios': []}
# {'_id': ObjectId('573a139af29313caabcf09da'), 'title': 'The Horse Whisperer', 'comentarios': [{'_id': ObjectId('5a9427648b0beebeb6962830'), 'name': 'Patrick Knight', 'email': 'patrick_knight@fakegmail.com', 'movie_id': ObjectId('573a139af29313caabcf09da'), 'text': 'Blanditiis maxime praesentium reiciendis quod ad incidunt recusandae exercitationem. Dolor deserunt debitis quod maiores magni. Officia ullam provident odit nemo.', 'date': datetime.datetime(1984, 6, 30, 4, 35, 38)}]}
# {'_id': ObjectId('573a139af29313caabcf0a6f'), 'title': 'Last Stand at Saber River', 'comentarios': []}
# {'_id': ObjectId('573a139af29313caabcf0eb5'), 'title': "From Dusk Till Dawn 3: The Hangman's Daughter", 'comentarios': []}
# {'_id': ObjectId('573a139af29313caabcf0eba'), 'title': 'The Hi-Lo Country', 'comentarios': []}
# {'_id': ObjectId('573a139af29313caabcf0f48'), 'title': 'Wild Wild West', 'comentarios': [{'_id': ObjectId('5a9427648b0beebeb6963e50'), 'name': 'Podrick Payne', 'email': 'daniel_portman@gameofthron.es', 'movie_id': ObjectId('573a139af29313caabcf0f48'), 'text': 'Explicabo quibusdam quasi consequatur ratione expedita accusamus. Qui ex minima fugiat occaecati reprehenderit perferendis. Illo asperiores esse placeat animi.', 'date': datetime.datetime(2010, 3, 8, 15, 32, 40)}]}
# {'_id': ObjectId('573a139cf29313caabcf7b39'), 'title': 'All the Pretty Horses', 'comentarios': []}
# {'_id': ObjectId('573a139df29313caabcf9bb2'), 'title': 'Purgatory', 'comentarios': []}
# {'_id': ObjectId('573a139df29313caabcfaa8e'), 'title': 'Blazing Saddles', 'comentarios': [{'_id': ObjectId('5a9427648b0beebeb6965b63'), 'name': 'Ronald Cox', 'email': 'ronald_cox@fakegmail.com', 'movie_id': ObjectId('573a139df29313caabcfaa8e'), 'text': 'Incidunt possimus culpa quidem commodi enim. Et aspernatur culpa magni. Aliquid deleniti in laborum amet.', 'date': datetime.datetime(2004, 12, 14, 4, 7, 52)}, {'_id': ObjectId('5a9427648b0beebeb6965b68'), 'name': 'Tywin Lannister', 'email': 'charles_dance@gameofthron.es', 'movie_id': ObjectId('573a139df29313caabcfaa8e'), 'text': 'Libero praesentium iure rerum animi. Sapiente explicabo est quis rem. Reprehenderit dolorum consequatur est alias saepe. Facilis amet tempora exercitationem eveniet.', 'date': datetime.datetime(1977, 12, 29, 10, 56, 50)}]}
# {'_id': ObjectId('573a139ef29313caabcfccee'), 'title': 'The Jack Bull', 'comentarios': []}
# {'_id': ObjectId('573a139ef29313caabcfd07c'), 'title': 'Dollar for the Dead', 'comentarios': [{'_id': ObjectId('5a9427648b0beebeb69667f2'), 'name': 'Lancel Lannister', 'email': 'eugene_simon@gameofthron.es', 'movie_id': ObjectId('573a139ef29313caabcfd07c'), 'text': 'Quae magnam magnam fuga eum maiores. Eaque nesciunt eos fugit. Ea exercitationem ullam totam accusantium odio ipsum minima. Quo adipisci explicabo distinctio optio ab.', 'date': datetime.datetime(1977, 7, 18, 3, 45, 23)}]}
# {'_id': ObjectId('573a139ff29313caabd01709'), 'title': 'The Daughter of Dawn', 'comentarios': []}
# {'_id': ObjectId('573a13a1f29313caabd0660a'), 'title': 'The Tracker', 'comentarios': []}
# {'_id': ObjectId('573a13a1f29313caabd07d0b'), 'title': 'The Claim', 'comentarios': []}
# {'_id': ObjectId('573a13a3f29313caabd0db37'), 'title': 'Dust', 'comentarios': [{'_id': ObjectId('5a9427658b0beebeb696915e'), 'name': 'Amy Ramirez', 'email': 'amy_ramirez@fakegmail.com', 'movie_id': ObjectId('573a13a3f29313caabd0db37'), 'text': 'Ut voluptatum illo rem enim rem. Alias itaque provident non delectus expedita modi pariatur voluptas. Impedit nam veniam aliquid dignissimos et aut.', 'date': datetime.datetime(2017, 1, 4, 14, 46, 49)}]}
# {'_id': ObjectId('573a13a3f29313caabd0de19'), 'title': 'American Outlaws', 'comentarios': []}
# {'_id': ObjectId('573a13a3f29313caabd0eea3'), 'title': "Manitou's Shoe", 'comentarios': []}
# {'_id': ObjectId('573a13a5f29313caabd159ff'), 'title': 'Renegade', 'comentarios': []}
# {'_id': ObjectId('573a13a6f29313caabd16fee'), 'title': 'King of Texas', 'comentarios': [{'_id': ObjectId('5a9427658b0beebeb696b0b1'), 'name': 'Beric Dondarrion', 'email': 'richard_dormer@gameofthron.es', 'movie_id': ObjectId('573a13a6f29313caabd16fee'), 'text': 'Ipsam impedit ipsa quaerat doloribus libero. Illo laborum exercitationem repudiandae omnis non incidunt. Doloribus modi ipsam debitis ex fuga vitae aperiam possimus. Ab soluta tempora cum beatae.', 'date': datetime.datetime(2001, 10, 3, 14, 46, 15)}]}
# {'_id': ObjectId('573a13a9f29313caabd1ee4e'), 'title': 'Open Range', 'comentarios': [{'_id': ObjectId('5a9427658b0beebeb696ccb7'), 'name': 'Shae', 'email': 'sibel_kekilli@gameofthron.es', 'movie_id': ObjectId('573a13a9f29313caabd1ee4e'), 'text': 'Odio delectus a at quod quod placeat repellat. Dolorum eos minima inventore sed dolore rerum incidunt. Officiis molestias magnam maiores.', 'date': datetime.datetime(1978, 8, 6, 22, 35, 38)}]}
# {'_id': ObjectId('573a13a9f29313caabd1f323'), 'title': 'Hidalgo', 'comentarios': []}
# {'_id': ObjectId('573a13aaf29313caabd21f8e'), 'title': 'Monte Walsh', 'comentarios': []}
# {'_id': ObjectId('573a13abf29313caabd24103'), 'title': 'The Missing', 'comentarios': []}
# {'_id': ObjectId('573a13abf29313caabd25cdb'), 'title': 'Love Comes Softly', 'comentarios': [{'_id': ObjectId('5a9427658b0beebeb696e3f4'), 'name': 'Sansa Stark', 'email': 'sophie_turner@gameofthron.es', 'movie_id': ObjectId('573a13abf29313caabd25cdb'), 'text': 'Eum fugit voluptatum deleniti. Commodi eaque cumque unde eligendi. Odio voluptate tempora rem facere eveniet.', 'date': datetime.datetime(1979, 4, 25, 21, 10, 42)}]}
# {'_id': ObjectId('573a13adf29313caabd2b3f6'), 'title': 'Lucky Luke and the Daltons', 'comentarios': [{'_id': ObjectId('5a9427658b0beebeb696f60f'), 'name': 'Rodrik Cassel', 'email': 'ron_donachie@gameofthron.es', 'movie_id': ObjectId('573a13adf29313caabd2b3f6'), 'text': 'Dolor quod molestiae illo incidunt facilis tenetur. Eaque rem ratione quos totam. Aperiam a nemo aperiam atque velit ipsa. Totam voluptas voluptas alias placeat.', 'date': datetime.datetime(2004, 11, 29, 0, 11, 23)}, {'_id': ObjectId('5a9427658b0beebeb696f610'), 'name': 'Amy Phillips', 'email': 'amy_phillips@fakegmail.com', 'movie_id': ObjectId('573a13adf29313caabd2b3f6'), 'text': 'Consequuntur odit dicta vitae eveniet adipisci. Rem delectus maxime deleniti minima molestiae id maxime. Dolorem doloribus ipsam ipsum porro a fugit.', 'date': datetime.datetime(1975, 5, 4, 22, 12, 53)}]}
# {'_id': ObjectId('573a13aef29313caabd2d606'), 'title': 'Dead Birds', 'comentarios': []}
# {'_id': ObjectId('573a13aff29313caabd2f5a5'), 'title': 'The Legend of Zorro', 'comentarios': [{'_id': ObjectId('5a9427658b0beebeb696fa13'), 'name': 'Mrs. Ariana Nunez', 'email': 'mrs._ariana_nunez@fakegmail.com', 'movie_id': ObjectId('573a13aff29313caabd2f5a5'), 'text': 'Qui quam aut labore vitae. Nobis quasi nihil repellat animi non earum aspernatur. Corporis delectus nesciunt modi quas maxime.', 'date': datetime.datetime(2004, 6, 13, 23, 47, 46)}]}
# {'_id': ObjectId('573a13aff29313caabd3139f'), 'title': 'The New Land', 'comentarios': []}
# {'_id': ObjectId('573a13aff29313caabd313a7'), 'title': 'The New Land', 'comentarios': []}
# {'_id': ObjectId('573a13aff29313caabd313aa'), 'title': 'The New Land', 'comentarios': [{'_id': ObjectId('5a9427658b0beebeb696faca'), 'name': 'Cameron Duran', 'email': 'cameron_duran@fakegmail.com', 'movie_id': ObjectId('573a13aff29313caabd313aa'), 'text': 'In cumque autem alias ratione voluptatem nam eveniet. Suscipit qui aperiam doloremque consequatur porro. Officiis sunt eveniet deleniti debitis nostrum.', 'date': datetime.datetime(1992, 9, 14, 11, 29, 48)}]}
# {'_id': ObjectId('573a13aff29313caabd313bd'), 'title': 'The New Land', 'comentarios': []}
# {'_id': ObjectId('573a13b0f29313caabd32dd1'), 'title': "Love's Enduring Promise", 'comentarios': [{'_id': ObjectId('5a9427658b0beebeb696fd09'), 'name': 'Catelyn Stark', 'email': 'michelle_fairley@gameofthron.es', 'movie_id': ObjectId('573a13b0f29313caabd32dd1'), 'text': 'Harum accusamus a voluptas voluptates labore occaecati. Adipisci dolore aut sapiente ullam est quasi. Repudiandae enim unde soluta magnam saepe.', 'date': datetime.datetime(1973, 6, 1, 10, 24, 3)}, {'_id': ObjectId('5a9427658b0beebeb696fd0d'), 'name': 'Thomas Morris', 'email': 'thomas_morris@fakegmail.com', 'movie_id': ObjectId('573a13b0f29313caabd32dd1'), 'text': 'Ipsa labore omnis provident assumenda perferendis porro. Aut quis doloremque assumenda voluptate repudiandae a ratione. Quas recusandae ab incidunt accusantium.', 'date': datetime.datetime(1992, 11, 21, 7, 10, 56)}]}
# {'_id': ObjectId('573a13b0f29313caabd34927'), 'title': 'Into the West', 'comentarios': [{'_id': ObjectId('5a9427658b0beebeb697057d'), 'name': 'Karina Martin', 'email': 'karina_martin@fakegmail.com', 'movie_id': ObjectId('573a13b0f29313caabd34927'), 'text': 'Sed voluptates distinctio quis voluptas harum beatae dolore magni. Minus inventore aut error nulla id ut ab ratione.', 'date': datetime.datetime(2004, 8, 24, 22, 30, 33)}]}
# {'_id': ObjectId('573a13b1f29313caabd37521'), 'title': 'The Proposition', 'comentarios': []}
# {'_id': ObjectId('573a13b3f29313caabd3d26c'), 'title': 'The Burrowers', 'comentarios': [{'_id': ObjectId('5a9427658b0beebeb69720b9'), 'name': 'Patrick Knight', 'email': 'patrick_knight@fakegmail.com', 'movie_id': ObjectId('573a13b3f29313caabd3d26c'), 'text': 'Cupiditate distinctio rerum doloremque sequi adipisci. Ratione suscipit et at molestiae explicabo. Pariatur nesciunt et optio ipsa qui culpa similique.', 'date': datetime.datetime(2011, 2, 14, 16, 8, 39)}]}
# ...
# {'_id': ObjectId('573a13adf29313caabd2b3f6'), 'title': 'Lucky Luke and the Daltons', 'comentarios': [{'_id': ObjectId('5a9427658b0beebeb696f60f'), 'name': 'Rodrik Cassel', 'email': 'ron_donachie@gameofthron.es', 'movie_id': ObjectId('573a13adf29313caabd2b3f6'), 'text': 'Dolor quod molestiae illo incidunt facilis tenetur. Eaque rem ratione quos totam. Aperiam a nemo aperiam atque velit ipsa. Totam voluptas voluptas alias placeat.', 'date': datetime.datetime(2004, 11, 29, 0, 11, 23)}, {'_id': ObjectId('5a9427658b0beebeb696f610'), 'name': 'Amy Phillips', 'email': 'amy_phillips@fakegmail.com', 'movie_id': ObjectId('573a13adf29313caabd2b3f6'), 'text': 'Consequuntur odit dicta vitae eveniet adipisci. Rem delectus maxime deleniti minima molestiae id maxime. Dolorem doloribus ipsam ipsum porro a fugit.', 'date': datetime.datetime(1975, 5, 4, 22, 12, 53)}]}
# {'_id': ObjectId('573a13aef29313caabd2d606'), 'title': 'Dead Birds', 'comentarios': []}
# {'_id': ObjectId('573a13aff29313caabd2f5a5'), 'title': 'The Legend of Zorro', 'comentarios': [{'_id': ObjectId('5a9427658b0beebeb696fa13'), 'name': 'Mrs. Ariana Nunez', 'email': 'mrs._ariana_nunez@fakegmail.com', 'movie_id': ObjectId('573a13aff29313caabd2f5a5'), 'text': 'Qui quam aut labore vitae. Nobis quasi nihil repellat animi non earum aspernatur. Corporis delectus nesciunt modi quas maxime.', 'date': datetime.datetime(2004, 6, 13, 23, 47, 46)}]}
# {'_id': ObjectId('573a13aff29313caabd3139f'), 'title': 'The New Land', 'comentarios': []}
# {'_id': ObjectId('573a13aff29313caabd313a7'), 'title': 'The New Land', 'comentarios': []}
# {'_id': ObjectId('573a13aff29313caabd313aa'), 'title': 'The New Land', 'comentarios': [{'_id': ObjectId('5a9427658b0beebeb696faca'), 'name': 'Cameron Duran', 'email': 'cameron_duran@fakegmail.com', 'movie_id': ObjectId('573a13aff29313caabd313aa'), 'text': 'In cumque autem alias ratione voluptatem nam eveniet. Suscipit qui aperiam doloremque consequatur porro. Officiis sunt eveniet deleniti debitis nostrum.', 'date': datetime.datetime(1992, 9, 14, 11, 29, 48)}]}
# {'_id': ObjectId('573a13aff29313caabd313bd'), 'title': 'The New Land', 'comentarios': []}
# {'_id': ObjectId('573a13b0f29313caabd32dd1'), 'title': "Love's Enduring Promise", 'comentarios': [{'_id': ObjectId('5a9427658b0beebeb696fd09'), 'name': 'Catelyn Stark', 'email': 'michelle_fairley@gameofthron.es', 'movie_id': ObjectId('573a13b0f29313caabd32dd1'), 'text': 'Harum accusamus a voluptas voluptates labore occaecati. Adipisci dolore aut sapiente ullam est quasi. Repudiandae enim unde soluta magnam saepe.', 'date': datetime.datetime(1973, 6, 1, 10, 24, 3)}, {'_id': ObjectId('5a9427658b0beebeb696fd0d'), 'name': 'Thomas Morris', 'email': 'thomas_morris@fakegmail.com', 'movie_id': ObjectId('573a13b0f29313caabd32dd1'), 'text': 'Ipsa labore omnis provident assumenda perferendis porro. Aut quis doloremque assumenda voluptate repudiandae a ratione. Quas recusandae ab incidunt accusantium.', 'date': datetime.datetime(1992, 11, 21, 7, 10, 56)}]}
# {'_id': ObjectId('573a13b0f29313caabd34927'), 'title': 'Into the West', 'comentarios': [{'_id': ObjectId('5a9427658b0beebeb697057d'), 'name': 'Karina Martin', 'email': 'karina_martin@fakegmail.com', 'movie_id': ObjectId('573a13b0f29313caabd34927'), 'text': 'Sed voluptates distinctio quis voluptas harum beatae dolore magni. Minus inventore aut error nulla id ut ab ratione.', 'date': datetime.datetime(2004, 8, 24, 22, 30, 33)}]}
# {'_id': ObjectId('573a13b1f29313caabd37521'), 'title': 'The Proposition', 'comentarios': []}
# {'_id': ObjectId('573a13b3f29313caabd3d26c'), 'title': 'The Burrowers', 'comentarios': [{'_id': ObjectId('5a9427658b0beebeb69720b9'), 'name': 'Patrick Knight', 'email': 'patrick_knight@fakegmail.com', 'movie_id': ObjectId('573a13b3f29313caabd3d26c'), 'text': 'Cupiditate distinctio rerum doloremque sequi adipisci. Ratione suscipit et at molestiae explicabo. Pariatur nesciunt et optio ipsa qui culpa similique.', 'date': datetime.datetime(2011, 2, 14, 16, 8, 39)}]}
# {'_id': ObjectId('573a13b5f29313caabd43a74'), 'title': 'September Dawn', 'comentarios': [{'_id': ObjectId('5a9427658b0beebeb6973227'), 'name': 'Ros', 'email': 'esme_bianco@gameofthron.es', 'movie_id': ObjectId('573a13b5f29313caabd43a74'), 'text': 'Nulla ea labore dolores mollitia tempora quaerat. Assumenda eos laudantium quo aperiam. Minima dignissimos quia natus incidunt nemo soluta amet doloribus. Aspernatur dignissimos quidem corrupti sit.', 'date': datetime.datetime(1995, 6, 5, 10, 16, 20)}]}
# {'_id': ObjectId('573a13b6f29313caabd45ca0'), 'title': 'Broken Trail', 'comentarios': []}
# {'_id': ObjectId('573a13b6f29313caabd46a04'), 'title': "Love's Long Journey", 'comentarios': []}
# {'_id': ObjectId('573a13b6f29313caabd48428'), 'title': 'Instructions for a Light and Sound Machine', 'comentarios': [{'_id': ObjectId('5a9427658b0beebeb6973da2'), 'name': 'Ashlee Hart', 'email': 'ashlee_hart@fakegmail.com', 'movie_id': ObjectId('573a13b6f29313caabd48428'), 'text': 'Dolorum eum ipsam eos ullam repellat corporis. Blanditiis exercitationem ex atque. Magnam natus distinctio possimus officiis odio architecto voluptate voluptatum.', 'date': datetime.datetime(1970, 11, 16, 8, 34, 21)}]}
# {'_id': ObjectId('573a13b8f29313caabd4b6c3'), 'title': 'Comanche Moon', 'comentarios': [{'_id': ObjectId('5a9427658b0beebeb6974888'), 'name': 'John Bishop', 'email': 'john_bishop@fakegmail.com', 'movie_id': ObjectId('573a13b8f29313caabd4b6c3'), 'text': 'Accusamus illum inventore repellat minus. Officiis enim commodi assumenda esse voluptatibus nostrum voluptatum vero. Iste assumenda natus quos.', 'date': datetime.datetime(2011, 6, 7, 16, 48, 9)}]}
# {'_id': ObjectId('573a13b8f29313caabd4c89a'), 'title': 'Appaloosa', 'comentarios': []}
# {'_id': ObjectId('573a13b9f29313caabd4df92'), 'title': 'Shoot First and Pray You Live (Because Luck Has Nothing to Do with It)', 'comentarios': [{'_id': ObjectId('5a9427658b0beebeb697520b'), 'name': 'Grand Maester Pycelle', 'email': 'julian_glover@gameofthron.es', 'movie_id': ObjectId('573a13b9f29313caabd4df92'), 'text': 'Debitis veritatis optio ut vero. Perferendis esse quo excepturi quam veritatis eligendi. Eos dicta illo et dolorum impedit veritatis cum illo.', 'date': datetime.datetime(1993, 5, 4, 1, 22, 4)}]}
# {'_id': ObjectId('573a13b9f29313caabd4e581'), 'title': 'Bury My Heart at Wounded Knee', 'comentarios': [{'_id': ObjectId('5a9427658b0beebeb6975228'), 'name': 'Daenerys Targaryen', 'email': 'emilia_clarke@gameofthron.es', 'movie_id': ObjectId('573a13b9f29313caabd4e581'), 'text': 'Illo autem dolorem amet odit provident eaque. Facere modi quasi quas tempore occaecati corporis amet magni. Est veritatis fuga recusandae alias delectus.', 'date': datetime.datetime(1971, 8, 11, 14, 53, 10)}]}
# {'_id': ObjectId('573a13bbf29313caabd53ad6'), 'title': 'Sukiyaki Western Django', 'comentarios': [{'_id': ObjectId('5a9427658b0beebeb6975805'), 'name': 'The High Sparrow', 'email': 'jonathan_pryce@gameofthron.es', 'movie_id': ObjectId('573a13bbf29313caabd53ad6'), 'text': 'Architecto fuga deleniti aspernatur cupiditate quae ut. Expedita inventore quam possimus quo. Sit in autem distinctio ut est et tempora voluptatum. Dolorem provident itaque laudantium modi.', 'date': datetime.datetime(1998, 6, 25, 0, 26, 40)}]}
# {'_id': ObjectId('573a13bbf29313caabd53b1f'), 'title': 'Sukiyaki Western Django', 'comentarios': [{'_id': ObjectId('5a9427658b0beebeb697580d'), 'name': 'Greg Powell', 'email': 'greg_powell@fakegmail.com', 'movie_id': ObjectId('573a13bbf29313caabd53b1f'), 'text': 'Similique quam aspernatur quas laborum. Fugit dolores veritatis aliquid alias suscipit velit. Repellendus accusamus eligendi illum expedita amet.', 'date': datetime.datetime(1972, 10, 4, 19, 7, 43)}]}
# {'_id': ObjectId('573a13bcf29313caabd56689'), 'title': "Love's Unfolding Dream", 'comentarios': []}
# {'_id': ObjectId('573a13bef29313caabd5dac1'), 'title': 'Lone Rider', 'comentarios': []}
# {'_id': ObjectId('573a13bff29313caabd5fdf0'), 'title': 'Blood River', 'comentarios': [{'_id': ObjectId('5a9427658b0beebeb6977c80'), 'name': 'Mrs. Ariana Nunez', 'email': 'mrs._ariana_nunez@fakegmail.com', 'movie_id': ObjectId('573a13bff29313caabd5fdf0'), 'text': 'Officia illo deleniti est odit aut facere perspiciatis. Ducimus cum sequi provident. Id dolore rem ipsa atque nostrum possimus placeat. Nisi atque aliquam itaque ullam odit.', 'date': datetime.datetime(1981, 5, 24, 23, 19, 35)}]}
# {'_id': ObjectId('573a13c1f29313caabd648d3'), 'title': 'The Lone Ranger', 'comentarios': []}
# {'_id': ObjectId('573a13c2f29313caabd68040'), 'title': 'Love Takes Wing', 'comentarios': []}
# {'_id': ObjectId('573a13c5f29313caabd6fbbb'), 'title': 'Ardor', 'comentarios': []}
# {'_id': ObjectId('573a13c5f29313caabd7002b'), 'title': 'Bad Day to Go Fishing', 'comentarios': [{'_id': ObjectId('5a9427658b0beebeb6979060'), 'name': 'Janos Slynt', 'email': 'dominic_carter@gameofthron.es', 'movie_id': ObjectId('573a13c5f29313caabd7002b'), 'text': 'Laborum saepe perferendis eos fugit. Possimus corporis unde autem vero aspernatur. Cumque nesciunt quo illum tempore laboriosam unde sequi. Eius doloribus ullam eaque labore nisi.', 'date': datetime.datetime(1981, 11, 3, 6, 44, 8)}]}
# {'_id': ObjectId('573a13c5f29313caabd710c9'), 'title': 'True Grit', 'comentarios': []}
# {'_id': ObjectId('573a13c8f29313caabd78900'), 'title': 'Heathens and Thieves', 'comentarios': []}
# {'_id': ObjectId('573a13c9f29313caabd792a8'), 'title': "Meek's Cutoff", 'comentarios': [{'_id': ObjectId('5a9427658b0beebeb6979758'), 'name': 'Ned Stark', 'email': 'sean_bean@gameofthron.es', 'movie_id': ObjectId('573a13c9f29313caabd792a8'), 'text': 'Cumque fugiat animi aspernatur nesciunt minus quia. Officia deleniti commodi non earum. Ex nisi ad earum occaecati mollitia.', 'date': datetime.datetime(2012, 2, 10, 15, 20, 33)}]}
# {'_id': ObjectId('573a13c9f29313caabd7a1da'), 'title': 'Red Hill', 'comentarios': [{'_id': ObjectId('5a9427658b0beebeb69797d5'), 'name': 'Othell Yarwyck', 'email': 'brian_fortune@gameofthron.es', 'movie_id': ObjectId('573a13c9f29313caabd7a1da'), 'text': 'Sit magnam id sunt odio. Fugit illum beatae natus saepe. Quasi veniam molestiae commodi nisi. Accusantium officiis temporibus quasi ullam similique occaecati.', 'date': datetime.datetime(2010, 9, 5, 2, 11, 39)}]}
# {'_id': ObjectId('573a13caf29313caabd7c3d2'), 'title': 'Six Shooters', 'comentarios': []}
# {'_id': ObjectId('573a13cbf29313caabd8059a'), 'title': 'DC Showcase: Jonah Hex', 'comentarios': []}
# {'_id': ObjectId('573a13ccf29313caabd820c7'), 'title': 'Blackthorn', 'comentarios': [{'_id': ObjectId('5a9427658b0beebeb6979b4d'), 'name': 'Osha', 'email': 'natalia_tena@gameofthron.es', 'movie_id': ObjectId('573a13ccf29313caabd820c7'), 'text': 'Illo reiciendis similique harum qui eos libero. Aspernatur distinctio quibusdam vel. Officia repellendus animi consequuntur officia aut officiis.', 'date': datetime.datetime(1972, 11, 25, 6, 7, 20)}]}
# {'_id': ObjectId('573a13cdf29313caabd850f9'), 'title': "Love's Resounding Courage", 'comentarios': []}
# {'_id': ObjectId('573a13cef29313caabd8708e'), 'title': 'Casa de mi Padre', 'comentarios': []}
# {'_id': ObjectId('573a13cef29313caabd87eb0'), 'title': 'Yellow Rock', 'comentarios': [{'_id': ObjectId('5a9427658b0beebeb6979e6f'), 'name': 'Catherine Romero', 'email': 'catherine_romero@fakegmail.com', 'movie_id': ObjectId('573a13cef29313caabd87eb0'), 'text': 'Hic beatae quaerat quam dolore. Doloribus deserunt facilis perspiciatis in nemo vero molestiae expedita. Ratione earum earum quidem cumque minima. Itaque praesentium natus molestiae.', 'date': datetime.datetime(2004, 3, 26, 21, 38, 31)}]}
# {'_id': ObjectId('573a13d0f29313caabd8cdab'), 'title': 'Good for Nothing', 'comentarios': []}
# {'_id': ObjectId('573a13d2f29313caabd92a92'), 'title': 'Django Unchained', 'comentarios': []}
# {'_id': ObjectId('573a13d2f29313caabd92e41'), 'title': 'Django Unchained', 'comentarios': []}
# {'_id': ObjectId('573a13d5f29313caabd9c1fc'), 'title': 'Dawn Rider', 'comentarios': []}
# {'_id': ObjectId('573a13d6f29313caabd9fb07'), 'title': "Hannah's Law", 'comentarios': []}
# {'_id': ObjectId('573a13d6f29313caabda07ec'), 'title': "Dead Man's Burden", 'comentarios': []}
# {'_id': ObjectId('573a13d7f29313caabda1c3f'), 'title': 'Wild Horse, Wild Ride', 'comentarios': []}
# {'_id': ObjectId('573a13d8f29313caabda7f76'), 'title': 'Sweetwater', 'comentarios': []}
# {'_id': ObjectId('573a13dbf29313caabdaee4d'), 'title': 'Gold', 'comentarios': []}
# {'_id': ObjectId('573a13dcf29313caabdb2a18'), 'title': 'The Homesman', 'comentarios': [{'_id': ObjectId('5a9427658b0beebeb697aef2'), 'name': 'Desiree Pierce', 'email': 'desiree_pierce@fakegmail.com', 'movie_id': ObjectId('573a13dcf29313caabdb2a18'), 'text': 'Sapiente fugiat ullam ullam dolores accusamus dolore. Doloremque expedita aliquid quisquam unde laboriosam perferendis. Doloremque voluptatum nam eligendi alias quisquam minima cumque.', 'date': datetime.datetime(1976, 9, 4, 23, 56, 28)}, {'_id': ObjectId('5a9427658b0beebeb697aef3'), 'name': 'Kevan Lannister', 'email': 'ian_gelder@gameofthron.es', 'movie_id': ObjectId('573a13dcf29313caabdb2a18'), 'text': 'Perferendis quaerat nesciunt deleniti. Optio eius dolore ex quo excepturi veniam. Sed quos ut necessitatibus excepturi vero quos. Numquam at amet saepe porro.', 'date': datetime.datetime(1985, 9, 27, 2, 16, 55)}]}
# {'_id': ObjectId('573a13dff29313caabdb786c'), 'title': 'A Million Ways to Die in the West', 'comentarios': []}
# {'_id': ObjectId('573a13e0f29313caabdb9f09'), 'title': 'The Retrieval', 'comentarios': [{'_id': ObjectId('5a9427658b0beebeb697b256'), 'name': 'Deborah Kennedy', 'email': 'deborah_kennedy@fakegmail.com', 'movie_id': ObjectId('573a13e0f29313caabdb9f09'), 'text': 'Modi omnis sit voluptatem quas. Eius ipsa repudiandae error quaerat. Deserunt ullam sit ut deleniti cumque veritatis.', 'date': datetime.datetime(2015, 10, 14, 12, 47, 15)}]}
# {'_id': ObjectId('573a13e1f29313caabdbc047'), 'title': 'The Salvation', 'comentarios': [{'_id': ObjectId('5a9427658b0beebeb697b31f'), 'name': 'Varys', 'email': 'conleth_hill@gameofthron.es', 'movie_id': ObjectId('573a13e1f29313caabdbc047'), 'text': 'Laudantium explicabo commodi vel sapiente vero error. Perspiciatis natus perferendis facere unde quia at. Iusto illum voluptas libero voluptatum.', 'date': datetime.datetime(1988, 2, 24, 22, 57, 6)}]}
# {'_id': ObjectId('573a13e2f29313caabdbe04f'), 'title': 'Darkness on the Edge of Town', 'comentarios': []}
# {'_id': ObjectId('573a13e8f29313caabdc9e14'), 'title': 'Slow West', 'comentarios': []}
# {'_id': ObjectId('573a13e8f29313caabdcac23'), 'title': 'Becoming Bulletproof', 'comentarios': [{'_id': ObjectId('5a9427658b0beebeb697b83a'), 'name': 'John Bishop', 'email': 'john_bishop@fakegmail.com', 'movie_id': ObjectId('573a13e8f29313caabdcac23'), 'text': 'In distinctio occaecati saepe quos. Repudiandae numquam ratione quasi animi qui voluptate. Consequuntur voluptatum soluta suscipit laudantium ad quisquam. Voluptate minima cumque illum quia fugit.', 'date': datetime.datetime(1994, 6, 10, 14, 52)}]}
# {'_id': ObjectId('573a13eaf29313caabdcef61'), 'title': 'The Gunfighter', 'comentarios': []}
# {'_id': ObjectId('573a13f5f29313caabde43f8'), 'title': 'Western', 'comentarios': [{'_id': ObjectId('5a9427658b0beebeb697c07b'), 'name': 'Lori Franklin', 'email': 'lori_franklin@fakegmail.com', 'movie_id': ObjectId('573a13f5f29313caabde43f8'), 'text': 'Explicabo libero non qui inventore culpa neque corporis mollitia. Odit adipisci aliquid natus ipsam illum vel tempora. Omnis illo dolores totam hic. Placeat nostrum quod qui consequuntur.', 'date': datetime.datetime(1977, 7, 20, 12, 6, 38)}]}
